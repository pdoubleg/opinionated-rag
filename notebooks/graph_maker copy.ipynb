# %%
import os
from dotenv import load_dotenv
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
from IPython.display import Markdown, display, HTML

import uuid
from tqdm import tqdm
from langchain_community.document_loaders import DataFrameLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

load_dotenv()
# Out:
# True

# %%
os.chdir(os.path.dirname(os.getcwd()))

# %%
from pathlib import Path

domain_knowledge_path = "omni\prompts\knowledge_bases\cons\domain_knowledge.txt"

with open(domain_knowledge_path, "r") as file:
    domain_knowledge = file.read()

# %%
import re

sections = re.split(r'\n# ', domain_knowledge.strip())
sections = [s.strip() for s in sections if s]

data_list = []
for section in sections:
    lines = section.split('\n')
    name = lines[0].replace('# ', '').strip()
    text = ' '.join(lines[1:]).strip()
    data_list.append({'name': name, 'text': text})

services_df = pd.DataFrame(data_list)
services_df['full_description'] = services_df.apply(lambda row: f"{row['name']}: {row['text']}", axis=1)

# %%
print(services_df.shape)
services_df.head()
# Out:
# (139, 3)
#                        name  \
# 0       Employment Disputes
# 1             Coverage Team
# 2               Field Legal
# 3           Compliance Team
# 4  Fraud Investigation Unit
#
#                                                 text  \
# 0  Handles legal issues concerning current or for...
# 1  Specialized attorneys providing advice on comp...
# 2  Manages all litigation matters. Handles cases ...
# 3  Ensures company adherence to legal standards a...
# 4  Investigates suspected insurance fraud cases. ...
#
#                                     full_description
# 0  Employment Disputes: Handles legal issues conc...
# 1  Coverage Team: Specialized attorneys providing...
# 2  Field Legal: Manages all litigation matters. H...
# 3  Compliance Team: Ensures company adherence to ...
# 4  Fraud Investigation Unit: Investigates suspect...

# %%
from typing import List, Dict
from pydantic import BaseModel, ConfigDict, Field

class OntologyLabel(BaseModel):
    """A label describing an ontology item for a given topic or theme."""
    
    category: str = Field(
        ...,
        description="A category label representing an entity type for a given text and theme of interest.",
    )
    description: str = Field(
        ...,
        description="A description or definition for the entity category.",
    )
    
    model_config = ConfigDict(
        json_schema_extra={
            "examples": [
                {   "category": "Department", 
                    "description": "A distinct department or team.."},
                {
                    "category": "Service",
                    "description": "A specific service offering.",
                },
                {
                    "category": "Role",
                    "description": "A role or job title within a department or team.",
                },
                {
                    "category": "Issue",
                    "description": "A specific issue that a team or service can resolve.",
                },
                {
                    "category": "CATEGORY",
                    "description": "DESCRIPTION",
                },
            ]
        }
    )

class Ontology(BaseModel):
    """An ontology for a given text and user specified theme or topic."""
    
    labels: List[OntologyLabel] = Field(
        ..., 
        default_factory=list,
        description="A list of ontology items to be used for downstream entity extraction and knowledge graph creation.",
    )
    model_config = ConfigDict(
        extra="allow",
        arbitrary_types_allowed=True,
    )
    
    @property
    def to_pandas(self):
        ontology_dict = {
            "category": [n.category for n in self.labels],
            "description": [n.description for n in self.labels],

        }
        return pd.DataFrame(ontology_dict)

# %%
import instructor
from openai import OpenAI


client = instructor.from_openai(OpenAI())


def user_message(theme: str, text: str) -> str:
    return f"While focusing on the theme **{theme}**, generate a comprehensive and targeted ontology for the following input text: ```\n{text}\n```"


def system_message() -> str:
    return (
        "You are an expert at creating a comprehensive ontology for a given theme or topic. "
        "Users will provide you with a **theme** and an input text delimited by ```. "
        "Extract ALL entity types from the input text that appear relevant to the **theme**. "
        "The goal is to create an ontology to use for downstream knowledge graph construction for the **theme**."
    )


def generate_ontology(theme: str, text: str) -> str:
    return client.chat.completions.create(
        model="gpt-4o",
        max_retries=3,
        messages=[
            {
                "role": "system",
                "content": system_message(),
            },
            {
                "role": "user",
                "content": user_message(theme=theme, text=text),
            },
        ],
        response_model=Ontology,
    )

# %%
extracted_ontology = generate_ontology(
    theme="Internal Legal Services",
    text=domain_knowledge,
)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"

# %%
o_df = extracted_ontology.to_pandas
Markdown(o_df.to_markdown())
# Out:
# |    | category           | description                                                                                                                                                     |
# |---:|:-------------------|:----------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |  0 | Department         | A distinct department or team within the internal legal services.                                                                                               |
# |  1 | Service            | A specific service offering within internal legal services.                                                                                                     |
# |  2 | Role               | A role or job title within a department or team.                                                                                                                |
# |  3 | Issue              | A specific issue that a team or service can resolve.                                                                                                            |
# |  4 | Case Type          | A type of legal case handled by the internal legal services.                                                                                                    |
# |  5 | Process            | A process or procedure followed by a legal team within the internal legal services.                                                                             |
# |  6 | Specialization     | A specific area of expertise within the legal field relevant to internal legal services.                                                                        |
# |  7 | Collaboration      | The act of working with other departments, teams, or external entities.                                                                                         |
# |  8 | Compliance         | Adherence to laws, regulations, and standards within internal legal services.                                                                                   |
# |  9 | Audit              | An internal or external review ensuring adherence to regulations and standards.                                                                                 |
# | 10 | Document           | Legal documents or papers handled or produced by the internal legal services.                                                                                   |
# | 11 | Guidance           | Advice or recommendations provided by legal experts.                                                                                                            |
# | 12 | Litigation         | The action of taking legal proceedings in a court.                                                                                                              |
# | 13 | Mediation          | A method of dispute resolution involving a neutral third party.                                                                                                 |
# | 14 | Risk Management    | The identification, evaluation, and prioritization of risks followed by coordinated efforts to minimize, control, and monitor the impact of unfortunate events. |
# | 15 | Policy             | A course or principle of action adopted or proposed by an organization or individual within the legal sphere.                                                   |
# | 16 | Dispute Resolution | The process of resolving a dispute or a conflict.                                                                                                               |
# | 17 | Training           | Educational activities aimed at improving legal knowledge and skills.                                                                                           |
# | 18 | Regulation         | Rules or directives made and maintained by an authority in the legal context.                                                                                   |

# %%
print(extracted_ontology.model_dump_json(indent=4))
# Out:
# {
#     "labels": [
#         {
#             "category": "Department",
#             "description": "A distinct department or team within the internal legal services."
#         },
#         {
#             "category": "Service",
#             "description": "A specific service offering within internal legal services."
#         },
#         {
#             "category": "Role",
#             "description": "A role or job title within a department or team."
#         },
#         {
#             "category": "Issue",
#             "description": "A specific issue that a team or service can resolve."
#         },
#         {
#             "category": "Case Type",
#             "description": "A type of legal case handled by the internal legal services."
#         },
#         {
#             "category": "Process",
#             "description": "A process or procedure followed by a legal team within the internal legal services."
#         },
#         {
#             "category": "Specialization",
#             "description": "A specific area of expertise within the legal field relevant to internal legal services."
#         },
#         {
#             "category": "Collaboration",
#             "description": "The act of working with other departments, teams, or external entities."
#         },
#         {
#             "category": "Compliance",
#             "description": "Adherence to laws, regulations, and standards within internal legal services."
#         },
#         {
#             "category": "Audit",
#             "description": "An internal or external review ensuring adherence to regulations and standards."
#         },
#         {
#             "category": "Document",
#             "description": "Legal documents or papers handled or produced by the internal legal services."
#         },
#         {
#             "category": "Guidance",
#             "description": "Advice or recommendations provided by legal experts."
#         },
#         {
#             "category": "Litigation",
#             "description": "The action of taking legal proceedings in a court."
#         },
#         {
#             "category": "Mediation",
#             "description": "A method of dispute resolution involving a neutral third party."
#         },
#         {
#             "category": "Risk Management",
#             "description": "The identification, evaluation, and prioritization of risks followed by coordinated efforts to minimize, control, and monitor the impact of unfortunate events."
#         },
#         {
#             "category": "Policy",
#             "description": "A course or principle of action adopted or proposed by an organization or individual within the legal sphere."
#         },
#         {
#             "category": "Dispute Resolution",
#             "description": "The process of resolving a dispute or a conflict."
#         },
#         {
#             "category": "Training",
#             "description": "Educational activities aimed at improving legal knowledge and skills."
#         },
#         {
#             "category": "Regulation",
#             "description": "Rules or directives made and maintained by an authority in the legal context."
#         }
#     ]
# }

# %%
from typing import List
from openai import OpenAI
import instructor
from pydantic import BaseModel, Field

client = instructor.from_openai(OpenAI())
model = "gpt-4o"


class Node(BaseModel):
    label: str
    name: str


class Edge(BaseModel):
    node_1: Node
    node_2: Node
    relationship: str
    

class KnowledgeGraph(BaseModel):
    edges: List[Edge] = Field(..., default_factory=list)
    
    @property
    def to_pandas(self):
        kg_dict = {
            "node_1": [n.node_1.name for n in self.edges],
            "node_2": [n.node_2.name for n in self.edges],
            "edge": [n.relationship for n in self.edges],
            "node_1_type": [n.node_1.label for n in self.edges],
            "node_2_type": [n.node_2.label for n in self.edges],
        }
        return pd.DataFrame(kg_dict)


def user_message(text: str) -> str:
    return f"input text: ```\n{text}\n```"

def system_message(ontology: Ontology) -> str:
    return (
        "You are an expert at creating Knowledge Graphs. "
        "Consider the following ontology. \n"
        f"{ontology.model_dump_json(indent=4)} \n"
        "The user will provide you with an input text delimited by ```. "
        "Extract all the entities and relationships from the user-provided text as per the given ontology. Do not use any previous knowledge about the context."
        "Remember there can be multiple direct (explicit) or implied relationships between the same pair of nodes. "
        "Be consistent with the given ontology. Use ONLY the labels and relationships mentioned in the ontology. "
        "Remember to follow the correct format, for example:\n"
        "[\n"
        "   {\n"
        '       node_1: Required, an entity object with attributes: {"label": "as per the ontology", "name": "Name of the entity"},\n'
        '       node_2: Required, an entity object with attributes: {"label": "as per the ontology", "name": "Name of the entity"},\n'
        "       relationship: Describe the relationship between node_1 and node_2 as per the context, in one or two sentences.\n"
        "   },\n"
        "]\n"
    )


def generate_graph(text: str, ontology: Ontology, model: str) -> str:
    return client.chat.completions.create(
        model=model,
        max_retries=3,
        messages=[
            {
                "role": "system",
                "content": system_message(ontology),
            },
            {
                "role": "user",
                "content": user_message(text=text),
            },
        ],
        response_model=KnowledgeGraph,
    )

# %%
def df2Graph(df, ontology, model="gpt-4o") -> pd.DataFrame:
    progress_bar = tqdm(total=len(df), desc="Processing chunks")

    def apply_graphPrompt(row):
        result = generate_graph(row.text, ontology, model)
        result_df = result.to_pandas
        result_df["chunk_id"] = row.chunk_id
        progress_bar.update(1)
        return result_df
    
    results = df.apply(apply_graphPrompt, axis=1)
    results_df = pd.concat(results.tolist(), ignore_index=True)
    progress_bar.close()
    
    return results_df

# %%
def dataframe2Documents(df: pd.DataFrame, text_column: str):
    loader = DataFrameLoader(df, page_content_column=text_column)
    return loader.load()

def documents2Dataframe(documents) -> pd.DataFrame:
    rows = []
    for chunk in documents:
        row = {
            "text": chunk.page_content,
            **chunk.metadata,
            "chunk_id": uuid.uuid4().hex,
        }
        rows = rows + [row]
    df = pd.DataFrame(rows)
    return df

# %%
docs = dataframe2Documents(
    df=services_df[["name", "full_description"]], 
    text_column="full_description",
)
prepped_df = documents2Dataframe(docs)
print(prepped_df.shape)
prepped_df.head(3)
# Out:
# (139, 3)
#                                                 text                 name  \
# 0  Employment Disputes: Handles legal issues conc...  Employment Disputes
# 1  Coverage Team: Specialized attorneys providing...        Coverage Team
# 2  Field Legal: Manages all litigation matters. H...          Field Legal
#
#                            chunk_id
# 0  b9ce1fcf4245475baeeec1740564e622
# 1  22f1ff1b010c4a078b30682768fa6ce1
# 2  54ce68e98bfb4a83bcef521071408301

# %%
dfg = df2Graph(prepped_df, extracted_ontology)
# Out:
# Processing chunks:   0%|          | 0/139 [00:00<?, ?it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:   1%|          | 1/139 [00:02<06:36,  2.87s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:   1%|▏         | 2/139 [00:08<10:50,  4.75s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:   2%|▏         | 3/139 [00:11<08:07,  3.58s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:   3%|▎         | 4/139 [00:13<07:00,  3.12s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:   4%|▎         | 5/139 [00:16<06:42,  3.00s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:   4%|▍         | 6/139 [00:19<07:01,  3.17s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:   5%|▌         | 7/139 [00:22<06:21,  2.89s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:   6%|▌         | 8/139 [00:24<06:11,  2.83s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:   6%|▋         | 9/139 [00:27<06:08,  2.84s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:   7%|▋         | 10/139 [00:30<06:20,  2.95s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:   8%|▊         | 11/139 [00:33<06:20,  2.97s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:   9%|▊         | 12/139 [00:37<06:51,  3.24s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:   9%|▉         | 13/139 [00:41<07:09,  3.40s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  10%|█         | 14/139 [00:46<08:10,  3.92s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  11%|█         | 15/139 [00:50<08:02,  3.89s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  12%|█▏        | 16/139 [00:53<07:31,  3.67s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  12%|█▏        | 17/139 [00:56<06:51,  3.37s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  13%|█▎        | 18/139 [01:02<08:47,  4.36s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  14%|█▎        | 19/139 [01:05<07:23,  3.69s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  14%|█▍        | 20/139 [01:07<06:22,  3.21s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  15%|█▌        | 21/139 [01:09<06:00,  3.06s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  16%|█▌        | 22/139 [01:12<05:34,  2.86s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  17%|█▋        | 23/139 [01:15<05:42,  2.95s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  17%|█▋        | 24/139 [01:19<05:58,  3.12s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  18%|█▊        | 25/139 [01:22<05:57,  3.14s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  19%|█▊        | 26/139 [01:27<07:20,  3.90s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  19%|█▉        | 27/139 [01:30<06:20,  3.40s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  20%|██        | 28/139 [01:33<06:15,  3.39s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  21%|██        | 29/139 [01:40<08:19,  4.54s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  22%|██▏       | 30/139 [01:43<07:11,  3.96s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  22%|██▏       | 31/139 [01:48<07:44,  4.30s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  23%|██▎       | 32/139 [01:52<07:23,  4.15s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  24%|██▎       | 33/139 [01:55<07:05,  4.01s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  24%|██▍       | 34/139 [01:59<07:03,  4.04s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  25%|██▌       | 35/139 [02:03<06:41,  3.86s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  26%|██▌       | 36/139 [02:07<06:36,  3.85s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  27%|██▋       | 37/139 [02:12<07:30,  4.41s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  27%|██▋       | 38/139 [02:16<07:08,  4.24s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  28%|██▊       | 39/139 [02:19<06:13,  3.74s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  29%|██▉       | 40/139 [02:21<05:20,  3.24s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  29%|██▉       | 41/139 [02:23<04:57,  3.03s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  30%|███       | 42/139 [02:26<04:40,  2.89s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  31%|███       | 43/139 [02:29<04:29,  2.80s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  32%|███▏      | 44/139 [02:30<03:53,  2.46s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  32%|███▏      | 45/139 [02:35<04:46,  3.04s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  33%|███▎      | 46/139 [02:37<04:27,  2.88s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  34%|███▍      | 47/139 [02:40<04:30,  2.94s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  35%|███▍      | 48/139 [02:43<04:17,  2.83s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  35%|███▌      | 49/139 [02:48<05:10,  3.45s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  36%|███▌      | 50/139 [02:51<04:54,  3.31s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  37%|███▋      | 51/139 [02:53<04:20,  2.96s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  37%|███▋      | 52/139 [02:57<04:53,  3.37s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  38%|███▊      | 53/139 [03:01<05:04,  3.54s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  39%|███▉      | 54/139 [03:05<04:59,  3.52s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  40%|███▉      | 55/139 [03:07<04:18,  3.08s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  40%|████      | 56/139 [03:12<05:11,  3.75s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  41%|████      | 57/139 [03:16<05:01,  3.68s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  42%|████▏     | 58/139 [03:19<04:47,  3.55s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  42%|████▏     | 59/139 [03:23<05:05,  3.82s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  43%|████▎     | 60/139 [03:27<05:01,  3.82s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  44%|████▍     | 61/139 [03:32<05:28,  4.22s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  45%|████▍     | 62/139 [03:35<04:59,  3.88s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  45%|████▌     | 63/139 [03:38<04:34,  3.61s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  46%|████▌     | 64/139 [03:42<04:41,  3.75s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  47%|████▋     | 65/139 [03:47<05:03,  4.10s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  47%|████▋     | 66/139 [03:51<04:55,  4.05s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  48%|████▊     | 67/139 [03:54<04:30,  3.76s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  49%|████▉     | 68/139 [03:56<03:43,  3.15s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  50%|████▉     | 69/139 [04:01<04:29,  3.85s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  50%|█████     | 70/139 [04:07<05:03,  4.40s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  51%|█████     | 71/139 [04:09<04:11,  3.70s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  52%|█████▏    | 72/139 [04:12<03:53,  3.48s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  53%|█████▎    | 73/139 [04:15<03:42,  3.37s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  53%|█████▎    | 74/139 [04:21<04:19,  4.00s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  54%|█████▍    | 75/139 [04:23<03:45,  3.52s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  55%|█████▍    | 76/139 [04:28<03:57,  3.77s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  55%|█████▌    | 77/139 [04:35<04:55,  4.76s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  56%|█████▌    | 78/139 [04:38<04:22,  4.30s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  57%|█████▋    | 79/139 [04:42<04:13,  4.22s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  58%|█████▊    | 80/139 [04:44<03:39,  3.71s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  58%|█████▊    | 81/139 [04:47<03:12,  3.32s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  59%|█████▉    | 82/139 [04:50<03:09,  3.32s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  60%|█████▉    | 83/139 [04:56<03:55,  4.21s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  60%|██████    | 84/139 [04:58<03:12,  3.50s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  61%|██████    | 85/139 [05:01<02:58,  3.31s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  62%|██████▏   | 86/139 [05:04<02:45,  3.12s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  63%|██████▎   | 87/139 [05:07<02:45,  3.18s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  63%|██████▎   | 88/139 [05:10<02:37,  3.10s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  64%|██████▍   | 89/139 [05:12<02:24,  2.89s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  65%|██████▍   | 90/139 [05:16<02:29,  3.05s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  65%|██████▌   | 91/139 [05:18<02:10,  2.72s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  66%|██████▌   | 92/139 [05:22<02:33,  3.27s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  67%|██████▋   | 93/139 [05:26<02:40,  3.48s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  68%|██████▊   | 94/139 [05:30<02:33,  3.41s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  68%|██████▊   | 95/139 [05:35<02:53,  3.93s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  69%|██████▉   | 96/139 [05:38<02:38,  3.68s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  70%|██████▉   | 97/139 [05:41<02:24,  3.45s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  71%|███████   | 98/139 [05:43<02:09,  3.15s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  71%|███████   | 99/139 [05:46<02:04,  3.12s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  72%|███████▏  | 100/139 [05:50<02:07,  3.26s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  73%|███████▎  | 101/139 [05:53<02:05,  3.29s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  73%|███████▎  | 102/139 [05:55<01:48,  2.93s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  74%|███████▍  | 103/139 [05:57<01:34,  2.62s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  75%|███████▍  | 104/139 [05:59<01:24,  2.41s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  76%|███████▌  | 105/139 [06:01<01:18,  2.31s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  76%|███████▋  | 106/139 [06:05<01:28,  2.69s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  77%|███████▋  | 107/139 [06:11<02:04,  3.88s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  78%|███████▊  | 108/139 [06:15<01:54,  3.70s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  78%|███████▊  | 109/139 [06:17<01:36,  3.23s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  79%|███████▉  | 110/139 [06:21<01:43,  3.57s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  80%|███████▉  | 111/139 [06:24<01:35,  3.41s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  81%|████████  | 112/139 [06:28<01:35,  3.54s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  81%|████████▏ | 113/139 [06:30<01:19,  3.05s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  82%|████████▏ | 114/139 [06:33<01:14,  2.99s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  83%|████████▎ | 115/139 [06:34<01:01,  2.58s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  83%|████████▎ | 116/139 [06:37<00:56,  2.44s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  84%|████████▍ | 117/139 [06:38<00:50,  2.28s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  85%|████████▍ | 118/139 [06:40<00:45,  2.18s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  86%|████████▌ | 119/139 [06:42<00:40,  2.04s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  86%|████████▋ | 120/139 [06:46<00:46,  2.46s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  87%|████████▋ | 121/139 [06:49<00:49,  2.76s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  88%|████████▊ | 122/139 [06:52<00:49,  2.89s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  88%|████████▊ | 123/139 [06:55<00:43,  2.72s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  89%|████████▉ | 124/139 [06:56<00:36,  2.47s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  90%|████████▉ | 125/139 [06:59<00:33,  2.41s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  91%|█████████ | 126/139 [07:02<00:33,  2.60s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  91%|█████████▏| 127/139 [07:04<00:30,  2.52s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  92%|█████████▏| 128/139 [07:06<00:25,  2.33s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  93%|█████████▎| 129/139 [07:09<00:24,  2.50s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  94%|█████████▎| 130/139 [07:11<00:20,  2.31s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  94%|█████████▍| 131/139 [07:13<00:18,  2.29s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  95%|█████████▍| 132/139 [07:15<00:15,  2.15s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  96%|█████████▌| 133/139 [07:17<00:12,  2.08s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  96%|█████████▋| 134/139 [07:19<00:10,  2.04s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  97%|█████████▋| 135/139 [07:25<00:13,  3.42s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  98%|█████████▊| 136/139 [07:27<00:09,  3.02s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  99%|█████████▊| 137/139 [07:29<00:05,  2.70s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks:  99%|█████████▉| 138/139 [07:36<00:03,  3.76s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing chunks: 100%|██████████| 139/139 [07:38<00:00,  3.30s/it]

# %%
dfg.replace("", np.nan, inplace=True)
dfg.dropna(subset=["node_1", "node_2", 'edge'], inplace=True)
dfg['count'] = 4

# %%
print(dfg.shape)
dfg.head()
# Out:
# (621, 7)
#                 node_1                      node_2  \
# 0  Employment Disputes        wrongful termination
# 1  Employment Disputes    payment-related disputes
# 2  Employment Disputes         contractual matters
# 3  Employment Disputes  discrimination accusations
# 4        Coverage Team       Specialized attorneys
#
#                                                 edge node_1_type node_2_type  \
# 0  Employment Disputes includes cases related to ...   Case Type       Issue
# 1  Employment Disputes includes cases related to ...   Case Type       Issue
# 2  Employment Disputes includes cases related to ...   Case Type       Issue
# 3  Employment Disputes does not handle cases rela...   Case Type       Issue
# 4   Coverage Team consists of Specialized attorneys.  Department        Role
#
#                            chunk_id  count
# 0  b9ce1fcf4245475baeeec1740564e622      4
# 1  b9ce1fcf4245475baeeec1740564e622      4
# 2  b9ce1fcf4245475baeeec1740564e622      4
# 3  b9ce1fcf4245475baeeec1740564e622      4
# 4  22f1ff1b010c4a078b30682768fa6ce1      4

# %%
dfg['node_1'].nunique(), dfg['node_2'].nunique()
# Out:
# (170, 503)

# %%
def contextual_proximity(df: pd.DataFrame) -> pd.DataFrame:
    ## Melt the dataframe into a list of nodes
    dfg_long = pd.melt(
        df, id_vars=["chunk_id"], value_vars=["node_1", "node_2"], value_name="node"
    )
    dfg_long.drop(columns=["variable"], inplace=True)
    # Self join with chunk id as the key will create a link between terms occurring in the same text chunk.
    dfg_wide = pd.merge(dfg_long, dfg_long, on="chunk_id", suffixes=("_1", "_2"))
    # drop self loops
    self_loops_drop = dfg_wide[dfg_wide["node_1"] == dfg_wide["node_2"]].index
    dfg2 = dfg_wide.drop(index=self_loops_drop).reset_index(drop=True)
    ## Group and count edges.
    dfg2 = (
        dfg2.groupby(["node_1", "node_2"])
        .agg({"chunk_id": [",".join, "count"]})
        .reset_index()
    )
    dfg2.columns = ["node_1", "node_2", "chunk_id", "count"]
    dfg2.replace("", np.nan, inplace=True)
    dfg2.dropna(subset=["node_1", "node_2"], inplace=True)
    # Drop edges with 1 count
    dfg2 = dfg2[dfg2["count"] != 1]
    dfg2["edge"] = "contextual proximity"
    return dfg2

# %%
dfg2 = contextual_proximity(dfg)

# %%
dfg2['count'].describe()
# Out:
# count    1678.000000
# mean        4.376639
# std         2.108840
# min         2.000000
# 25%         3.000000
# 50%         4.000000
# 75%         6.000000
# max        18.000000
# Name: count, dtype: float64

# %%
print(dfg2.shape)
dfg2.head()
# Out:
# (1678, 5)
#                                     node_1  \
# 0                           ADR Strategies
# 7   Addresses instances of insurance fraud
# 10    Advertising and Marketing Legal Team
# 11    Advertising and Marketing Legal Team
# 12    Advertising and Marketing Legal Team
#
#                                    node_2  \
# 0     Alternative Dispute Resolution Team
# 7         Insurance Fraud Prevention Team
# 10       Advertising and marketing issues
# 11    Advertising and marketing practices
# 12  Advertising regulations and standards
#
#                                              chunk_id  count  \
# 0   ccb1a3260f904b8d9d687db10380464b,ccb1a3260f904...      6
# 7   ecccbc4e02e247c9b476f8bbf6e843be,ecccbc4e02e24...      4
# 10  618d341bbe5e41d09f83fd2ec2cec1f4,618d341bbe5e4...     10
# 11  618d341bbe5e41d09f83fd2ec2cec1f4,618d341bbe5e4...      5
# 12  618d341bbe5e41d09f83fd2ec2cec1f4,618d341bbe5e4...     10
#
#                     edge
# 0   contextual proximity
# 7   contextual proximity
# 10  contextual proximity
# 11  contextual proximity
# 12  contextual proximity

# %%
dfg3 = pd.concat([dfg, dfg2], axis=0)
dfg3 = (
    dfg.groupby(["node_1", "node_2"])
    .agg({"chunk_id": ",".join, "edge": ','.join, 'count': 'sum'})
    .reset_index()
)
print(dfg3.shape)
dfg3.head()
# Out:
# (599, 5)
#                                  node_1  \
# 0  Advertising and Marketing Legal Team
# 1  Advertising and Marketing Legal Team
# 2  Advertising and Marketing Legal Team
# 3  Advertising and Marketing Legal Team
# 4  Advertising and Marketing Legal Team
#
#                                   node_2                          chunk_id  \
# 0    Advertising and marketing practices  618d341bbe5e41d09f83fd2ec2cec1f4
# 1  Advertising regulations and standards  618d341bbe5e41d09f83fd2ec2cec1f4
# 2                   Advice on compliance  618d341bbe5e41d09f83fd2ec2cec1f4
# 3                               Disputes  618d341bbe5e41d09f83fd2ec2cec1f4
# 4                             Litigation  618d341bbe5e41d09f83fd2ec2cec1f4
#
#                                edge  count
# 0  Handles legal matters related to      4
# 1                Provides advice on      4
# 2                          Provides      4
# 3                           Manages      4
# 4                           Manages      4

# %%
nodes = pd.concat([dfg['node_1'], dfg['node_2']], axis=0).unique()
nodes.shape
# Out:
# (622,)

# %%
import networkx as nx
G = nx.Graph()

## Add nodes to the graph
for node in nodes:
    G.add_node(
        str(node)
    )

## Add edges to the graph
for index, row in dfg.iterrows():
    G.add_edge(
        str(row["node_1"]),
        str(row["node_2"]),
        title=row["edge"],
        weight=row['count']/4
    )

# %%
communities_generator = nx.community.girvan_newman(G)
top_level_communities = next(communities_generator)
next_level_communities = next(communities_generator)
communities = sorted(map(sorted, next_level_communities))
print("Number of Communities = ", len(communities))
print(communities)
# Out:
# Number of Communities =  67
# [['ADR Strategies', 'Alternative Dispute Resolution Team', 'Arbitration', 'Auto Accidents', 'Auto Claims Legal Team', 'Auto Repair Experts', 'Bad Faith Allegations', 'Bad Faith Allegations Team', 'Claims Adjusters', 'Claims Litigation', 'Claims Litigation Team', 'Defense Strategies', 'Legal Advice', 'Legal Defense', 'Mediation', 'Non-litigation Dispute Resolution', 'Other Departments', 'Support for alternative dispute resolution methods', 'Vehicle Damage', 'Zoning Litigation', 'Zoning Litigation Team', 'Zoning and Land Use Disputes'], ['Addresses instances of insurance fraud', 'Fraud prevention and detection efforts', 'Insurance Fraud Prevention Team', 'Investigates instances of insurance fraud', 'Law enforcement and other agencies'], ['Advertising and Marketing Legal Team', 'Advertising and marketing issues', 'Advertising and marketing practices', 'Advertising regulations and standards', 'Advice on compliance', 'Appellate Legal Team', 'Appellate Litigation Team', 'Cases from the Coverage Team and other departments', 'Compliance with supply chain regulations and standards', 'Defending the company in court', 'Develop appellate strategies', 'Disputes', 'Disputes and litigation involving supply chain issues', 'Field Legal', 'Handles appeals and post-trial motions for litigation matters', 'Handling legal matters related to supply chain management and logistics', 'Litigation', 'Managing disputes', 'Provide advice on compliance with supply chain regulations and standards', 'Provides legal support for appellate briefs and oral arguments', 'Supply Chain Legal Team', 'Works with trial attorneys', 'Works with trial attorneys to develop appellate strategies'], ['Advice on Compliance', 'Child Protection Laws and Regulations', 'Disputes involving Youth Protection Issues', 'Litigation involving Youth Protection Issues', 'Protection of Minors', 'Youth Protection Legal Team'], ['Advice on Government Regulations and Policies', 'Disputes involving Government Affairs', 'Government Affairs Legal Team', 'Government Agencies and Officials', 'Litigation involving Government Affairs'], ['Advice on complex claims', 'Case law research', 'Coverage Team', 'Non-litigated matters', 'Policy definitions and their application', 'Specialized attorneys'], ['Advice on coverage issues', 'Insurance Coverage Legal Team', 'Insurance coverage', 'Litigation involving insurance coverage', 'Manages disputes', 'Policy interpretation', 'Policy language'], ['Advice on policy language and coverage issues', 'Drafting and review of insurance policies and contracts', 'Insurance Policy Drafting Team', 'Policy documents', 'Working with underwriters and other departments'], ['Alternative Energy Compliance Legal Team', 'Compliance with alternative energy laws and regulations', 'Guidance on alternative energy compliance issues', 'Internal audits and reviews of alternative energy practices'], ['Alternative Energy Legal Team', 'alternative energy', 'compliance with alternative energy regulations and standards', 'disputes involving alternative energy issues', 'litigation involving alternative energy issues'], ['Antitrust', 'Antitrust Claims', 'Antitrust Compliance', 'Antitrust Legal Team', 'Competition Law', 'Dispute Management', 'Legal advice', 'Litigation Management', 'Regulatory Issues', 'Workplace Safety Legal Team', 'Workplace safety issues', 'Workplace safety standards'], ['Appellate Compliance Legal Team', 'Board governance', 'Class Action Compliance', 'Class Action Compliance Issues', 'Class Action Compliance Legal Team', 'Compliance', 'Compliance Guidance', 'Compliance Team', 'Compliance with regulatory laws and regulations', 'Compliance-Related Issues', 'Corporate Governance Legal Team', 'Corporate governance', 'Corporate policies', 'Crisis Compliance', 'Crisis Compliance Issues', 'Crisis Compliance Legal Team', 'Disputes involving corporate governance issues', 'Employment Compliance', 'Employment Compliance Issues', 'Employment Compliance Legal Team', 'Employment Law Compli ...

# %%
import random
import seaborn as sns
palette = "hls"

def colors2Community(communities) -> pd.DataFrame:
    p = sns.color_palette(palette, len(communities)).as_hex()
    random.shuffle(p)
    rows = []
    group = 0
    for community in communities:
        color = p.pop()
        group += 1
        for node in community:
            rows += [{"node": node, "color": color, "group": group}]
    df_colors = pd.DataFrame(rows)
    return df_colors

# %%
colors = colors2Community(communities)
colors
# Out:
#                                                 node    color  group
# 0                                     ADR Strategies  #57aadb      1
# 1                Alternative Dispute Resolution Team  #57aadb      1
# 2                                        Arbitration  #57aadb      1
# 3                                     Auto Accidents  #57aadb      1
# 4                             Auto Claims Legal Team  #57aadb      1
# ..                                               ...      ...    ...
# 617            advice on compliance with zoning laws  #db575b     67
# 618                      compliance with zoning laws  #db575b     67
# 619           disputes involving zoning and land use  #db575b     67
# 620  litigation involving zoning and land use issues  #db575b     67
# 621                  zoning and land use regulations  #db575b     67
#
# [622 rows x 3 columns]

# %%
for index, row in colors.iterrows():
    G.nodes[row['node']]['group'] = row['group']
    G.nodes[row['node']]['color'] = row['color']
    G.nodes[row['node']]['size'] = G.degree[row['node']]

# %%
from pyvis.network import Network

graph_output_directory = "index.html"

net = Network(
    notebook=False,
    bgcolor="#1a1a1a",
    cdn_resources="remote",
    height="900px",
    width="100%",
    select_menu=True,
    font_color="#cccccc",
    filter_menu=True,
)

net.from_nx(G)
net.force_atlas_2based(central_gravity=0.015, gravity=-31)
net.show_buttons(filter_=["physics"])

net.show(graph_output_directory, notebook=False)
# Out:
# index.html

# %%
from src.parsing.graph_maker import GraphMaker, Document, Ontology

# %%
from typing import Literal


ENTITIES = Literal["DEPARTMENT", "TEAM", "ORGANIZATION", "SERVICE", "LEGAL_TOPIC", "INSURANCE_TOPIC"]

RELATIONS = Literal[
    "OVERSEER_OF",
    "RESPONSIBLE_FOR",
    "PROVIDES_GUIDANCE_ON",
    "CONDUCTS",
    "SUPPORTS",
    "REGULATES",
    "REVIEWS",
]

# %%
def user_message(text: str) -> str:
    return f"input text: ```\n{text}\n```"

def system_message() -> str:
    return (
        "You are an expert at creating Knowledge Graphs. "
        "The user will provide you with an input text delimited by ```. "
        "Extract all the entities and relationships from the user-provided text. Do not use any previous knowledge about the context."
        "Remember there can be multiple direct (explicit) or implied relationships between the same pair of nodes. "
        "Remember to follow the correct format."
    )


def generate_graph(text: str, model: str = "gpt-4o") -> str:
    return client.chat.completions.create(
        model=model,
        max_retries=3,
        messages=[
            {
                "role": "system",
                "content": system_message(),
            },
            {
                "role": "user",
                "content": user_message(text=text),
            },
        ],
        response_model=List[triplet_cls],
    )

# %%
test = generate_graph(domain_knowledge)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# File c:\Users\pdoub\opinionated-rag\.venv\lib\site-packages\instructor\retry.py:166, in retry_sync(func, response_model, validation_context, args, kwargs, max_retries, strict, mode)
#     165     response = update_total_usage(response, total_usage)
# --> 166     return process_response(
#     167         response,
#     168         response_model=response_model,
#     169         stream=stream,
#     170         validation_context=validation_context,
#     171         strict=strict,
#     172         mode=mode,
#     173     )
#     174 except (ValidationError, JSONDecodeError) as e:
#
# File c:\Users\pdoub\opinionated-rag\.venv\lib\site-packages\instructor\process_response.py:144, in process_response(response, response_model, stream, validation_context, strict, mode)
#     142     return model
# --> 144 model = response_model.from_response(
#     145     response,
#     146     validation_context=validation_context,
#     147     strict=strict,
#     148     mode=mode,
#     149 )
#     151 # ? This really hints at the fact that we need a better way of
#     152 # ? attaching usage data and the raw response to the model we return.
#
# File c:\Users\pdoub\opinionated-rag\.venv\lib\site-packages\instructor\function_calls.py:118, in OpenAISchema.from_response(cls, completion, validation_context, strict, mode)
#     117 if mode in {Mode.TOOLS, Mode.MISTRAL_TOOLS}:
# --> 118     return cls.parse_tools(completion, validation_context, strict)
#     120 if mode in {Mode.JSON, Mode.JSON_SCHEMA, Mode.MD_JSON}:
#
# File c:\Users\pdoub\opinionated-rag\.venv\lib\site-packages\instructor\function_calls.py:236, in OpenAISchema.parse_tools(cls, completion, validation_context, strict)
#     233 assert (
#     234     tool_call.function.name == cls.openai_schema["name"]  # type: ignore[index]
#     235 ), "Tool name does not match"
# --> 236 return cls.model_validate_json(
#     237     tool_call.function.arguments,  # type: ignore
#     238     context=validation_context,
#     239     strict=strict,
#     240 )
#
# File c:\Users\pdoub\opinionated-rag\.venv\lib\site-packages\pydantic\main.py:580, in BaseModel.model_validate_json(cls, json_data, strict, context)
#     579 __tracebackhide__ = True
# --> 580 return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
#
# ValidationError: 5 validation errors for Response
# content.4.relation.type
#   Input should be 'OVERSEER_OF', 'RESPONSIBLE_FOR', 'PROVIDES_GUIDANCE_ON', 'CONDUCTS', 'SUPPORTS', 'REGULATES' or 'REVIEWS' [type=literal_error, input_value='DOES_NOT_HANDLE', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/literal_error
# content.12.relation.type
#   Input should be 'OVERSEER_OF', 'RESPONSIBLE_FOR', 'PROVIDES_GUIDANCE_ON', 'CONDUCTS', 'SUPPORTS', 'REGULATES' or 'REVIEWS' [type=literal_error, input_value='ENSURES', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/literal_error
# content.18.relation.type
#   Input should be 'OVERSEER_OF', 'RESPONSIBLE_FOR', 'PROVIDES_GUIDANCE_ON', 'CONDUCTS', 'SUPPORTS', 'REGULATES' or 'REVIEWS' [type=literal_error, input_value='RECOVERS', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/literal_error
# content.23.relation.type
#   Input should be 'OVERSEER_OF', 'RESPONSIBLE_FOR', 'PROVIDES_GUIDANCE_ON', 'CONDUCTS', 'SUPPORTS', 'REGULATES' or 'REVIEWS' [type=literal_error, input_value='COLLABORATES_WITH', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/literal_error
# content.35.relation.type
#   Input should be 'OVERSEER_OF', 'RESPONSIBLE_FOR', 'PROVIDES_GUIDANCE_ON', 'CONDUCTS', 'SUPPORTS', 'REGULATES' or 'REVIEWS' [type=literal_error, input_value=' COLLABORATES_WITH', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/literal_error
#
# The above exception was the direct cause of the following exception:
#
# InstructorRetryException                  Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 test = generate_graph(domain_knowledge)
#
# Cell In[88], line 15, in generate_graph(text, model)
#      14 def generate_graph(text: str, model: str = "gpt-4o") -> str:
# ---> 15     return client.chat.completions.create(
#      16         model=model,
#      17         max_retries=3,
#      18         messages=[
#      19             {
#      20                 "role": "system",
#      21                 "content": system_message(),
#      22             },
#      23             {
#      24                 "role": "user",
#      25                 "content": user_message(text=text),
#      26             },
#      27         ],
#      28         response_model=List[triplet_cls],
#      29     )
#
# File c:\Users\pdoub\opinionated-rag\.venv\lib\site-packages\instructor\client.py:93, in Instructor.create(self, response_model, messages, max_retries, validation_context, strict, **kwargs)
#      82 def create(
#      83     self,
#      84     response_model: type[T],
#    (...)
#      89     **kwargs: Any,
#      90 ) -> T | Awaitable[T]:
#      91     kwargs = self.handle_kwargs(kwargs)
# ---> 93     return self.create_fn(
#      94         response_model=response_model,
#      95         messages=messages,
#      96         max_retries=max_retries,
#      97         validation_context=validation_context,
#      98         strict=strict,
#      99         **kwargs,
#     100     )
#
# File c:\Users\pdoub\opinionated-rag\.venv\lib\site-packages\instructor\patch.py:149, in patch.<locals>.new_create_sync(response_model, validation_context, max_retries, strict, *args, **kwargs)
#     137 @wraps(func)
#     138 def new_create_sync(
#     139     response_model: type[T_Model] = None,
#    (...)
#     144     **kwargs: T_ParamSpec.kwargs,
#     145 ) -> T_Model:
#     146     response_model, new_kwargs = handle_response_model(
#     147         response_model=response_model, mode=mode, **kwargs
#     148     )
# --> 149     response = retry_sync(
#     150         func=func,
#     151         response_model=response_model,
#     152         validation_context=validation_context,
#     153         max_retries=max_retries,
#     154         args=args,
#     155         strict=strict,
#     156         kwargs=new_kwargs,
#     157         mode=mode,
#     158     )
#     159     return response
#
# File c:\Users\pdoub\opinionated-rag\.venv\lib\site-packages\instructor\retry.py:160, in retry_sync(func, response_model, validation_context, args, kwargs, max_retries, strict, mode)
#     157     raise ValueError("max_retries must be an int or a `tenacity.Retrying` object")
#     159 try:
# --> 160     for attempt in max_retries:
#     161         with attempt:
#     162             try:
#
# File c:\Users\pdoub\opinionated-rag\.venv\lib\site-packages\tenacity\__init__.py:435, in BaseRetrying.__iter__(self)
#     433 retry_state = RetryCallState(self, fn=None, args=(), kwargs={})
#     434 while True:
# --> 435     do = self.iter(retry_state=retry_state)
#     436     if isinstance(do, DoAttempt):
#     437         yield AttemptManager(retry_state=retry_state)
#
# File c:\Users\pdoub\opinionated-rag\.venv\lib\site-packages\tenacity\__init__.py:368, in BaseRetrying.iter(self, retry_state)
#     366 result = None
#     367 for action in self.iter_state.actions:
# --> 368     result = action(retry_state)
#     369 return result
#
# File c:\Users\pdoub\opinionated-rag\.venv\lib\site-packages\tenacity\__init__.py:410, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     408 retry_exc = self.retry_error_cls(fut)
#     409 if self.reraise:
# --> 410     raise retry_exc.reraise()
#     411 raise retry_exc from fut.exception()
#
# File c:\Users\pdoub\opinionated-rag\.venv\lib\site-packages\tenacity\__init__.py:183, in RetryError.reraise(self)
#     181 def reraise(self) -> t.NoReturn:
#     182     if self.last_attempt.failed:
# --> 183         raise self.last_attempt.result()
#     184     raise self
#
# File ~\.pyenv\pyenv-win\versions\3.10.11\lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\.pyenv\pyenv-win\versions\3.10.11\lib\concurrent\futures\_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File c:\Users\pdoub\opinionated-rag\.venv\lib\site-packages\instructor\retry.py:184, in retry_sync(func, response_model, validation_context, args, kwargs, max_retries, strict, mode)
#     180                 if mode in {Mode.ANTHROPIC_TOOLS, Mode.ANTHROPIC_JSON}:
#     181                     kwargs["messages"] = merge_consecutive_messages(
#     182                         kwargs["messages"]
#     183                     )
# --> 184                 raise InstructorRetryException(
#     185                     e,
#     186                     last_completion=response,
#     187                     n_attempts=attempt.retry_state.attempt_number,
#     188                     messages=kwargs.get("messages", kwargs.get("contents")),
#     189                     total_usage=total_usage,
#     190                 ) from e
#     191 except RetryError as e:
#     192     raise InstructorRetryException(
#     193         e,
#     194         last_completion=response,
#    (...)
#     197         total_usage=total_usage,
#     198     ) from e
#
# InstructorRetryException: 5 validation errors for Response
# content.4.relation.type
#   Input should be 'OVERSEER_OF', 'RESPONSIBLE_FOR', 'PROVIDES_GUIDANCE_ON', 'CONDUCTS', 'SUPPORTS', 'REGULATES' or 'REVIEWS' [type=literal_error, input_value='DOES_NOT_HANDLE', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/literal_error
# content.12.relation.type
#   Input should be 'OVERSEER_OF', 'RESPONSIBLE_FOR', 'PROVIDES_GUIDANCE_ON', 'CONDUCTS', 'SUPPORTS', 'REGULATES' or 'REVIEWS' [type=literal_error, input_value='ENSURES', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/literal_error
# content.18.relation.type
#   Input should be 'OVERSEER_OF', 'RESPONSIBLE_FOR', 'PROVIDES_GUIDANCE_ON', 'CONDUCTS', 'SUPPORTS', 'REGULATES' or 'REVIEWS' [type=literal_error, input_value='RECOVERS', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/literal_error
# content.23.relation.type
#   Input should be 'OVERSEER_OF', 'RESPONSIBLE_FOR', 'PROVIDES_GUIDANCE_ON', 'CONDUCTS', 'SUPPORTS', 'REGULATES' or 'REVIEWS' [type=literal_error, input_value='COLLABORATES_WITH', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/literal_error
# content.35.relation.type
#   Input should be 'OVERSEER_OF', 'RESPONSIBLE_FOR', 'PROVIDES_GUIDANCE_ON', 'CONDUCTS', 'SUPPORTS', 'REGULATES' or 'REVIEWS' [type=literal_error, input_value=' COLLABORATES_WITH', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.7/v/literal_error

# %%
from typing import List
from openai import OpenAI
import instructor
from pydantic import BaseModel, Field

client = instructor.from_openai(OpenAI())
model = "gpt-4o"


class Node(BaseModel):
    label: str
    name: str


class Edge(BaseModel):
    node_1: Node
    node_2: Node
    relationship: str
    

class KnowledgeGraph(BaseModel):
    edges: List[Edge] = Field(..., default_factory=list)
    
    @property
    def to_pandas(self):
        kg_dict = {
            "node_1": [n.node_1.name for n in self.edges],
            "node_2": [n.node_2.name for n in self.edges],
            "edge": [n.relationship for n in self.edges],
            "node_1_type": [n.node_1.label for n in self.edges],
            "node_2_type": [n.node_2.label for n in self.edges],
        }
        return pd.DataFrame(kg_dict)


def user_message(text: str) -> str:
    return f"input text: ```\n{text}\n```"

def system_message(ontology: Ontology) -> str:
    return (
        "You are an expert at creating Knowledge Graphs. "
        "Consider the following ontology. \n"
        f"{ontology} \n"
        "The user will provide you with an input text delimited by ```. "
        "Extract all the entities and relationships from the user-provided text as per the given ontology. Do not use any previous knowledge about the context."
        "Remember there can be multiple direct (explicit) or implied relationships between the same pair of nodes. "
        "Be consistent with the given ontology. Use ONLY the labels and relationships mentioned in the ontology. "
        "Remember to follow the correct format, for example:\n"
        "[\n"
        "   {\n"
        '       node_1: Required, an entity object with attributes: {"label": "as per the ontology", "name": "Name of the entity"},\n'
        '       node_2: Required, an entity object with attributes: {"label": "as per the ontology", "name": "Name of the entity"},\n'
        "       relationship: Describe the relationship between node_1 and node_2 as per the context, in one or two sentences.\n"
        "   },\n"
        "]\n"
    )


def generate_graph(text: str, ontology: Ontology, model: str) -> str:
    return client.chat.completions.create(
        model=model,
        max_retries=3,
        messages=[
            {
                "role": "system",
                "content": system_message(ontology),
            },
            {
                "role": "user",
                "content": user_message(text=text),
            },
        ],
        response_model=KnowledgeGraph,
    )

# %%
# df.head(1)
# Out:
#        id        citation                                               name  \
# 0  411690  154 Ill. 2d 90  RICHARD R. JOHNSON, Plaintiff-Appellant and Cr...
#
#      name_abbreviation decision_date  court_id                court_name  \
# 0  Johnson v. Halloran    2000-01-13      8837  Illinois Appellate Court
#
#    court_slug judges                                          attorneys  \
# 0  ill-app-ct     []  ['Wolter, Beeman, Lynch & McIntyre, of Springf...
#
#                                            citations  \
# 0  [{'type': 'official', 'cite': '312 Ill. App. 3...
#
#                                      url  \
# 0  https://api.case.law/v1/cases/411690/
#
#                                                 head  \
# 0  RICHARD R. JOHNSON, Plaintiff-Appellant and Cr...
#
#                                                 body  name_contains_lm  \
# 0  JUSTICE HALL\r\ndelivered the opinion of the c...             False
#
#    body_contains_lm  year                                            context  \
# 0              True  2000  The public defender of Cook County was appoint...
#
#   context_citation  context_tokens
# 0   154 Ill. 2d 90            1317

# %%
sample_test = df.sample(1)
text_column = 'body'

splitter = RecursiveCharacterTextSplitter(
    chunk_size=10000,
    chunk_overlap=0,
    length_function=len,
    is_separator_regex=False,
)

def dataframe2Documents(df: pd.DataFrame, text_column: str):
    loader = DataFrameLoader(df, page_content_column=text_column)
    return loader.load()

documents = dataframe2Documents(sample_test, text_column)
docs = splitter.split_documents(documents)
len(docs)
# Out:
# 4

# %%
Markdown(docs[1].page_content)
# Out:
# In Illinois, an insurer’s duty to defend is determined by comparing the allegations in the underlying complaint to the relevant provisions of the insurance policy. Outboard Marine, 154 Ill. 2d at 107-08, 607 N.E.2d at 1212. If the allegations in the underlying complaint fall within or even potentially within the policy’s coverage, the insurer’s duty to defend arises. See, e.g., Cincinnati Cos., 183 Ill. 2d at 323, 701 N.E.2d at 502; Outboard Marine, 154 Ill. 2d at 125, 607 N.E.2d at 1212. Thus, in determining whether a duty to defend has arisen it is the potentiality of coverage that matters. See, e.g., Aetna Casualty & Surety Co. v. Prestige Casualty Co., 195 Ill. App. 3d 660, 664, 553 N.E.2d 39, 41 (1990) (“Unless the complaint, on its face, clearly alleges facts which, if true, would exclude coverage, the potentiality of coverage is present and the insurer has a duty to defend”). The threshold that a complaint must satisfy to present a claim of potential coverage is low. Bituminous Casualty Corp. v. Gust K. Newberg Construction Co., 218 Ill. App. 3d 956, 960, 578 N.E.2d 1006 (1991). For potentiality of coverage to exist, the complaint need present only a possibility of recovery, not a probability of recovery. Bituminous Casualty Corp., 218 Ill. App. 3d at 960, 578 N.E.2d 1006.
# Our supreme court has repeatedly and consistently identified the two options available to an insurer that takes the position that a complaint potentially alleging coverage is not covered under its policy: the insurer may either “ ‘defend the suit under a reservation of rights or seek a declaratory judgment that there is no coverage.’ [Citation.]” (Emphasis added.) State Farm Fire & Casualty Co. v. Martin, 186 Ill. 2d 367, 373, 710 N.E.2d 1228, 1231 (1999). The course of action chosen by St. Paul, refusing to do either, has been referred to as a third option by one court. Maneikis v. St. Paul Insurance Co., 655 F.2d 818 (7th Cir. 1981) (noting that the insurer can refuse either to defend or to seek a declaratory judgment at the insurer’s peril that it might later be found to have breached its duty to defend).
# Thus, the threshold question in this appeal is whether St. Paul breached its duty to defend. An insurer’s duty to defend is much broader than its duty to indemnify. Crum & Forster Managers Corp. v. Resolution Trust Corp., 156 Ill. 2d 384, 393-94, 620 N.E.2d 1073 (1993). The determination of whether St. Paul breached its duty to defend turns not on whether the claim actually came within the policy (establishing the duty to indemnify) but, rather, on whether the 1990 claim was potentially within the scope of coverage. St. Paul has presented numerous arguments as to why it believes the claim here was not within the policy coverage. In so doing, St. Paul fails to adequately distinguish its duty to defend from its duty to indemnify La Grange. The distinction is important in this appeal. It has long been established that the consequence of an insurer’s breach of its duty to defend is that it is estopped from later raising any policy defenses based on non-coverage. See Sims v. Illinois National Casualty Co., 43 Ill. App. 2d 184, 193 N.E.2d 123 (1963).
# Clearly, with respect to the Mundy claim, there was a possibility that the St. Paul policy afforded coverage to La Grange; whether it actually did so was a matter for later investigation by St. Paul. See, e.g., Clemmons v. Travelers Insurance Co., 88 Ill. 2d 469, 476, 430 N.E.2d 1104, 1107 (1981). St. Paul offers no real argument, since there is none, that the 1990 claim did not potentially come within the scope of coverage. We conclude that St. Paul’s duty to defend La Grange in the underlying Mundy claim was established in 1990. St. Paul breached its duty to defend by failing to either seek a declaratory judgment that there was no coverage or defend the claim under a reservation of rights. Thus, since St. Paul breached its duty to defend, in the first instance, it is now estopped from asserting any defenses of noncoverage.
# St. Paul’s attempts to draw a distinction between a duty to defend RSMA and a duty to defend La Grange are unavailing. St. Paul wrote this policy to include protection not only to the named insured, but also to third-party beneficiaries, such as La Grange. By drafting this language, St. Paul acknowledged and accepted that its insured would be entering into contracts under which St. Paul would be obligated to provide a defense and a direct benefit to those parties, such as La Grange. St. Paul did not require that its insured get St. Paul’s approval of the contracts or require its insured to disclose the identities of the third parties or require that RSMA name those parties as additional insureds. St. Paul thus assumed the responsibility of providing defenses for certain unknown and unnamed third-party beneficiaries. Since La Grange falls under the definition of the description of the others protected under the agreement, it is a direct beneficiary and is entitled to enforce the terms of the insurance policy. See Altevogt v. Brinkoetter, 85 Ill. 2d 44, 55, 421 N.E.2d 182 (1981) (it is unnecessary that a contract for the benefit of a third-party beneficiary identify him by name; the contract may define the party benefitted by class description); American National Trust Co. v. Kentucky Fried Chicken of Southern California, Inc., 308 Ill. App. 3d 106, 120, 719 N.E.2d 201, 211 (1999) (same); Garcia v. Lovellette, 265 Ill. App. 3d 724, 732, 639 N.E.2d 935 (1994) (same). This principle is even more compelling here where we are dealing with a policy of insurance which is, in addition, strictly construed against the drafter. La Grange is covered by the St. Paul policy because it is a protected person pursuant to the language drafted by St. Paul.
# St. Paul, in bringing this appeal, continues to try to put forth its additional policy defense of late notice, contending that the 1990 notice was not adequate and that its duty to defend could not have been triggered until July 25, 1995, the date when St. Paul received notice of the claim directly from La Grange. Illinois law is clear that an insurer’s duty to defend is triggered by actual notice of a claim against the insured. Cincinnati Cos. v. West American Insurance Co., 183 Ill. 2d 317, 701 N.E.2d 499 (1998). An insurer has “actual notice” where it knows both “ ‘that a cause of action has been filed and that the complaint falls within or potentially within the scope of the coverage of one of its policies.’ [Citation.]” (Emphasis added.) Employers Insurance v. Ehlco Liquidating Trust, 186 Ill. 2d 127, 143, 708 N.E.2d 1122, 1131 (1999). “Actual notice” exists where the insurer receives notice “from any source sufficient to permit the insurer to locate and defend its insured.” (Emphasis added.) Insurance Co. v. Federal Kemper Insurance Co., 291 Ill. App. 3d 384, 388, 683 N.E.2d 947 (1997). As we previously explained, on March 27, 1990, RSMA provided notice to St. Paul that La Grange demanded indemnification for Mundy’s claim. This notice included a copy of the letter from La Grange, along with the contracts under which La Grange was claiming RSMA was responsible for Mundy’s claim. The documents sent to St. Paul were listed in a letter that accompanied the documents. On or about April 5, 1990, St. Paul confirmed receipt of this notice. That it was RSMA which provided notice at that time, not La Grange, is irrelevant. The date that La Grange first notified St. Paul is not the issue; what is critical is when St. Paul had actual notice. The trial court concluded, and we agree, that St. Paul had actual notice of this claim in 1990.
# Nonetheless, St. Paul asserts in its brief as follows:
# “At best, the 1990 notice informed St. Paul that Hilke Mundy, a La Grange employee, had brought a workers’ compensation claim against her employer, and that La Grange wanted RSMA to pay. The 1990 notice did not inform St. Paul that La Grange or RSMA had a contract between them requiring RSMA to make La Grange an insured under the St. Paul Umbrella Excess Liability policy. The 1990 notice did not inform St. Paul that La Grange did not have underlying Workers’ Compensation insurance.” (Emphasis added.)
# The “pieces of information” purportedly lacking from RSMA’s notice are not pertinent. RSMA had no duty to include such information in its notice. St. Paul’s contention that the 1990 notice did not provide St. Paul with actual notice of its purported obligations is specious.
# Because St. Paul destroyed the policy, the record does not contain the policy’s notice provision. Nonetheless, St. Paul has produced specimens of all of the alternative notice provisions that might have been in effect. First, none of the notice provisions can be interpreted as requiring RSMA to “inform St. Paul that La Grange or RSMA had a contract between them requiring RSMA to make La Grange an insured under the St. Paul Umbrella Excess Liability policy.” Second, none of the notice provisions can be interpreted as requiring RSMA to “inform St. Paul that La Grange did not have underlying Workers’ Compensation insurance.” In fact, St. Paul’s assertion of some requirement that RSMA make La Grange an insured is nothing more than an attempt, after the fact, to inject into the policy St. Paul’s meritless argument that only those that RSMA named as an insured were protected under the policy. RSMA did inform St. Paul that it had a contract with La Grange and provided a copy of the contract, which, when read together with the St. Paul policy, showed that La Grange was a protected entity and showed undeniably that Mundy’s claim was at least potentially within the policy’s coverage. Moreover, notice by an insured to its insurance company is sufficient to charge the insurer on all policies running in the insured’s favor. Casualty Insurance Co. v. E.W. Corrigan Construction Co., 247 Ill. App. 3d 326, 332-33, 617 N.E.2d 228, 233-34 (1993).

# %%
def documents2Dataframe(documents) -> pd.DataFrame:
    rows = []
    for chunk in documents:
        row = {
            "text": chunk.page_content,
            **chunk.metadata,
            "chunk_id": uuid.uuid4().hex,
        }
        rows = rows + [row]
    df = pd.DataFrame(rows)
    return df

# %%
df = documents2Dataframe(docs)
print(df.shape)
df.head(2)
# Out:
# (4, 21)
#                                                 text       id  \
# 0  JUSTICE GALLAGHER\r\ndelivered the opinion of ...  1025915
# 1  In Illinois, an insurer’s duty to defend is de...  1025915
#
#           citation                                               name  \
# 0  183 Ill. 2d 317  LA GRANGE MEMORIAL HOSPITAL, Plaintiff-Appelle...
# 1  183 Ill. 2d 317  LA GRANGE MEMORIAL HOSPITAL, Plaintiff-Appelle...
#
#                                    name_abbreviation decision_date  court_id  \
# 0  La Grange Memorial Hospital v. St. Paul Insurance    2000-11-09      8837
# 1  La Grange Memorial Hospital v. St. Paul Insurance    2000-11-09      8837
#
#                  court_name  court_slug judges  \
# 0  Illinois Appellate Court  ill-app-ct     []
# 1  Illinois Appellate Court  ill-app-ct     []
#
#                                            attorneys  \
# 0  ['Piper Marbury Rudnick & Wolfe, of Chicago (K...
# 1  ['Piper Marbury Rudnick & Wolfe, of Chicago (K...
#
#                                            citations  \
# 0  [{'type': 'official', 'cite': '317 Ill. App. 3...
# 1  [{'type': 'official', 'cite': '317 Ill. App. 3...
#
#                                       url  \
# 0  https://api.case.law/v1/cases/1025915/
# 1  https://api.case.law/v1/cases/1025915/
#
#                                                 head  name_contains_lm  \
# 0  LA GRANGE MEMORIAL HOSPITAL, Plaintiff-Appelle...             False
# 1  LA GRANGE MEMORIAL HOSPITAL, Plaintiff-Appelle...             False
#
#    body_contains_lm  year                                            context  \
# 0              True  2000  At the time, RSMA had a workers’ compensation ...
# 1              True  2000  At the time, RSMA had a workers’ compensation ...
#
#   context_citation  context_tokens                          chunk_id
# 0  183 Ill. 2d 317            1546  e4ea5975aaca4e378931a802b8269818
# 1  183 Ill. 2d 317            1546  45f9bd628cd644f09af527819547c567

# %%
def df2Ontology(theme: str, df:pd.DataFrame, model: str ="gpt-4o") -> pd.DataFrame:
    progress_bar = tqdm(total=len(df), desc="Processing chunks")

    def apply_ontologyPrompt(row):
        result = generate_ontology(theme=theme, text=row.text, model=model)
        result_df = result.to_pandas
        result_df["chunk_id"] = row.chunk_id
        progress_bar.update(1)
        return result_df
    
    results = df.apply(apply_ontologyPrompt, axis=1)
    results_df = pd.concat(results.tolist(), ignore_index=True)
    progress_bar.close()
    
    return results_df

# %%
test = df2Ontology(
    theme="Insurance Coverage",
    df=df)
# Out:
# Processing chunks: 100%|██████████| 4/4 [00:13<00:00,  3.42s/it]

# %%
Markdown(test.to_markdown())
# Out:
# |    | category                | description                                                                                                                                | chunk_id                         |
# |---:|:------------------------|:-------------------------------------------------------------------------------------------------------------------------------------------|:---------------------------------|
# |  0 | Person                  | A person referenced in the context.                                                                                                        | e4ea5975aaca4e378931a802b8269818 |
# |  1 | Organization            | An organization or entity that is referenced in the context.                                                                               | e4ea5975aaca4e378931a802b8269818 |
# |  2 | Legal Document          | A formal document referenced in the context, including contracts, policies, or other written agreements.                                   | e4ea5975aaca4e378931a802b8269818 |
# |  3 | Insurance Policy        | A specific insurance policy mentioned in the context.                                                                                      | e4ea5975aaca4e378931a802b8269818 |
# |  4 | Insurance Claim         | A specific insurance claim mentioned in the context.                                                                                       | e4ea5975aaca4e378931a802b8269818 |
# |  5 | Judicial Action         | A legal action, ruling or proceeding referenced in the context.                                                                            | e4ea5975aaca4e378931a802b8269818 |
# |  6 | Law or Statute          | A specific law, act, or statute referenced in the text.                                                                                    | e4ea5975aaca4e378931a802b8269818 |
# |  7 | Insurer                 | An insurance company referenced in the context.                                                                                            | 45f9bd628cd644f09af527819547c567 |
# |  8 | Insurance Coverage      | A specific line of insurance coverage mentioned in the context.                                                                            | 45f9bd628cd644f09af527819547c567 |
# |  9 | Duty to Defend          | An insurer's obligation to provide legal defense when a claim is made that potentially falls within the policy's coverage.                 | 45f9bd628cd644f09af527819547c567 |
# | 10 | Duty to Indemnify       | An insurer's obligation to cover the costs or damages incurred by the insured if the claim falls within the policy's coverage.             | 45f9bd628cd644f09af527819547c567 |
# | 11 | Declaratory Judgment    | A court judgment that determines the rights of parties without ordering any specific action or awarding damages.                           | 45f9bd628cd644f09af527819547c567 |
# | 12 | Policy Defense          | Arguments or reasons presented by the insurer to deny coverage.                                                                            | 45f9bd628cd644f09af527819547c567 |
# | 13 | Third-party Beneficiary | A party that can benefit from a contract or policy even though they are not the primary insured or policyholder.                           | 45f9bd628cd644f09af527819547c567 |
# | 14 | Actual Notice           | The condition where the insurer is made aware of a claim that falls or potentially falls within the policy’s coverage.                     | 45f9bd628cd644f09af527819547c567 |
# | 15 | Reservation of Rights   | A declaration made by an insurer to defend a policyholder in a legal action while reserving the right to contest coverage at a later date. | 45f9bd628cd644f09af527819547c567 |
# | 16 | Noncoverage             | Situations or claims that are not covered under the insurance policy.                                                                      | 45f9bd628cd644f09af527819547c567 |
# | 17 | Case Law                | Specific legal cases cited in the context to support arguments or establish precedents.                                                    | 45f9bd628cd644f09af527819547c567 |
# | 18 | Insurance Company       | A company that offers insurance policies to the public.                                                                                    | e49f8433ccec41c7ae0acbbeceadbe5b |
# | 19 | Legal Doctrine          | Established principles of law that are authoritative in determining legal outcomes.                                                        | e49f8433ccec41c7ae0acbbeceadbe5b |
# | 20 | Legal Action            | Formal proceedings carried out in a court of law.                                                                                          | e49f8433ccec41c7ae0acbbeceadbe5b |
# | 21 | Court Ruling            | A decision made by a judge or a court that resolves a legal issue.                                                                         | e49f8433ccec41c7ae0acbbeceadbe5b |
# | 22 | Policy Defense          | Arguments or claims made by an insurance company to avoid paying a claim.                                                                  | e49f8433ccec41c7ae0acbbeceadbe5b |
# | 23 | Legal Case              | A dispute between parties that is resolved in a court of law.                                                                              | e49f8433ccec41c7ae0acbbeceadbe5b |
# | 24 | Reservation of Rights   | A statement by an insurer specifying that they may not cover a claim and that they reserve the right to assert any defenses later.         | e49f8433ccec41c7ae0acbbeceadbe5b |
# | 25 | Declaratory Judgment    | A judgment from a court that determines the rights of parties without ordering any specific action or awarding damages.                    | e49f8433ccec41c7ae0acbbeceadbe5b |
# | 26 | Penalties and Sanctions | Punitive measures or fines imposed by a court.                                                                                             | e49f8433ccec41c7ae0acbbeceadbe5b |
# | 27 | Interest and Damages    | Financial compensation awarded to a party for loss or injury.                                                                              | e49f8433ccec41c7ae0acbbeceadbe5b |
# | 28 | Statute or Rule         | A written law passed by a legislative body or a formal regulation.                                                                         | e49f8433ccec41c7ae0acbbeceadbe5b |
# | 29 | Insurance Coverage      | The amount and type of protection provided by an insurance policy.                                                                         | e49f8433ccec41c7ae0acbbeceadbe5b |
# | 30 | Case Law                | Specific cases mentioned in the context.                                                                                                   | dc432f8b98344f9fa73a9b78b770aa61 |
# | 31 | Legal Rule              | Legal rules or statutes referenced in the context.                                                                                         | dc432f8b98344f9fa73a9b78b770aa61 |
# | 32 | Insurance Company       | Insurance companies mentioned in the context.                                                                                              | dc432f8b98344f9fa73a9b78b770aa61 |
# | 33 | Judicial Outcome        | Descriptions of judgments, affirmations, or dismissals.                                                                                    | dc432f8b98344f9fa73a9b78b770aa61 |
# | 34 | Sanction                | Penalties or orders issued by the court.                                                                                                   | dc432f8b98344f9fa73a9b78b770aa61 |
# | 35 | Legal Concept           | Legal principles or doctrines referenced in the context.                                                                                   | dc432f8b98344f9fa73a9b78b770aa61 |

# %%
client = instructor.from_openai(OpenAI())

def user_message(theme: str, text: str) -> str:
    return f"While focusing on the theme **{theme}**, generate an ontology for the following input text: ```\n{text}\n```"

def system_message() -> str:
    return (
        "You are an expert at creating an ontology for a given theme or topic. "
        "Users will provide you with a **theme** and an input text delimited by ```. "
        "Extract all the entity types from the input text relevant to the **theme**. "
        "The goal is to create an ontology to use for downstream knowledge graph construction for the **theme**."
    )


def generate_ontology(theme: str, text: str) -> str:
    return client.chat.completions.create(
        model="gpt-4o",
        max_retries=3,
        messages=[
            {
                "role": "system",
                "content": system_message(),
            },
            {
                "role": "user",
                "content": user_message(theme=theme, text=text),
            },
        ],
        response_model=Ontology,
    )

# %%
text_sample = df['text'].tolist()[0]

# %%
extracted_ontology = generate_ontology(
    theme="Insurance Coverage",
    text=text_sample,
)

# %%
extracted_ontology.to_pandas
# Out:
#            category                                        description
# 0            Person  An individual involved in the context of the i...
# 1      Organization  A company, hospital, insurance firm or other e...
# 2  Insurance Policy  A specific insurance coverage or policy mentio...
# 3    Legal Document  Legal documents such as contracts, agreements,...
# 4               Law  Statutes, codes, or regulations relevant to th...
# 5             Event  Incidents or occurrences relevant to the insur...
# 6    Court Decision  Specific court rulings or judicial findings re...
# 7        Legal Term  Specific legal terms or concepts relevant to t...
# 8             Claim    Specific claims made under an insurance policy.

# %%
from typing import List
from openai import OpenAI
import instructor
from pydantic import BaseModel, Field

client = instructor.from_openai(OpenAI())
model = "gpt-3.5-turbo"


class Node(BaseModel):
    label: str
    name: str


class Edge(BaseModel):
    node_1: Node
    node_2: Node
    relationship: str
    

class KnowledgeGraph(BaseModel):
    edges: List[Edge] = Field(..., default_factory=list)
    
    @property
    def to_pandas(self):
        kg_dict = {
            "node_1": [n.node_1.name for n in self.edges],
            "node_2": [n.node_2.name for n in self.edges],
            "edge": [n.relationship for n in self.edges],
            "node_1_type": [n.node_1.label for n in self.edges],
            "node_2_type": [n.node_2.label for n in self.edges],
        }
        return pd.DataFrame(kg_dict)


def user_message(text: str) -> str:
    return f"input text: ```\n{text}\n```"

def system_message(ontology: Ontology) -> str:
    return (
        "You are an expert at creating Knowledge Graphs. "
        "Consider the following ontology. \n"
        f"{ontology} \n"
        "The user will provide you with an input text delimited by ```. "
        "Extract all the entities and relationships from the user-provided text as per the given ontology. Do not use any previous knowledge about the context."
        "Remember there can be multiple direct (explicit) or implied relationships between the same pair of nodes. "
        "Be consistent with the given ontology. Use ONLY the labels and relationships mentioned in the ontology. "
        "Remember to follow the correct format, for example:\n"
        "[\n"
        "   {\n"
        '       node_1: Required, an entity object with attributes: {"label": "as per the ontology", "name": "Name of the entity"},\n'
        '       node_2: Required, an entity object with attributes: {"label": "as per the ontology", "name": "Name of the entity"},\n'
        "       relationship: Describe the relationship between node_1 and node_2 as per the context, in one or two sentences.\n"
        "   },\n"
        "]\n"
    )


def generate_graph(text: str, ontology: Ontology, model: str) -> str:
    return client.chat.completions.create(
        model=model,
        max_retries=3,
        messages=[
            {
                "role": "system",
                "content": system_message(ontology),
            },
            {
                "role": "user",
                "content": user_message(text=text),
            },
        ],
        response_model=KnowledgeGraph,
    )

# %%
def df2Graph(df, ontology, model="gpt-4o") -> pd.DataFrame:
    progress_bar = tqdm(total=len(df), desc="Processing chunks")

    def apply_graphPrompt(row):
        result = generate_graph(row.text, ontology, model)
        result_df = result.to_pandas
        result_df["chunk_id"] = row.chunk_id
        progress_bar.update(1)
        return result_df
    
    results = df.apply(apply_graphPrompt, axis=1)
    results_df = pd.concat(results.tolist(), ignore_index=True)
    progress_bar.close()
    
    return results_df

# %%
dfg = df2Graph(df, extracted_ontology)
# Out:
# Processing chunks: 100%|██████████| 4/4 [01:32<00:00, 23.21s/it]

# %%
print(dfg.shape)
dfg.head()
# Out:
# (90, 6)
#                                    node_1                       node_2  \
# 0                       JUSTICE GALLAGHER                      Opinion
# 1             La Grange Memorial Hospital   St. Paul Insurance Company
# 2                             Hilke Mundy  La Grange Memorial Hospital
# 3             La Grange Memorial Hospital   St. Paul Insurance Company
# 4  Rehabilitation Services of Mid-America   St. Paul Insurance Company
#
#                                                 edge   node_1_type  \
# 0  JUSTICE GALLAGHER delivered the opinion of the...        Person
# 1  Involved in an insurance coverage dispute aris...  Organization
# 2  Hilke Mundy brought a workers’ compensation cl...        Person
# 3  La Grange contended that St. Paul had a duty t...  Organization
# 4  St. Paul issued an umbrella excess insurance p...  Organization
#
#       node_2_type                          chunk_id
# 0  Court Decision  e4ea5975aaca4e378931a802b8269818
# 1    Organization  e4ea5975aaca4e378931a802b8269818
# 2    Organization  e4ea5975aaca4e378931a802b8269818
# 3    Organization  e4ea5975aaca4e378931a802b8269818
# 4    Organization  e4ea5975aaca4e378931a802b8269818

# %%
dfg['node_1'].nunique(), dfg['node_2'].nunique()
# Out:
# (54, 48)

# %%
nodes = pd.concat(
    [dfg["node_1"], dfg["node_2"]], axis=0
).unique()

len(nodes)
# Out:
# 87

# %%
import networkx as nx

G = nx.Graph()

for node in nodes:
    G.add_node(str(node))
# Add edges to the graph
for _, row in dfg.iterrows():
    G.add_edge(
        str(row["node_1"]),
        str(row["node_2"]),
        title=row["edge"],
        chunk_id=row["chunk_id"],
    )

# %%
from cdlib import algorithms

def detect_communities(graph):
    communities = []
    index = 0
    for component in nx.connected_components(graph):
        print(
            f"Component index {index} of {len(list(nx.connected_components(graph)))}:")
        subgraph = graph.subgraph(component)
        if len(subgraph.nodes) > 1:  # Leiden algorithm requires at least 2 nodes
            try:
                sub_communities = algorithms.leiden(subgraph)
                for community in sub_communities.communities:
                    communities.append(list(community))
            except Exception as e:
                print(f"Error processing community {index}: {e}")
        else:
            communities.append(list(subgraph.nodes))
        index += 1
    print("Communities from detect_communities:", communities)
    return communities

# %%
test = detect_communities(G)
# Out:
# Component index 0 of 11:
# Error processing community 0: invalid literal for int() with base 10: 'JUSTICE GALLAGHER'
# Component index 1 of 11:
# Component index 2 of 11:
# Error processing community 2: invalid literal for int() with base 10: 'underlying complaint'
# Component index 3 of 11:
# Error processing community 3: invalid literal for int() with base 10: 'State Farm Fire & Casualty Co.'
# Component index 4 of 11:
# Error processing community 4: invalid literal for int() with base 10: 'American National Trust Co. v. Kentucky Fried Chicken of Southern California, Inc., 308 Ill. App. 3d 106, 120, 719 N.E.2d 201, 211 (1999)'
# Component index 5 of 11:
# Error processing community 5: invalid literal for int() with base 10: 'Federal Kemper Insurance Co.'
# Component index 6 of 11:
# Error processing community 6: invalid literal for int() with base 10: 'Casualty Insurance Co. v. E.W. Corrigan Construction Co., 247 Ill. App. 3d 326, 332-33, 617 N.E.2d 228, 233-34 (1993)'
# Component index 7 of 11:
# Error processing community 7: invalid literal for int() with base 10: 'Maneikis v. St. Paul Insurance Co.'
# Component index 8 of 11:
# Error processing community 8: invalid literal for int() with base 10: 'Award of penalties'
# Component index 9 of 11:
# Error processing community 9: invalid literal for int() with base 10: 'St. Paul citing overruled cases'
# Component index 10 of 11:
# Error processing community 10: invalid literal for int() with base 10: 'St. Paul’s breach of duty to defend in 1995'
# Communities from detect_communities: [['La Grange Memorial Hospital', 'Rehabilitation Services of Mid-America', 'Court Decision', 'Illinois Insurance Code', 'Illinois Interest Act', 'Appeal', 'St. Paul policy', "Hilke Mundy's claim", 'Dispute', 'Claim for indemnification', 'Summary judgment', 'Jurisdiction', 'Clemmons v. Travelers Insurance Co., 88 Ill. 2d 469, 476, 430 N.E.2d 1104, 1107 (1981)', 'St. Paul Insurance Company'], ['St. Paul', 'insurance policy', 'Crum & Forster Managers Corp. v. Resolution Trust Corp., 156 Ill. 2d 384, 393-94, 620 N.E.2d 1073 (1993)', 'Sims v. Illinois National Casualty Co., 43 Ill. App. 2d 184, 193 N.E.2d 123 (1963)', 'breach duty to defend', 'duty to defend RSMA versus La Grange', '1990 notice', 'duty to defend', 'late notice defense', 'Illinois Supreme Court Rule 341(a)', 'appeal', 'destruction of policy', 'equitable estoppel', 'persuasion attempt'], ['Mundy', 'RSMA', 'contracts', 'La Grange', '2015 notice', 'Illinois Interest Act, Section 2', 'Illinois Supreme Court Rule 375(b)', '1990 claim', 'St. Paul Policy', 'Sanctions for frivolous appeal', 'La Grange’s filing of declaratory judgment action', 'sanctions against St. Paul'], ['Hilke Mundy', "Workers' compensation claim", 'St. Paul Insurance Co.', 'Illinois Supreme Court Rule 341(g)', 'Industrial Coatings Group, Inc. v. American Motorists Insurance Co.', 'Injury', 'Mundy’s claim', 'Received notice of claim on July 25, 1995', 'Breach of duty to defend', 'Received actual notice of the claim in 1990'], ['Illinois Supreme Court Rule 342(a)', 'Collier', 'appellant’s brief', 'Avis Rent A Car System, Inc.'], ['Cincinnati Cos. v. West American Insurance Co., 183 Ill. 2d 317, 701 N.E.2d 499 (1998)', 'actual notice', 'Employers Insurance v. Ehlco Liquidating Trust, 186 Ill. 2d 127, 143, 708 N.E.2d 1122, 1131 (1999)', 'Insurance Co. v. Federal Kemper Insurance Co., 291 Ill. App. 3d 384, 388, 683 N.E.2d 947 (1997)']]

# %%
len(test)
# Out:
# 6

# %%
def detect_communities(G):
    communities_generator = nx.community.girvan_newman(G)
    next_level_communities = next(communities_generator)
    communities = sorted(map(sorted, next_level_communities))
    return communities

# %%
communities = detect_communities(G)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 communities = detect_communities(G)
#
# Cell In[85], line 3, in detect_communities(G)
#       1 def detect_communities(G):
#       2     communities_generator = nx.community.kclique.k_clique_communities(G, k=10)
# ----> 3     next_level_communities = next(communities_generator)
#       4     communities = sorted(map(sorted, next_level_communities))
#       5     return communities
#
# StopIteration:

# %%
len(communities)
# Out:
# 26

# %%
communities
# Out:
# [['1990 claim', 'Mundy', 'RSMA', 'contracts'],
#  ['1990 notice',
#   'Illinois Supreme Court Rule 341(a)',
#   'St. Paul',
#   'appeal',
#   'destruction of policy',
#   'duty to defend RSMA versus La Grange',
#   'equitable estoppel',
#   'insurance policy',
#   'late notice defense',
#   'persuasion attempt'],
#  ['2015 notice',
#   'Illinois Interest Act, Section 2',
#   'La Grange',
#   'La Grange’s filing of declaratory judgment action',
#   'St. Paul Policy',
#   'sanctions against St. Paul'],
#  ['Altevogt v. Brinkoetter, 85 Ill. 2d 44, 55, 421 N.E.2d 182 (1981)',
#   'American National Trust Co. v. Kentucky Fried Chicken of Southern California, Inc., 308 Ill. App. 3d 106, 120, 719 N.E.2d 201, 211 (1999)',
#   'Garcia v. Lovellette, 265 Ill. App. 3d 724, 732, 639 N.E.2d 935 (1994)',
#   'third-party beneficiary'],
#  ['Appeal', 'Jurisdiction'],
#  ['Avis Rent A Car System, Inc.', 'Collier'],
#  ['Award of penalties', 'Section 155'],
#  ['Breach of duty to defend',
#   'Illinois Supreme Court Rule 341(g)',
#   'Industrial Coatings Group, Inc. v. American Motorists Insurance Co.',
#   'Received actual notice of the claim in 1990',
#   'Received notice of claim on July 25, 1995',
#   'St. Paul Insurance Co.'],
#  ['Casualty Insurance Co. v. E.W. Corrigan Construction Co., 247 Ill. App. 3d 326, 332-33, 617 N.E.2d 228, 233-34 (1993)',
#   'notice by an insured'],
#  ['Cincinnati Cos. v. West American Insurance Co.',
#   'St. Paul citing overruled cases'],
#  ['Cincinnati Cos. v. West American Insurance Co., 183 Ill. 2d 317, 701 N.E.2d 499 (1998)',
#   'Employers Insurance v. Ehlco Liquidating Trust, 186 Ill. 2d 127, 143, 708 N.E.2d 1122, 1131 (1999)',
#   'Insurance Co. v. Federal Kemper Insurance Co., 291 Ill. App. 3d 384, 388, 683 N.E.2d 947 (1997)',
#   'actual notice'],
#  ['Cincinnati Cos., 183 Ill. 2d at 323, 701 N.E.2d at 502',
#   'Illinois',
#   "Insurer's duty to defend",
#   'Outboard Marine, 154 Ill. 2d at 107-08, 607 N.E.2d at 1212',
#   'relevant provisions of the insurance policy',
#   'underlying complaint'],
#  ['Claim for indemnification',
#   "Hilke Mundy's claim",
#   'La Grange Memorial Hospital'],
#  ['Clemmons v. Travelers Insurance Co., 88 Ill. 2d 469, 476, 430 N.E.2d 1104, 1107 (1981)',
#   'Dispute',
#   'Rehabilitation Services of Mid-America',
#   'St. Paul policy'],
#  ['Court Decision',
#   'Illinois Insurance Code',
#   'Illinois Interest Act',
#   'St. Paul Insurance Company',
#   'Summary judgment'],
#  ['Crum & Forster Managers Corp. v. Resolution Trust Corp., 156 Ill. 2d 384, 393-94, 620 N.E.2d 1073 (1993)',
#   'duty to defend'],
#  ['Employers Insurance', 'supreme court'],
#  ['Employers Insurance v. Ehlco Liquidating Trust',
#   'Maneikis v. St. Paul Insurance Co.',
#   'St. Paul’s duty to defend was triggered'],
#  ['Federal Kemper Insurance Co.', 'Insurance Co.'],
#  ['Hilke Mundy', 'Injury', 'Mundy’s claim', "Workers' compensation claim"],
#  ['Illinois Supreme Court Rule 342(a)', 'appellant’s brief'],
#  ['Illinois Supreme Court Rule 375(b)', 'Sanctions for frivolous appeal'],
#  ['JUSTICE GALLAGHER', 'Opinion'],
#  ['Martin', 'State Farm Fire & Casualty Co.'],
#  ['Sims v. Illinois National Casualty Co., 43 Ill. App. 2d 184, 193 N.E.2d 123 (1963)',
#   'breach duty to defend'],
#  ['St. Paul’s breach of duty to defend in 1990',
#   'St. Paul’s breach of duty to defend in 1995']]

# %%
for index, community in enumerate(communities):
    print(f"Summarize Community index {index} of {len(communities)}:")
    subgraph = G.subgraph(community)
    nodes = list(subgraph.nodes)
    edges = list(subgraph.edges(data=True))
    description = "Entities: " + ", ".join(nodes) + "\nRelationships: "
    relationships = []
    for edge in edges:
        relationships.append(
            f"{edge[0]} -> {edge[2]['title']} -> {edge[1]}")
    description += ", ".join(relationships)
    print(description)
# Out:
# Summarize Community index 0 of 26:
# Entities: RSMA, 1990 claim, Mundy, contracts
# Relationships: RSMA -> RSMA provided notice of the 1990 claim to St. Paul. -> 1990 claim, 1990 claim -> Mundy presented the 1990 claim. -> Mundy, 1990 claim -> Contracts were part of the documents sent to St. Paul regarding the 1990 claim. -> contracts
# Summarize Community index 1 of 26:
# Entities: 1990 notice, Illinois Supreme Court Rule 341(a), persuasion attempt, equitable estoppel, late notice defense, St. Paul, duty to defend RSMA versus La Grange, insurance policy, destruction of policy, appeal
# Relationships: 1990 notice -> Received notice of Mundy’s claim in 1990. -> St. Paul, Illinois Supreme Court Rule 341(a) -> St. Paul failed to comply with this rule regarding the page limitation of the reply brief. -> St. Paul, persuasion attempt -> St. Paul's attempt to persuade the court that RSMA’s 1990 notice did not constitute 'actual notice' under Illinois law was found unconvincing. -> St. Paul, equitable estoppel -> St. Paul's actions were evaluated under the principle of equitable estoppel. -> St. Paul, late notice defense -> St. Paul contended that the notice provided in 1990 was not sufficient and raised a late notice defense. -> St. Paul, St. Paul -> St. Paul drafted the insurance policy. -> insurance policy, St. Paul -> St. Paul attempted to draw a distinction between its duty to defend RSMA vs La Grange. -> duty to defend RSMA versus La Grange, St. Paul -> St. Paul filed this document which was found frivolous by the court. -> appeal, St. Paul -> St. Paul destroyed the actual policy related to the case. -> destruction of policy
# Summarize Community index 2 of 26:
# Entities: 2015 notice, La Grange’s filing of declaratory judgment action, St. Paul Policy, La Grange, sanctions against St. Paul, Illinois Interest Act, Section 2
# Relationships: 2015 notice -> La Grange provided notice to St. Paul in 2015. -> La Grange, La Grange’s filing of declaratory judgment action -> Filed action to question coverage under St. Paul Policy. -> La Grange, St. Paul Policy -> Filed declaratory judgment action questioning coverage. -> La Grange, La Grange -> Granted prejudgment interest for La Grange as per trial court's sound discretion. -> Illinois Interest Act, Section 2, La Grange -> La Grange's motion for sanctions was granted by the court. -> sanctions against St. Paul
# Summarize Community index 3 of 26:
# Entities: American National Trust Co. v. Kentucky Fried Chicken of Southern California, Inc., 308 Ill. App. 3d 106, 120, 719 N.E.2d 201, 211 (1999), Altevogt v. Brinkoetter, 85 Ill. 2d 44, 55, 421 N.E.2d 182 (1981), Garcia v. Lovellette, 265 Ill. App. 3d 724, 732, 639 N.E.2d 935 (1994), third-party beneficiary
# Relationships: American National Trust Co. v. Kentucky Fried Chicken of Southern California, Inc., 308 Ill. App. 3d 106, 120, 719 N.E.2d 201, 211 (1999) -> Reiterates that contract for third-party beneficiary may define by class. -> third-party beneficiary, Altevogt v. Brinkoetter, 85 Ill. 2d 44, 55, 421 N.E.2d 182 (1981) -> Contract for the benefit of a third-party beneficiary does not need to identify him by name. -> third-party beneficiary, Garcia v. Lovellette, 265 Ill. App. 3d 724, 732, 639 N.E.2d 935 (1994) -> Reiterates that contract for third-party beneficiary may define by class. -> third-party beneficiary
# Summarize Community index 4 of 26:
# Entities: Jurisdiction, Appeal
# Relationships: Jurisdiction -> The court ruled that they have jurisdiction to consider the appeal despite late filing. -> Appeal
# Summarize Community index 5 of 26:
# Entities: Collier, Avis Rent A Car System, Inc.
# Relationships: Collier -> Collier was involved in a legal case against Avis Rent A Car System, Inc. referenced in the appeal. -> Avis Rent A Car System, Inc.
# Summarize Community index 6 of 26:
# Entities: Award of penalties, Section 155
# Relationships: Award of penalties -> Provides a basis for the award of penalties for breach. -> Section 155
# Summarize Community index 7 of 26:
# Entities: Breach of duty to defend, Industrial Coatings Group, Inc. v. American Motorists Insurance Co., Illinois Supreme Court Rule 341(g), Received notice of claim on July 25, 1995, St. Paul Insurance Co., Received actual notice of the claim in 1990
# Relationships: Breach of duty to defend -> Failed to defend La Grange, leading to estoppel from denying coverage. -> St. Paul Insurance Co., Industrial Coatings Group, Inc. v. American Motorists Insurance Co. -> Cited overruled case related to timely notice as a condition precedent. -> St. Paul Insurance Co., Illinois Supreme Court Rule 341(g) -> Waived argument by non-compliance with the rule. -> St. Paul Insurance Co., Received notice of claim on July 25, 1995 -> Notice of claim received, triggering duty to defend according to St. Paul. -> St. Paul Insurance Co., St. Paul Insurance Co. -> Had initial notice of the claim, triggering duty to defend. -> Received actual notice of the claim in 1990
# Summarize Community index 8 of 26:
# Entities: Casualty Insurance Co. v. E.W. Corrigan Construction Co., 247 Ill. App. 3d 326, 332-33, 617 N.E.2d 228, 233-34 (1993), notice by an insured
# Relationships: Casualty Insurance Co. v. E.W. Corrigan Construction Co., 247 Ill. App. 3d 326, 332-33, 617 N.E.2d 228, 233-34 (1993) -> Notice by an insured to its insurance company charges the insurer on all policies running in the insured’s favor. -> notice by an insured
# Summarize Community index 9 of 26:
# Entities: St. Paul citing overruled cases, Cincinnati Cos. v. West American Insurance Co.
# Relationships: St. Paul citing overruled cases -> Clarified the insurer's defense obligation upon receiving actual notice. -> Cincinnati Cos. v. West American Insurance Co.
# Summarize Community index 10 of 26:
# Entities: Insurance Co. v. Federal Kemper Insurance Co., 291 Ill. App. 3d 384, 388, 683 N.E.2d 947 (1997), Employers Insurance v. Ehlco Liquidating Trust, 186 Ill. 2d 127, 143, 708 N.E.2d 1122, 1131 (1999), actual notice, Cincinnati Cos. v. West American Insurance Co., 183 Ill. 2d 317, 701 N.E.2d 499 (1998)
# Relationships: Insurance Co. v. Federal Kemper Insurance Co., 291 Ill. App. 3d 384, 388, 683 N.E.2d 947 (1997) -> Existence of actual notice specified. -> actual notice, Employers Insurance v. Ehlco Liquidating Trust, 186 Ill. 2d 127, 143, 708 N.E.2d 1122, 1131 (1999) -> Defines actual notice when insurer knows cause of action has been filed and complaint falls potentially within policy coverage. -> actual notice, actual notice -> An insurer's duty to defend is triggered by actual notice of a claim against the insured. -> Cincinnati Cos. v. West American Insurance Co., 183 Ill. 2d 317, 701 N.E.2d 499 (1998)
# Summarize Community index 11 of 26:
# Entities: underlying complaint, Illinois, Outboard Marine, 154 Ill. 2d at 107-08, 607 N.E.2d at 1212, Cincinnati Cos., 183 Ill. 2d at 323, 701 N.E.2d at 502, relevant provisions of the insurance policy, Insurer's duty to defend
# Relationships: underlying complaint -> The duty to defend is determined by comparing allegations in the underlying complaint. -> Insurer's duty to defend, Illinois -> The insurer’s duty to defend is determined by comparing the allegations in the underlying complaint to the relevant provisions of the insurance policy in Illinois. -> Insurer's duty to defend, Outboard Marine, 154 Ill. 2d at 107-08, 607 N.E.2d at 1212 -> Determines that if the allegations in the underlying complaint fall within or potentially within the policy’s coverage, the insurer’s duty to defend arises. -> Insurer's duty to defend, Cincinnati Cos., 183 Ill. 2d at 323, 701 N.E.2d at 502 -> Reiterates that duty to defend arises if allegations fall potentially within policy coverage. -> Insurer's duty to defend, relevant provisions of the insurance policy -> The duty to defend is determined by comparing relevant provisions of the insurance policy. -> Insurer's duty to defend
# Summarize Community index 12 of 26:
# Entities: Hilke Mundy's claim, La Grange Memorial Hospital, Claim for indemnification
# Relationships: Hilke Mundy's claim -> La Grange made temporary total disability payments to Mundy under the Illinois Workers' Compensation Act. -> La Grange Memorial Hospital, La Grange Memorial Hospital -> La Grange demanded indemnification from RSMA for Mundy's claim. -> Claim for indemnification
# Summarize Community index 13 of 26:
# Entities: Clemmons v. Travelers Insurance Co., 88 Ill. 2d 469, 476, 430 N.E.2d 1104, 1107 (1981), St. Paul policy, Rehabilitation Services of Mid-America, Dispute
# Relationships: Clemmons v. Travelers Insurance Co., 88 Ill. 2d 469, 476, 430 N.E.2d 1104, 1107 (1981) -> St. Paul policy is determined to potentially afford coverage whether it actually did so was a matter for later investigation. -> St. Paul policy, St. Paul policy -> The St. Paul policy covered RSMA. -> Rehabilitation Services of Mid-America, St. Paul policy -> The dispute arose over the coverage provided under the St. Paul policy. -> Dispute
# Summarize Community index 14 of 26:
# Entities: Court Decision, Summary judgment, Illinois Insurance Code, St. Paul Insurance Company, Illinois Interest Act
# Relationships: Court Decision -> The circuit court granted summary judgment against St. Paul. -> St. Paul Insurance Company, Summary judgment -> The court granted summary judgment against St. Paul. -> St. Paul Insurance Company, Illinois Insurance Code -> Statutory penalties were awarded against St. Paul for vexatious and unreasonable conduct pursuant to section 155. -> St. Paul Insurance Company, St. Paul Insurance Company -> Prejudgment interest was awarded under section 2. -> Illinois Interest Act
# Summarize Community index 15 of 26:
# Entities: duty to defend, Crum & Forster Managers Corp. v. Resolution Trust Corp., 156 Ill. 2d 384, 393-94, 620 N.E.2d 1073 (1993)
# Relationships: duty to defend -> Indicates that the duty to defend is broader than the duty to indemnify. -> Crum & Forster Managers Corp. v. Resolution Trust Corp., 156 Ill. 2d 384, 393-94, 620 N.E.2d 1073 (1993)
# Summarize Community index 16 of 26:
# Entities: supreme court, Employers Insurance
# Relationships: supreme court -> Employers Insurance case was acknowledged by the supreme court regarding the doctrine of estoppel. -> Employers Insurance
# Summarize Community index 17 of 26:
# Entities: Maneikis v. St. Paul Insurance Co., St. Paul’s duty to defend was triggered, Employers Insurance v. Ehlco Liquidating Trust
# Relationships: Maneikis v. St. Paul Insurance Co. -> Referenced as supporting the no late-notice exception to estoppel doctrine. -> Employers Insurance v. Ehlco Liquidating Trust, St. Paul’s duty to defend was triggered -> Clarified that late-notice is no exception to estoppel doctrine. -> Employers Insurance v. Ehlco Liquidating Trust
# Summarize Community index 18 of 26:
# Entities: Federal Kemper Insurance Co., Insurance Co.
# Relationships: Federal Kemper Insurance Co. -> Discusses actual notice where insurer receives notice from any source sufficient to permit the insurer to locate and defend its insured. -> Insurance Co.
# Summarize Community index 19 of 26:
# Entities: Hilke Mundy, Workers' compensation claim, Mundy’s claim, Injury
# Relationships: Hilke Mundy -> Hilke Mundy filed a workers' compensation claim for her injuries. -> Workers' compensation claim, Hilke Mundy -> Hilke Mundy was injured while working at La Grange Memorial Hospital. -> Injury, Hilke Mundy -> The claim was made by Hilke Mundy, triggering a duty to defend from St. Paul Insurance Co. -> Mundy’s claim
# Summarize Community index 20 of 26:
# Entities: Illinois Supreme Court Rule 342(a), appellant’s brief
# Relationships: Illinois Supreme Court Rule 342(a) -> This rule requires the appellant’s brief to include an appendix with specific contents. -> appellant’s brief
# Summarize Community index 21 of 26:
# Entities: Illinois Supreme Court Rule 375(b), Sanctions for frivolous appeal
# Relationships: Illinois Supreme Court Rule 375(b) -> Permits sanctions for filing a frivolous appeal. -> Sanctions for frivolous appeal
# Summarize Community index 22 of 26:
# Entities: JUSTICE GALLAGHER, Opinion
# Relationships: JUSTICE GALLAGHER -> JUSTICE GALLAGHER delivered the opinion of the court. -> Opinion
# Summarize Community index 23 of 26:
# Entities: State Farm Fire & Casualty Co., Martin
# Relationships: State Farm Fire & Casualty Co. -> State Farm Fire & Casualty Co. v. Martin identified options available to an insurer regarding coverage. -> Martin
# Summarize Community index 24 of 26:
# Entities: breach duty to defend, Sims v. Illinois National Casualty Co., 43 Ill. App. 2d 184, 193 N.E.2d 123 (1963)
# Relationships: breach duty to defend -> Establishes that an insurer is estopped from raising policy defenses if it breaches the duty to defend. -> Sims v. Illinois National Casualty Co., 43 Ill. App. 2d 184, 193 N.E.2d 123 (1963)
# Summarize Community index 25 of 26:
# Entities: St. Paul’s breach of duty to defend in 1995, St. Paul’s breach of duty to defend in 1990
# Relationships: St. Paul’s breach of duty to defend in 1995 -> The latter breach is inconsequential compared to the former breach in 1990. -> St. Paul’s breach of duty to defend in 1990

# %%
import openai

def summarize_communities(communities, graph):
    client = openai.OpenAI()
    community_summaries = []
    for index, community in enumerate(communities):
        print(f"Summarize Community index {index} of {len(communities)}:")
        subgraph = graph.subgraph(community)
        nodes = list(subgraph.nodes)
        edges = list(subgraph.edges(data=True))
        description = "Entities: " + ", ".join(nodes) + "\nRelationships: "
        relationships = []
        for edge in edges:
            relationships.append(
                f"{edge[0]} -> {edge[2]['title']} -> {edge[1]}")
        description += ", ".join(relationships)

        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": "Summarize the following community of entities and relationships."},
                {"role": "user", "content": description}
            ]
        )
        summary = response.choices[0].message.content.strip()
        community_summaries.append(summary)
    return community_summaries

# %%
summarized_communities = summarize_communities(test, G)
# Out:
# Summarize Community index 0 of 6:
# Summarize Community index 1 of 6:
# Summarize Community index 2 of 6:
# Summarize Community index 3 of 6:
# Summarize Community index 4 of 6:
# Summarize Community index 5 of 6:

# %%
Markdown(summarized_communities[5])
# Out:
# The community of entities and relationships revolves around legal cases and the concept of "actual notice" in the context of insurance law.
#
# 1. **Insurance Co. v. Federal Kemper Insurance Co., 291 Ill. App. 3d 384, 388, 683 N.E.2d 947 (1997)**: This case addresses the specification of the existence of actual notice.
#
# 2. **Employers Insurance v. Ehlco Liquidating Trust, 186 Ill. 2d 127, 143, 708 N.E.2d 1122, 1131 (1999)**: This case defines actual notice, stating that an insurer has actual notice when it is aware that a cause of action has been filed and the complaint possibly falls within the policy coverage.
#
# 3. **Cincinnati Cos. v. West American Insurance Co., 183 Ill. 2d 317, 701 N.E.2d 499 (1998)**: This case is associated with the principle that an insurer's duty to defend is triggered by its actual notice of a claim against the insured.
#
# These cases collectively elucidate the role of actual notice in determining an insurer's duty to defend.

# %%
# 6. Community Summaries → Community Answers → Global Answer
def generate_answers_from_communities(community_summaries, query):
    intermediate_answers = []
    for index, summary in enumerate(community_summaries):
        print(f"Summary index {index} of {len(community_summaries)}:")
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": "Answer the following query based on the provided summary."},
                {"role": "user", "content": f"Query: {query} Summary: {summary}"}
            ]
        )
        print("Intermediate answer:", response.choices[0].message.content)
        intermediate_answers.append(
            response.choices[0].message.content)

    final_response = client.chat.completions.create(
        model="gpt-4o",
        messages=[
            {"role": "system",
                "content": "Combine these answers into a final, concise response."},
            {"role": "user", "content": f"Intermediate answers: {intermediate_answers}"}
        ]
    )
    final_answer = final_response.choices[0].message.content
    return final_answer

# %%
final_answer = generate_answers_from_communities(
    community_summaries=summarized_communities,
    query="",
)

# %%
import logging
import random
import seaborn as sns


palette = "hls"
p = sns.color_palette(palette, len(communities)).as_hex()
random.shuffle(p)
rows = []
group = 0
for community in communities:
    color = p.pop()
    group += 1
    for node in community:
        rows += [{"node": node, "color": color, "group": group}]
df_colors = pd.DataFrame(rows)

for _, row in df_colors.iterrows():
    G.nodes[row["node"]]["group"] = row["group"]
    G.nodes[row["node"]]["color"] = row["color"]
    G.nodes[row["node"]]["size"] = G.degree[row["node"]]

# %%
import json

graph_data = nx.node_link_data(G)

# Specify the file path where you want to save the JSON
json_file_path = "data/graph_data.json"

# Write the graph data to a JSON file
with open(json_file_path, "w", encoding="utf-8-sig") as json_file:
    json.dump(graph_data, json_file, ensure_ascii=False)

# %%
graph_data["links"]
# Out:
# [{'title': 'chunk contextual proximity',
#   'weight': 1.75,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': '$984,943.15',
#   'target': 'Hartford'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': '$984,943.15',
#   'target': 'Hartford Casualty'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': '$984,943.15',
#   'target': 'January 17, 1995'},
#  {'title': 'chunk contextual proximity,The amount included in the judgment in favor of Konami.',
#   'weight': 4.25,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': '$984,943.15',
#   'target': 'Konami'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': '$984,943.15',
#   'target': 'Land & Sky'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': '$984,943.15',
#   'target': 'advertising injury provision'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': '$984,943.15',
#   'target': 'appeal'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': '$984,943.15',
#   'target': 'summary judgment'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.25,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': '$984,943.15',
#   'target': 'trial'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': '935 F. Supp. at 1116',
#   'target': 'Fromberg Inc.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.75,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': '935 F. Supp. at 1116',
#   'target': 'Konami'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.0,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': '935 F. Supp. at 1116',
#   'target': 'Land & Sky Inc.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': '935 F. Supp. at 1116',
#   'target': 'North American Philips'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.75,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': '935 F. Supp. at 1116',
#   'target': 'Union Insurance Co.'},
#  {'title': 'Referenced for the requirement of instructions in a patent infringement case',
#   'weight': 0.0,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c',
#   'source': '935 F. Supp. at 1116',
#   'target': 'Star Technologies'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Advertising mode',
#   'target': 'Fromberg Inc.'},
#  {'title': 'chunk contextual proximity,Used coin-operated machines for advertising mode allegedly causing patent infringement',
#   'weight': 0.75,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Advertising mode',
#   'target': 'Konami'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.0,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Advertising mode',
#   'target': 'Land & Sky Inc.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Advertising mode',
#   'target': 'North American Philips'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.75,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Advertising mode',
#   'target': 'Union Insurance Co.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.75,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'April 16, 1999',
#   'target': 'Hartford'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'April 16, 1999',
#   'target': 'Hartford Casualty'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'April 16, 1999',
#   'target': 'January 17, 1995'},
#  {'title': 'chunk contextual proximity',
#   'weight': 4.25,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'April 16, 1999',
#   'target': 'Konami'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'April 16, 1999',
#   'target': 'Land & Sky'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'April 16, 1999',
#   'target': 'advertising injury provision'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'April 16, 1999',
#   'target': 'appeal'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'April 16, 1999',
#   'target': 'summary judgment'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.25,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'April 16, 1999',
#   'target': 'trial'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.75,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'April 23, 1996',
#   'target': 'Hartford'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'April 23, 1996',
#   'target': 'Hartford Casualty'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'April 23, 1996',
#   'target': 'January 17, 1995'},
#  {'title': 'chunk contextual proximity',
#   'weight': 4.25,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'April 23, 1996',
#   'target': 'Konami'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'April 23, 1996',
#   'target': 'Land & Sky'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'April 23, 1996',
#   'target': 'advertising injury provision'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'April 23, 1996',
#   'target': 'appeal'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'April 23, 1996',
#   'target': 'summary judgment'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.25,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'April 23, 1996',
#   'target': 'trial'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': 'd34ea47c26c8475fa77f6fb79b91af1b,d34ea47c26c8475fa77f6fb79b91af1b',
#   'source': 'Brochu',
#   'target': 'Complaint'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.75,
#   'chunk_id': 'd34ea47c26c8475fa77f6fb79b91af1b,d34ea47c26c8475fa77f6fb79b91af1b,d34ea47c26c8475fa77f6fb79b91af1b',
#   'source': 'Brochu',
#   'target': 'Hartford'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.75,
#   'chunk_id': 'd34ea47c26c8475fa77f6fb79b91af1b,d34ea47c26c8475fa77f6fb79b91af1b,d34ea47c26c8475fa77f6fb79b91af1b',
#   'source': 'Brochu',
#   'target': 'Konami'},
#  {'title': 'Involved in cited case regarding insurance purposes and estoppel',
#   'weight': 0.0,
#   'chunk_id': 'd34ea47c26c8475fa77f6fb79b91af1b',
#   'source': 'Brochu',
#   'target': 'Western Casualty & Surety Co.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 2.0,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,7673b452763e4cb3b6cbca0d8abc3e83,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'CGL policy',
#   'target': 'Hartford'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'CGL policy',
#   'target': 'Hartford Casualty'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'CGL policy',
#   'target': 'January 17, 1995'},
#  {'title': 'chunk contextual proximity,Konami argues that none of the other enumerated offenses under the advertising injury provision of the CGL policy are applicable to the case.',
#   'weight': 5.0,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,7673b452763e4cb3b6cbca0d8abc3e83,7673b452763e4cb3b6cbca0d8abc3e83,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,7673b452763e4cb3b6cbca0d8abc3e83,7673b452763e4cb3b6cbca0d8abc3e83',
#   'source': 'CGL policy',
#   'target': 'Konami'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'CGL policy',
#   'target': 'Land & Sky'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '7673b452763e4cb3b6cbca0d8abc3e83,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'CGL policy',
#   'target': 'North American Philips'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'CGL policy',
#   'target': 'advertising injury provision'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'CGL policy',
#   'target': 'appeal'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.75,
#   'chunk_id': '7673b452763e4cb3b6cbca0d8abc3e83,7673b452763e4cb3b6cbca0d8abc3e83,7673b452763e4cb3b6cbca0d8abc3e83',
#   'source': 'CGL policy',
#   'target': 'patent infringement'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'CGL policy',
#   'target': 'summary judgment'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.25,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'CGL policy',
#   'target': 'trial'},
#  {'title': 'chunk contextual proximity,Forwarded underlying to home office for evaluation',
#   'weight': 1.5,
#   'chunk_id': 'd34ea47c26c8475fa77f6fb79b91af1b,d34ea47c26c8475fa77f6fb79b91af1b,d34ea47c26c8475fa77f6fb79b91af1b,d34ea47c26c8475fa77f6fb79b91af1b,d34ea47c26c8475fa77f6fb79b91af1b,d34ea47c26c8475fa77f6fb79b91af1b,d34ea47c26c8475fa77f6fb79b91af1b',
#   'source': 'Complaint',
#   'target': 'Hartford'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.5,
#   'chunk_id': 'd34ea47c26c8475fa77f6fb79b91af1b,d34ea47c26c8475fa77f6fb79b91af1b,d34ea47c26c8475fa77f6fb79b91af1b,d34ea47c26c8475fa77f6fb79b91af1b,d34ea47c26c8475fa77f6fb79b91af1b,d34ea47c26c8475fa77f6fb79b91af1b',
#   'source': 'Complaint',
#   'target': 'Konami'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': 'd34ea47c26c8475fa77f6fb79b91af1b,d34ea47c26c8475fa77f6fb79b91af1b',
#   'source': 'Complaint',
#   'target': 'Letter'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': 'd34ea47c26c8475fa77f6fb79b91af1b,d34ea47c26c8475fa77f6fb79b91af1b',
#   'source': 'Complaint',
#   'target': 'North American Philips'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': 'd34ea47c26c8475fa77f6fb79b91af1b,d34ea47c26c8475fa77f6fb79b91af1b',
#   'source': 'Complaint',
#   'target': 'Western Casualty & Surety Co.'},
#  {'title': 'chunk contextual proximity,Defendant advertised device insertion to infringe patent',
#   'weight': 0.5,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Device Insertion',
#   'target': 'Fromberg Inc.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.75,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Device Insertion',
#   'target': 'Konami'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.0,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Device Insertion',
#   'target': 'Land & Sky Inc.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Device Insertion',
#   'target': 'North American Philips'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.75,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Device Insertion',
#   'target': 'Union Insurance Co.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': 'f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354',
#   'source': 'Du Page County',
#   'target': 'Hartford Casualty Insurance Company'},
#  {'title': 'chunk contextual proximity',
#   'weight': 3.5,
#   'chunk_id': 'f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354',
#   'source': 'Du Page County',
#   'target': 'Hartford Insurance Company of Illinois'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': 'f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354',
#   'source': 'Du Page County',
#   'target': 'JUSTICE GEIGER'},
#  {'title': 'chunk contextual proximity',
#   'weight': 6.5,
#   'chunk_id': 'f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354',
#   'source': 'Du Page County',
#   'target': 'Konami'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.0,
#   'chunk_id': 'f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354',
#   'source': 'Du Page County',
#   'target': 'Lockheed Sanders, Inc.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': 'f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354',
#   'source': 'Du Page County',
#   'target': 'North American Philips'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.0,
#   'chunk_id': 'f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354',
#   'source': 'Du Page County',
#   'target': 'North American Philips Corporation'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': 'f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354',
#   'source': 'Du Page County',
#   'target': 'advertising injury'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.0,
#   'chunk_id': 'f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354',
#   'source': 'Du Page County',
#   'target': 'complaint'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': 'f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354',
#   'source': 'Du Page County',
#   'target': 'insurance policies'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': 'f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354',
#   'source': 'Du Page County',
#   'target': 'opinion of the court'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': 'f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354',
#   'source': 'Du Page County',
#   'target': 'patent infringement'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': 'f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354',
#   'source': 'Du Page County',
#   'target': 'patent infringement lawsuit'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.75,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'February 20, 1996',
#   'target': 'Hartford'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'February 20, 1996',
#   'target': 'Hartford Casualty'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'February 20, 1996',
#   'target': 'January 17, 1995'},
#  {'title': 'chunk contextual proximity',
#   'weight': 4.25,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'February 20, 1996',
#   'target': 'Konami'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'February 20, 1996',
#   'target': 'Land & Sky'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'February 20, 1996',
#   'target': 'advertising injury provision'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'February 20, 1996',
#   'target': 'appeal'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'February 20, 1996',
#   'target': 'summary judgment'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.25,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'February 20, 1996',
#   'target': 'trial'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Florists’ Mutual Insurance Co.',
#   'target': 'Fromberg Inc.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.75,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Florists’ Mutual Insurance Co.',
#   'target': 'Konami'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.0,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Florists’ Mutual Insurance Co.',
#   'target': 'Land & Sky Inc.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Florists’ Mutual Insurance Co.',
#   'target': 'North American Philips'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.75,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Florists’ Mutual Insurance Co.',
#   'target': 'Union Insurance Co.'},
#  {'title': 'Involved in court case 201 Ill. App. 3d 428, 433 (1990)',
#   'weight': 0.0,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c',
#   'source': 'Florists’ Mutual Insurance Co.',
#   'target': 'International Insurance Co.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Fromberg Inc.',
#   'target': 'Illinois'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Fromberg Inc.',
#   'target': 'Instruction Sheets'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Fromberg Inc.',
#   'target': 'International Insurance Co.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.5,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Fromberg Inc.',
#   'target': 'Konami'},
#  {'title': 'chunk contextual proximity',
#   'weight': 2.0,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Fromberg Inc.',
#   'target': 'Land & Sky Inc.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Fromberg Inc.',
#   'target': 'New Hampshire Insurance Co.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.0,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Fromberg Inc.',
#   'target': 'North American Philips'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Fromberg Inc.',
#   'target': 'Owens-Coming Fiberglas Corp.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Fromberg Inc.',
#   'target': 'RL Chaides Construction Co.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Fromberg Inc.',
#   'target': 'Rohm & Haas'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Fromberg Inc.',
#   'target': 'Star Technologies'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Fromberg Inc.',
#   'target': 'State Farm Fire & Casualty Co.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Fromberg Inc.',
#   'target': 'Thornhill'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.5,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Fromberg Inc.',
#   'target': 'Union Insurance Co.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 3.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Hartford',
#   'target': 'Hartford Casualty'},
#  {'title': 'Hartford filed a cross-motion for summary judgment on this date.,chunk contextual proximity',
#   'weight': 3.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Hartford',
#   'target': 'January 17, 1995'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.75,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Hartford',
#   'target': 'July 31, 1998'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.75,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Hartford',
#   'target': 'June 2, 1995'},
#  {'title': 'Legal dispute over duty to defend,Konami sought to recover attorney fees and costs from Hartford.,chunk contextual proximity,There was no causal connection between Konami’s advertising and the alleged patent infringement according to Hartford.,Dispute over whether patent infringement fell under advertising injury coverage.',
#   'weight': 32.75,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,7673b452763e4cb3b6cbca0d8abc3e83,7673b452763e4cb3b6cbca0d8abc3e83,d34ea47c26c8475fa77f6fb79b91af1b,d34ea47c26c8475fa77f6fb79b91af1b,d34ea47c26c8475fa77f6fb79b91af1b,d34ea47c26c8475fa77f6fb79b91af1b,d34ea47c26c8475fa77f6fb79b91af1b,d34ea47c26c8475fa77f6fb79b91af1b,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144 ...
#   'source': 'Hartford',
#   'target': 'Konami'},
#  {'title': 'chunk contextual proximity',
#   'weight': 3.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Hartford',
#   'target': 'Land & Sky'},
#  {'title': 'chunk contextual proximity,Sent by to Konami indicating a question of coverage',
#   'weight': 0.75,
#   'chunk_id': 'd34ea47c26c8475fa77f6fb79b91af1b,d34ea47c26c8475fa77f6fb79b91af1b,d34ea47c26c8475fa77f6fb79b91af1b,d34ea47c26c8475fa77f6fb79b91af1b',
#   'source': 'Hartford',
#   'target': 'Letter'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.75,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Hartford',
#   'target': 'May 6, 1996'},
#  {'title': 'chunk contextual proximity',
#   'weight': 2.75,
#   'chunk_id': '7673b452763e4cb3b6cbca0d8abc3e83,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,d34ea47c26c8475fa77f6fb79b91af1b,d34ea47c26c8475fa77f6fb79b91af1b,d34ea47c26c8475fa77f6fb79b91af1b',
#   'source': 'Hartford',
#   'target': 'North American Philips'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.75,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Hartford',
#   'target': 'November 23, 1994'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.75,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Hartford',
#   'target': 'September 14, 2000'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.75,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Hartford',
#   'target': 'Union Insurance Co.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.75,
#   'chunk_id': 'd34ea47c26c8475fa77f6fb79b91af1b,d34ea47c26c8475fa77f6fb79b91af1b,d34ea47c26c8475fa77f6fb79b91af1b',
#   'source': 'Hartford',
#   'target': 'Western Casualty & Surety Co.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 3.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Hartford',
#   'target': 'advertising injury provision'},
#  {'title': 'chunk contextual proximity',
#   'weight': 3.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Hartford',
#   'target': 'appeal'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.75,
#   'chunk_id': '7673b452763e4cb3b6cbca0d8abc3e83,7673b452763e4cb3b6cbca0d8abc3e83,7673b452763e4cb3b6cbca0d8abc3e83',
#   'source': 'Hartford',
#   'target': 'patent infringement'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.75,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Hartford',
#   'target': 'section 155'},
#  {'title': 'chunk contextual proximity',
#   'weight': 3.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Hartford',
#   'target': 'summary judgment'},
#  {'title': 'chunk contextual proximity',
#   'weight': 8.75,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Hartford',
#   'target': 'trial'},
#  {'title': 'chunk contextual proximity,Hartford Casualty filed a cross-motion for summary judgment on this date.',
#   'weight': 1.0,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Hartford Casualty',
#   'target': 'January 17, 1995'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Hartford Casualty',
#   'target': 'July 31, 1998'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Hartford Casualty',
#   'target': 'June 2, 1995'},
#  {'title': 'chunk contextual proximity',
#   'weight': 8.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Hartford Casualty',
#   'target': 'Konami'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.0,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Hartford Casualty',
#   'target': 'Land & Sky'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Hartford Casualty',
#   'target': 'May 6, 1996'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Hartford Casualty',
#   'target': 'North American Philips'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Hartford Casualty',
#   'target': 'November 23, 1994'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Hartford Casualty',
#   'target': 'September 14, 2000'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Hartford Casualty',
#   'target': 'Union Insurance Co.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.0,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Hartford Casualty',
#   'target': 'advertising injury provision'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.0,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Hartford Casualty',
#   'target': 'appeal'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Hartford Casualty',
#   'target': 'section 155'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.0,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Hartford Casualty',
#   'target': 'summary judgment'},
#  {'title': 'chunk contextual proximity',
#   'weight': 2.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Hartford Casualty',
#   'target': 'trial'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.75,
#   'chunk_id': 'f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354',
#   'source': 'Hartford Casualty Insurance Company',
#   'target': 'Hartford Insurance Company of Illinois'},
#  {'title': 'chunk contextual proximity',
#   'weight': 3.25,
#   'chunk_id': 'f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354',
#   'source': 'Hartford Casualty Insurance Company',
#   'target': 'Konami'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': 'f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354',
#   'source': 'Hartford Casualty Insurance Company',
#   'target': 'Lockheed Sanders, Inc.'},
#  {'title': 'chunk contextual proximity',
# ...
#  {'title': 'Involved in court case 847 F. Supp. 1452, 1458 (N.D. Cal. 1994)',
#   'weight': 0.0,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c',
#   'source': 'New Hampshire Insurance Co.',
#   'target': 'RL Chaides Construction Co.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.75,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'New Hampshire Insurance Co.',
#   'target': 'Union Insurance Co.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': 'f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354',
#   'source': 'North American Philips',
#   'target': 'North American Philips Corporation'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'North American Philips',
#   'target': 'Owens-Coming Fiberglas Corp.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'North American Philips',
#   'target': 'RL Chaides Construction Co.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'North American Philips',
#   'target': 'Rohm & Haas'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'North American Philips',
#   'target': 'Star Technologies'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'North American Philips',
#   'target': 'State Farm Fire & Casualty Co.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'North American Philips',
#   'target': 'Thornhill'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.75,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'North American Philips',
#   'target': 'Union Insurance Co.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'North American Philips',
#   'target': 'advertising injury provision'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'North American Philips',
#   'target': 'appeal'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': 'f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354',
#   'source': 'North American Philips',
#   'target': 'complaint'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.0,
#   'chunk_id': 'f3b37b0a5f5f493caa3dc83df34fb354,7673b452763e4cb3b6cbca0d8abc3e83,7673b452763e4cb3b6cbca0d8abc3e83,7673b452763e4cb3b6cbca0d8abc3e83',
#   'source': 'North American Philips',
#   'target': 'patent infringement'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'North American Philips',
#   'target': 'summary judgment'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.25,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'North American Philips',
#   'target': 'trial'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': 'f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354',
#   'source': 'North American Philips Corporation',
#   'target': 'advertising injury'},
#  {'title': 'filed by,chunk contextual proximity',
#   'weight': 1.0,
#   'chunk_id': 'f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354',
#   'source': 'North American Philips Corporation',
#   'target': 'complaint'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': 'f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354',
#   'source': 'North American Philips Corporation',
#   'target': 'insurance policies'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': 'f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354',
#   'source': 'North American Philips Corporation',
#   'target': 'opinion of the court'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': 'f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354',
#   'source': 'North American Philips Corporation',
#   'target': 'patent infringement'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': 'f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354',
#   'source': 'North American Philips Corporation',
#   'target': 'patent infringement lawsuit'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'November 23, 1994',
#   'target': 'advertising injury provision'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'November 23, 1994',
#   'target': 'appeal'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'November 23, 1994',
#   'target': 'summary judgment'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.25,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'November 23, 1994',
#   'target': 'trial'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.75,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Owens-Coming Fiberglas Corp.',
#   'target': 'Union Insurance Co.'},
#  {'title': 'Involved in court case 196 U.S. Pat. Q. 726, 745 (N.D. Ala. 1977)',
#   'weight': 0.0,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c',
#   'source': 'Owens-Coming Fiberglas Corp.',
#   'target': 'Rohm & Haas'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.75,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'RL Chaides Construction Co.',
#   'target': 'Union Insurance Co.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.75,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Rohm & Haas',
#   'target': 'Union Insurance Co.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'September 14, 2000',
#   'target': 'advertising injury provision'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'September 14, 2000',
#   'target': 'appeal'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'September 14, 2000',
#   'target': 'summary judgment'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.25,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'September 14, 2000',
#   'target': 'trial'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.75,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Star Technologies',
#   'target': 'Union Insurance Co.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.75,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'State Farm Fire & Casualty Co.',
#   'target': 'Union Insurance Co.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.75,
#   'chunk_id': '6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c,6ef23272a356436581e78bcddb240e6c',
#   'source': 'Thornhill',
#   'target': 'Union Insurance Co.'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Union Insurance Co.',
#   'target': 'advertising injury provision'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Union Insurance Co.',
#   'target': 'appeal'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Union Insurance Co.',
#   'target': 'summary judgment'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.25,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'Union Insurance Co.',
#   'target': 'trial'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': 'f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354',
#   'source': 'advertising injury',
#   'target': 'complaint'},
#  {'title': 'denied to be related to by the insurance companies',
#   'weight': 0.0,
#   'chunk_id': 'f3b37b0a5f5f493caa3dc83df34fb354',
#   'source': 'advertising injury',
#   'target': 'patent infringement'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.0,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'advertising injury provision',
#   'target': 'appeal'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'advertising injury provision',
#   'target': 'section 155'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.0,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'advertising injury provision',
#   'target': 'summary judgment'},
#  {'title': 'chunk contextual proximity',
#   'weight': 2.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'advertising injury provision',
#   'target': 'trial'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'appeal',
#   'target': 'section 155'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.0,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'appeal',
#   'target': 'summary judgment'},
#  {'title': 'chunk contextual proximity',
#   'weight': 2.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'appeal',
#   'target': 'trial'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': 'f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354',
#   'source': 'complaint',
#   'target': 'insurance policies'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': 'f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354',
#   'source': 'complaint',
#   'target': 'opinion of the court'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': 'f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354',
#   'source': 'complaint',
#   'target': 'patent infringement'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': 'f3b37b0a5f5f493caa3dc83df34fb354,f3b37b0a5f5f493caa3dc83df34fb354',
#   'source': 'complaint',
#   'target': 'patent infringement lawsuit'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.75,
#   'chunk_id': '7673b452763e4cb3b6cbca0d8abc3e83,7673b452763e4cb3b6cbca0d8abc3e83,7673b452763e4cb3b6cbca0d8abc3e83',
#   'source': 'contributory infringement',
#   'target': 'patent infringement'},
#  {'title': 'Contributory infringement is based solely on the sale of a patented component.',
#   'weight': 0.0,
#   'chunk_id': '7673b452763e4cb3b6cbca0d8abc3e83',
#   'source': 'contributory infringement',
#   'target': 'sale of a patented component'},
#  {'title': 'Direct patent infringement refers to the making, using, or selling of a patented invention.',
#   'weight': 0.0,
#   'chunk_id': '7673b452763e4cb3b6cbca0d8abc3e83',
#   'source': 'direct patent infringement',
#   'target': 'making, using, or selling of a patented invention'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.75,
#   'chunk_id': '7673b452763e4cb3b6cbca0d8abc3e83,7673b452763e4cb3b6cbca0d8abc3e83,7673b452763e4cb3b6cbca0d8abc3e83',
#   'source': 'direct patent infringement',
#   'target': 'patent infringement'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.75,
#   'chunk_id': '7673b452763e4cb3b6cbca0d8abc3e83,7673b452763e4cb3b6cbca0d8abc3e83,7673b452763e4cb3b6cbca0d8abc3e83',
#   'source': 'making, using, or selling of a patented invention',
#   'target': 'patent infringement'},
#  {'title': 'chunk contextual proximity,Some dictionaries define piracy to encompass patent infringement.',
#   'weight': 0.75,
#   'chunk_id': '7673b452763e4cb3b6cbca0d8abc3e83,7673b452763e4cb3b6cbca0d8abc3e83,7673b452763e4cb3b6cbca0d8abc3e83,7673b452763e4cb3b6cbca0d8abc3e83',
#   'source': 'patent infringement',
#   'target': 'piracy'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.75,
#   'chunk_id': '7673b452763e4cb3b6cbca0d8abc3e83,7673b452763e4cb3b6cbca0d8abc3e83,7673b452763e4cb3b6cbca0d8abc3e83',
#   'source': 'patent infringement',
#   'target': 'sale of a patented component'},
#  {'title': 'chunk contextual proximity',
#   'weight': 0.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'section 155',
#   'target': 'summary judgment'},
#  {'title': 'chunk contextual proximity',
#   'weight': 1.25,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'section 155',
#   'target': 'trial'},
#  {'title': 'chunk contextual proximity',
#   'weight': 2.5,
#   'chunk_id': '0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4d1b9f43d4144b3e7e67',
#   'source': 'summary judgment',
#   'target': 'trial'}]

# %%
def load_graph_from_json(json_file_path):
    try:
        with open(json_file_path, 'r', encoding='utf-8-sig') as file:
            json_data = json.load(file)
    except FileNotFoundError:
        print(f"File not found: {json_file_path}")
        return None
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON from the file: {json_file_path}. Error: {e}")
        return None
    except Exception as e:
        print(f"Unexpected error while reading the file: {e}")
        return None

    G = nx.Graph()
    for node in json_data['nodes']:
        G.add_node(node['id'])
    for link in json_data['links']:
        G.add_edge(link['source'], link['target'], weight=link['weight'], title=link['title'])
    return G


# function to load df from json for chunk retrieval based on node and chunk id
def load_chunks_dataframe(json_file_path):
    try:
        with open(json_file_path, 'r', encoding='utf-8-sig') as file:
            data = json.load(file)

        # Extracting chunks and their IDs
        chunks = []
        for link in data['links']:
            chunk_ids = link.get('chunk_id', '').split(',')
            text = link.get('title', '')  # Assuming 'title' contains the text associated with the chunk
            for chunk_id in chunk_ids:
                if chunk_id:
                    chunks.append({'chunk_id': chunk_id, 'text': text})

        return pd.DataFrame(chunks)

    except Exception as e:
        print(f"Error: {e}")
        return pd.DataFrame()  # Return an empty DataFrame in case of an error

# %%
# Load the graph
graph = load_graph_from_json('data/graph_data.json')
# load the chunk_dataframe
chunks_dataframe = load_chunks_dataframe('data/graph_data.json')

# %%
chunks_dataframe[chunks_dataframe['text']!='chunk contextual proximity']
# Out:
#                               chunk_id  \
# 11    0d1336884d5b4d1b9f43d4144b3e7e67
# 12    0d1336884d5b4d1b9f43d4144b3e7e67
# 13    0d1336884d5b4d1b9f43d4144b3e7e67
# 14    0d1336884d5b4d1b9f43d4144b3e7e67
# 15    0d1336884d5b4d1b9f43d4144b3e7e67
# ...                                ...
# 2070  7673b452763e4cb3b6cbca0d8abc3e83
# 2077  7673b452763e4cb3b6cbca0d8abc3e83
# 2078  7673b452763e4cb3b6cbca0d8abc3e83
# 2079  7673b452763e4cb3b6cbca0d8abc3e83
# 2080  7673b452763e4cb3b6cbca0d8abc3e83
#
#                                                    text
# 11    chunk contextual proximity,The amount included...
# 12    chunk contextual proximity,The amount included...
# 13    chunk contextual proximity,The amount included...
# 14    chunk contextual proximity,The amount included...
# 15    chunk contextual proximity,The amount included...
# ...                                                 ...
# 2070  Direct patent infringement refers to the makin...
# 2077  chunk contextual proximity,Some dictionaries d...
# 2078  chunk contextual proximity,Some dictionaries d...
# 2079  chunk contextual proximity,Some dictionaries d...
# 2080  chunk contextual proximity,Some dictionaries d...
#
# [576 rows x 2 columns]

# %%
import re


def textualize_graph(graph):
    triplets = re.findall(r'\((.*?)\)', graph)
    nodes = {}
    edges = []
    for tri in triplets:
        src, edeg_attr, dst = tri.split(';')
        src = src.lower().strip()
        dst = dst.lower().strip()
        if src not in nodes:
            nodes[src] = len(nodes)
        if dst not in nodes:
            nodes[dst] = len(nodes)
        edges.append({'src': nodes[src], 'edge_attr': edeg_attr.lower().strip(), 'dst': nodes[dst], })

    nodes = pd.DataFrame(nodes.items(), columns=['node_attr', 'node_id'])
    edges = pd.DataFrame(edges)
    return nodes, edges

# %%
from src.embedding_models.models import OpenAIEmbeddings
import nest_asyncio

embeddings = OpenAIEmbeddings()
embedding_fn = embeddings.embedding_fn()

# %%
node_features = pd.DataFrame(graph_data["nodes"])
node_embeddings = embedding_fn(node_features["id"].tolist())
node_features["embeddings"] = node_embeddings
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"

# %%
print(node_features.shape)
node_features.head()
# Out:
# (59, 5)
#    group    color  size                    id  \
# 0      1  #db5f57     9           $984,943.15
# 1      1  #db5f57     6  935 F. Supp. at 1116
# 2      1  #db5f57     5      Advertising mode
# 3      1  #db5f57     9        April 16, 1999
# 4      1  #db5f57     9        April 23, 1996
#
#                                           embeddings
# 0  [0.01951550878584385, -0.01489550992846489, 0....
# 1  [-0.00864872895181179, 0.005267801228910685, 0...
# 2  [-0.006128218956291676, -0.011504832655191422,...
# 3  [-0.0065999156795442104, -0.031243011355400085...
# 4  [-0.001258106785826385, -0.008358835242688656,...

# %%
edge_features = pd.DataFrame(graph_data["links"])
edge_embeddings = embedding_fn(edge_features["title"].tolist())
node_embeddings = embedding_fn(edge_features["source"].tolist())
edge_features["embeddings"] = edge_embeddings
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"

# %%
edge_features
# Out:
#                                                  title  weight  \
# 0                           chunk contextual proximity    1.75
# 1                           chunk contextual proximity    0.50
# 2                           chunk contextual proximity    0.50
# 3    chunk contextual proximity,The amount included...    4.25
# 4                           chunk contextual proximity    0.50
# ..                                                 ...     ...
# 324  chunk contextual proximity,Some dictionaries d...    0.75
# 325                         chunk contextual proximity    0.75
# 326                         chunk contextual proximity    0.50
# 327                         chunk contextual proximity    1.25
# 328                         chunk contextual proximity    2.50
#
#                                               chunk_id               source  \
# 0    0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4...          $984,943.15
# 1    0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4...          $984,943.15
# 2    0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4...          $984,943.15
# 3    0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4...          $984,943.15
# 4    0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4...          $984,943.15
# ..                                                 ...                  ...
# 324  7673b452763e4cb3b6cbca0d8abc3e83,7673b452763e4...  patent infringement
# 325  7673b452763e4cb3b6cbca0d8abc3e83,7673b452763e4...  patent infringement
# 326  0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4...          section 155
# 327  0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4...          section 155
# 328  0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4...     summary judgment
#
#                            target  \
# 0                        Hartford
# 1               Hartford Casualty
# 2                January 17, 1995
# 3                          Konami
# 4                      Land & Sky
# ..                            ...
# 324                        piracy
# 325  sale of a patented component
# 326              summary judgment
# 327                         trial
# 328                         trial
#
#                                             embeddings
# 0    [-0.025688467547297478, -0.01057156641036272, ...
# 1    [-0.025688467547297478, -0.01057156641036272, ...
# 2    [-0.025688467547297478, -0.01057156641036272, ...
# 3    [0.0019303852459415793, -0.0123488400131464, 0...
# 4    [-0.025688467547297478, -0.01057156641036272, ...
# ..                                                 ...
# 324  [-0.01839851774275303, -0.02950393036007881, 0...
# 325  [-0.025586551055312157, -0.01060118991881609, ...
# 326  [-0.025688467547297478, -0.01057156641036272, ...
# 327  [-0.025688467547297478, -0.01057156641036272, ...
# 328  [-0.025688467547297478, -0.01057156641036272, ...
#
# [329 rows x 6 columns]

# %%
from pyvis.network import Network

net = Network(
    notebook=False,
    bgcolor="#1a1a1a",
    cdn_resources="remote",
    height="900px",
    width="100%",
    select_menu=True,
    font_color="#cccccc",
    filter_menu=False,
)
net.from_nx(G)
net.force_atlas_2based(central_gravity=0.015, gravity=-31)
net.show_buttons(filter_=["physics"])
html_output_path = os.path.join("data", "index.html")
html = net.generate_html()
with open(html_output_path, mode="w", encoding="utf-8-sig") as fp:
    fp.write(html)
net.show(html_output_path, notebook=False)
# Out:
# data\index.html

# %%
print(dfg_final.shape)
dfg_final.head()
# Out:
# (648, 5)
#         node_1             node_2  \
# 0  $984,943.15           Hartford
# 1  $984,943.15  Hartford Casualty
# 2  $984,943.15   January 17, 1995
# 3  $984,943.15             Konami
# 4  $984,943.15         Land & Sky
#
#                                             chunk_id  \
# 0  0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4...
# 1  0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4...
# 2  0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4...
# 3  0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4...
# 4  0d1336884d5b4d1b9f43d4144b3e7e67,0d1336884d5b4...
#
#                          edge  count
# 0  chunk contextual proximity    7.0
# 1  chunk contextual proximity    2.0
# 2  chunk contextual proximity    2.0
# 3  chunk contextual proximity   17.0
# 4  chunk contextual proximity    2.0

# %%
from src.embedding_models.models import OpenAIEmbeddings

embeddings = OpenAIEmbeddings()

# %%
embeddings = OpenAIEmbeddings()

# %%
pd.DataFrame(nodes)
# Out:
#                                                     0
# 0                                         $984,943.15
# 1                                935 F. Supp. at 1116
# 2                                    Advertising mode
# 3                                      April 16, 1999
# 4                                      April 23, 1996
# 5                                              Brochu
# 6                                          CGL policy
# 7                                           Complaint
# 8                                    Device Insertion
# 9                                      Du Page County
# 10                                  February 20, 1996
# 11                     Florists’ Mutual Insurance Co.
# 12                                      Fromberg Inc.
# 13                                           Hartford
# 14                                  Hartford Casualty
# 15                Hartford Casualty Insurance Company
# 16             Hartford Insurance Company of Illinois
# 17                                           Illinois
# 18                                 Instruction Sheets
# 19                        International Insurance Co.
# 20                                     JUSTICE GEIGER
# 21                                   January 17, 1995
# 22                                      July 31, 1998
# 23                                       June 2, 1995
# 24                                             Konami
# 25                                         Land & Sky
# 26                                    Land & Sky Inc.
# 27                                             Letter
# 28                             Lockheed Sanders, Inc.
# 29                                        May 6, 1996
# 30                        New Hampshire Insurance Co.
# 31                             North American Philips
# 32                 North American Philips Corporation
# 33                                  November 23, 1994
# 34                       Owens-Coming Fiberglas Corp.
# 35                        RL Chaides Construction Co.
# 36                                        Rohm & Haas
# 37                                 September 14, 2000
# 38                                  Star Technologies
# 39                     State Farm Fire & Casualty Co.
# 40                                          Thornhill
# 41                                Union Insurance Co.
# 42                      Western Casualty & Surety Co.
# 43                                 advertising injury
# 44                       advertising injury provision
# 45                                             appeal
# 46                                          complaint
# 47                          contributory infringement
# 48                         direct patent infringement
# 49                                 insurance policies
# 50  making, using, or selling of a patented invention
# 51                               opinion of the court
# 52                                patent infringement
# 53                        patent infringement lawsuit
# 54                                             piracy
# 55                       sale of a patented component
# 56                                        section 155
# 57                                   summary judgment
# 58                                              trial

# %%
from openai import AsyncOpenAI
import asyncio
from tqdm.asyncio import tqdm_asyncio

class NodeEntity(BaseModel):
    """The original and resolved entity name from a list of nodes."""
    
    original_name: str = Field(
        ...,
        description="The original entity given by the user.",
    )
    resolved_name: str = Field(
        ...,
        description="The name of the entity such that duplications are resolved and issues with punctuation or capitalization are corrected.",
    )
    
    
class ResolvedEntities(BaseModel):
    """A list of entities."""
    
    entities: List[NodeEntity] = Field(..., default_factory=list)
    
    @property
    def to_pandas(self):
        entity_dict = {
            "original_name": [n.original_name for n in self.entities],
            "resolved_name": [n.resolved_name for n in self.entities],
        }
        return pd.DataFrame(entity_dict)
    
    
def system_message() -> str:
    return (
        "You are an expert entity resolution AI. "
        "Users will provide you with a list of Node names representing entities from a knowledge graph separated by new lines. "
        "Your task is to, for each entity, generate a NodeEntity such that duplicates are removed by determining their resolved name. "
        "Try to infer the base name that uniquely describes the entity as concisely as possible. "
        "For example, 'Liberty Mutual Group', 'Liberty Mutual Insurance Co', 'Liberty Mutual Company of Massachusets', 'Liberty Mutual Casualty Insurance' "
        "should all simply be 'Liberty Mutual'. "
        "Please also correct any punctuation or capitalization issues."
    )


async def resolve_entities(entities: List[str], model: str = 'gpt-4o') -> str:
    entity_list_string = "\n ".join(entities)
    client = instructor.from_openai(AsyncOpenAI())
    return await client.chat.completions.create(
        model=model,
        max_retries=5,
        messages=[
            {
                "role": "system",
                "content": system_message(),
            },
            {
                "role": "user",
                "content": f"Here is the list of entities to resolve:\n\n{entity_list_string}",
            },
        ],
        response_model=ResolvedEntities,
    )
  
  
async def process_batch(df_batch: pd.DataFrame, column_name: str, model: str) -> pd.DataFrame:
    entities = df_batch[column_name].tolist()
    resolved_entities = await resolve_entities(entities, model)
    resolved_df = resolved_entities.to_pandas
    resolved_df.index = df_batch.index
    return df_batch.join(resolved_df.set_index("original_name"), on=column_name)


async def process_dataframe(df: pd.DataFrame, column_name: str, model: str, batch_size: int = 50) -> pd.DataFrame:
    tasks = []
    for start in range(0, len(df), batch_size):
        df_batch = df.iloc[start:start + batch_size]
        tasks.append(process_batch(df_batch, column_name, model))
    
    results = []
    for f in tqdm_asyncio.as_completed(tasks, desc="Processing batches"):
        result = await f
        results.append(result)
    
    return pd.concat(results, ignore_index=True)

# Example usage
# import nest_asyncio
# nest_asyncio.apply()

# column_name = "node"
# model = "gpt-4o"

# resolved_df = asyncio.run(process_dataframe(df, column_name, model))

# %%
resolved_entity_nodes = resolve_entities(nodes.tolist())
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"

# %%
test_df = pd.DataFrame({'node': nodes})
test_df.head()
# Out:
#                    node
# 0           $984,943.15
# 1  935 F. Supp. at 1116
# 2      Advertising mode
# 3        April 16, 1999
# 4        April 23, 1996

# %%
import nest_asyncio
nest_asyncio.apply()

column_name = "node"
model = "gpt-4o"

resolved_df = asyncio.run(process_dataframe(test_df, column_name, model))
# Out:
# Processing batches:   0%|          | 0/2 [00:00<?, ?it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing batches:  50%|█████     | 1/2 [00:03<00:03,  3.47s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing batches: 100%|██████████| 2/2 [00:12<00:00,  6.41s/it]

# %%
resolved_df
# Out:
#                                                  node  \
# 0   making, using, or selling of a patented invention
# 1                                opinion of the court
# 2                                 patent infringement
# 3                         patent infringement lawsuit
# 4                                              piracy
# 5                        sale of a patented component
# 6                                         section 155
# 7                                    summary judgment
# 8                                               trial
# 9                                         $984,943.15
# 10                               935 F. Supp. at 1116
# 11                                   Advertising mode
# 12                                     April 16, 1999
# 13                                     April 23, 1996
# 14                                             Brochu
# 15                                         CGL policy
# 16                                          Complaint
# 17                                   Device Insertion
# 18                                     Du Page County
# 19                                  February 20, 1996
# 20                     Florists’ Mutual Insurance Co.
# 21                                      Fromberg Inc.
# 22                                           Hartford
# 23                                  Hartford Casualty
# 24                Hartford Casualty Insurance Company
# 25             Hartford Insurance Company of Illinois
# 26                                           Illinois
# 27                                 Instruction Sheets
# 28                        International Insurance Co.
# 29                                     JUSTICE GEIGER
# 30                                   January 17, 1995
# 31                                      July 31, 1998
# 32                                       June 2, 1995
# 33                                             Konami
# 34                                         Land & Sky
# 35                                    Land & Sky Inc.
# 36                                             Letter
# 37                             Lockheed Sanders, Inc.
# 38                                        May 6, 1996
# 39                        New Hampshire Insurance Co.
# 40                             North American Philips
# 41                 North American Philips Corporation
# 42                                  November 23, 1994
# 43                       Owens-Coming Fiberglas Corp.
# 44                        RL Chaides Construction Co.
# 45                                        Rohm & Haas
# 46                                 September 14, 2000
# 47                                  Star Technologies
# 48                     State Farm Fire & Casualty Co.
# 49                                          Thornhill
# 50                                Union Insurance Co.
# 51                      Western Casualty & Surety Co.
# 52                                 advertising injury
# 53                       advertising injury provision
# 54                                             appeal
# 55                                          complaint
# 56                          contributory infringement
# 57                         direct patent infringement
# 58                                 insurance policies
#
#                                         resolved_name
# 0   Making, Using, or Selling of a Patented Invention
# 1                                Opinion of the Court
# 2                                 Patent Infringement
# 3                                 Patent Infringement
# 4                                              Piracy
# 5                        Sale of a Patented Component
# 6                                         Section 155
# 7                                    Summary Judgment
# 8                                               Trial
# 9                                          984,943.15
# 10                                       935 F. Supp.
# 11                                   Advertising mode
# 12                                     April 16, 1999
# 13                                     April 23, 1996
# 14                                             Brochu
# 15                                         CGL policy
# 16                                          Complaint
# 17                                   Device Insertion
# 18                                     Du Page County
# 19                                  February 20, 1996
# 20                                   Florists’ Mutual
# 21                                           Fromberg
# 22                                           Hartford
# 23                                  Hartford Casualty
# 24                                  Hartford Casualty
# 25                                           Hartford
# 26                                           Illinois
# 27                                 Instruction Sheets
# 28                            International Insurance
# 29                                     Justice Geiger
# 30                                   January 17, 1995
# 31                                      July 31, 1998
# 32                                       June 2, 1995
# 33                                             Konami
# 34                                         Land & Sky
# 35                                         Land & Sky
# 36                                             Letter
# 37                                   Lockheed Sanders
# 38                                        May 6, 1996
# 39                            New Hampshire Insurance
# 40                             North American Philips
# 41                             North American Philips
# 42                                  November 23, 1994
# 43                             Owens-Coming Fiberglas
# 44                            RL Chaides Construction
# 45                                        Rohm & Haas
# 46                                 September 14, 2000
# 47                                  Star Technologies
# 48                         State Farm Fire & Casualty
# 49                                          Thornhill
# 50                                    Union Insurance
# 51                          Western Casualty & Surety
# 52                                 advertising injury
# 53                       advertising injury provision
# 54                                             appeal
# 55                                          complaint
# 56                          contributory infringement
# 57                         direct patent infringement
# 58                                 insurance policies

# %%
docs = [Document(text=t) for t in example_text_list]

# %%
graph_maker = GraphMaker(ontology=example_ontology, verbose=True)

# %%
graph = graph_maker.from_documents(
    docs[:3], 
    delay_s_between=1,
    )
# Out:
# ▶︎ GRAPH MAKER LOG - 2024-05-10 16:39:48 - INFO
# Document: 1
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-10 16:39:48 - INFO
# Using Ontology:
# labels=[{'Person': 'Person name without any adjectives, Remember a person may be referenced by their name or using a pronoun'}, {'Object': "Do not add the definite article 'the' in the object name"}, {'Event': 'Event event involving multiple people. Do not include qualifiers or verbs like gives, leaves, works etc.'}, 'Place', 'Document', 'Organization', 'Action', {'Miscellaneous': 'Any important concept can not be categorized with any other given label'}] relationships=['Relation between any pair of Entities']
#
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-10 16:40:22 - INFO
# LLM Response:
# [
#    {
#        "node_1": {"label": "Person", "name": "Bilbo Baggins"},
#        "node_2": {"label": "Event", "name": "birthday"},
#        "relationship": "Bilbo Baggins celebrates his birthday."
#    },
#    {
#        "node_1": {"label": "Person", "name": "Bilbo Baggins"},
#        "node_2": {"label": "Person", "name": "Frodo"},
#        "relationship": "Bilbo Baggins leaves the Ring to Frodo, who is his heir."
#    },
#    {
#        "node_1": {"label": "Person", "name": "Gandalf"},
#        "node_2": {"label": "Object", "name": "Ring"},
#        "relationship": "Gandalf suspects and later confirms that the Ring is a Ring of Power."
#    },
#    {
#        "node_1": {"label": "Person", "name": "Ring"},
#        "node_2": {"label": "Person", "name": "Dark Lord Sauron"},
#        "relationship": "The Ring was lost by Dark Lord Sauron."
#    },
#    {
#        "node_1": {"label": "Person", "name": "Gandalf"},
#        "node_2": {"label": "Person", "name": "Frodo"},
#        "relationship": "Gandalf counsels Frodo to take the Ring away from the Shire and promises to return."
#    },
#    {
#        "node_1": {"label": "Person", "name": "Frodo"},
#        "node_2": {"label": "Person", "name": "Pippin Took"},
#        "relationship": "Frodo sets out on foot with his cousin Pippin Took."
#    },
#    {
#        "node_1": {"label": "Person", "name": "Frodo"},
#        "node_2": {"label": "Person", "name": "Sam Gamgee"},
#        "relationship": "Sam Gamgee, as Frodo's gardener, joins him on his journey."
#    },
#    {
#        "node_1": {"label": "Person", "name": "Black Riders"},
#        "node_2": {"label": "Person", "name": "Elves"},
#        "relationship": "The Elves' singing to Elbereth helps ward off the Black Riders."
#    },
#    {
#        "node_1": {"label": "Place", "name": "Bucklebury Ferry"},
#        "node_2": {"label": "Person", "name": "Merry Brandybuck"},
#        "relationship": "The Hobbits meet their friend Merry Brandybuck at Bucklebury Ferry."
#    },
#    {
#        "node_1": {"label": "Person", "name": "Merry Brandybuck"},
#        "node_2": {"label": "Person", "name": "Frodo"},
#        "relationship": "Merry Brandybuck insists on joining Frodo's journey along with knowing about the Ring."
#    },
#    {
#        "node_1": {"label": "Person", "name": "Pippin Took"},
#        "node_2": {"label": "Person", "name": "Frodo"},
#        "relationship": "Pippin Took reveals that he knows about the Ring and insists on joining Frodo on his journey."
#    }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-10 16:40:22 - INFO
# Trying JSON Parsing:
# [
#    {
#        "node_1": {"label": "Person", "name": "Bilbo Baggins"},
#        "node_2": {"label": "Event", "name": "birthday"},
#        "relationship": "Bilbo Baggins celebrates his birthday."
#    },
#    {
#        "node_1": {"label": "Person", "name": "Bilbo Baggins"},
#        "node_2": {"label": "Person", "name": "Frodo"},
#        "relationship": "Bilbo Baggins leaves the Ring to Frodo, who is his heir."
#    },
#    {
#        "node_1": {"label": "Person", "name": "Gandalf"},
#        "node_2": {"label": "Object", "name": "Ring"},
#        "relationship": "Gandalf suspects and later confirms that the Ring is a Ring of Power."
#    },
#    {
#        "node_1": {"label": "Person", "name": "Ring"},
#        "node_2": {"label": "Person", "name": "Dark Lord Sauron"},
#        "relationship": "The Ring was lost by Dark Lord Sauron."
#    },
#    {
#        "node_1": {"label": "Person", "name": "Gandalf"},
#        "node_2": {"label": "Person", "name": "Frodo"},
#        "relationship": "Gandalf counsels Frodo to take the Ring away from the Shire and promises to return."
#    },
#    {
#        "node_1": {"label": "Person", "name": "Frodo"},
#        "node_2": {"label": "Person", "name": "Pippin Took"},
#        "relationship": "Frodo sets out on foot with his cousin Pippin Took."
#    },
#    {
#        "node_1": {"label": "Person", "name": "Frodo"},
#        "node_2": {"label": "Person", "name": "Sam Gamgee"},
#        "relationship": "Sam Gamgee, as Frodo's gardener, joins him on his journey."
#    },
#    {
#        "node_1": {"label": "Person", "name": "Black Riders"},
#        "node_2": {"label": "Person", "name": "Elves"},
#        "relationship": "The Elves' singing to Elbereth helps ward off the Black Riders."
#    },
#    {
#        "node_1": {"label": "Place", "name": "Bucklebury Ferry"},
#        "node_2": {"label": "Person", "name": "Merry Brandybuck"},
#        "relationship": "The Hobbits meet their friend Merry Brandybuck at Bucklebury Ferry."
#    },
#    {
#        "node_1": {"label": "Person", "name": "Merry Brandybuck"},
#        "node_2": {"label": "Person", "name": "Frodo"},
#        "relationship": "Merry Brandybuck insists on joining Frodo's journey along with knowing about the Ring."
#    },
#    {
#        "node_1": {"label": "Person", "name": "Pippin Took"},
#        "node_2": {"label": "Person", "name": "Frodo"},
#        "relationship": "Pippin Took reveals that he knows about the Ring and insists on joining Frodo on his journey."
#    }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-10 16:40:22 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-10 16:40:23 - INFO
# Document: 2
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-10 16:40:23 - INFO
# Using Ontology:
# labels=[{'Person': 'Person name without any adjectives, Remember a person may be referenced by their name or using a pronoun'}, {'Object': "Do not add the definite article 'the' in the object name"}, {'Event': 'Event event involving multiple people. Do not include qualifiers or verbs like gives, leaves, works etc.'}, 'Place', 'Document', 'Organization', 'Action', {'Miscellaneous': 'Any important concept can not be categorized with any other given label'}] relationships=['Relation between any pair of Entities']
#
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-10 16:40:58 - INFO
# LLM Response:
# [
#     {
#         "node_1": {"label": "Person", "name": "Merry"},
#         "node_2": {"label": "Person", "name": "Pippin"},
#         "relationship": "Merry and Pippin were both trapped by Old Man Willow."
#     },
#     {
#         "node_1": {"label": "Person", "name": "Tom Bombadil"},
#         "node_2": {"label": "Person", "name": "Merry"},
#         "relationship": "Tom Bombadil rescued Merry from Old Man Willow."
#     },
#     {
#         "node_1": {"label": "Person", "name": "Tom Bombadil"},
#         "node_2": {"label": "Person", "name": "Pippin"},
#         "relationship": "Tom Bombadil rescued Pippin from Old Man Willow."
#     },
#     {
#         "node_1": {"label": "Person", "name": "Tom Bombadil"},
#         "node_2": {"label": "Person", "name": "Frodo"},
#         "relationship": "Tom Bombadil freed Frodo from the barrow-wight's spell."
#     },
#     {
#         "node_1": {"label": "Person", "name": "Tom Bombadil"},
#         "node_2": {"label": "Object", "name": "ancient swords"},
#         "relationship": "Tom Bombadil gives ancient swords to Frodo and his friends."
#     },
#     {
#         "node_1": {"label": "Person", "name": "Strider"},
#         "node_2": {"label": "Place", "name": "Rivendell"},
#         "relationship": "Strider guides the group toward Rivendell."
#     },
#     {
#         "node_1": {"label": "Person", "name": "Frodo"},
#         "node_2": {"label": "Person", "name": "Strider"},
#         "relationship": "Strider meets Frodo in the village of Bree."
#     },
#     {
#         "node_1": {"label": "Person", "name": "Frodo"},
#         "node_2": {"label": "Object", "name": "Ring"},
#         "relationship": "Frodo is associated with the Ring which the Black Riders are after."
#     },
#     {
#         "node_1": {"label": "Person", "name": "innkeeper"},
#         "node_2": {"label": "Document", "name": "old letter"},
#         "relationship": "The innkeeper gives Frodo an old letter from Gandalf."
#     },
#     {
#         "node_1": {"label": "Document", "name": "old letter"},
#         "node_2": {"label": "Person", "name": "Gandalf"},
#         "relationship": "The old letter is written by Gandalf."
#     },
#     {
#         "node_1": {"label": "Person", "name": "Gandalf"},
#         "node_2": {"label": "Person", "name": "Strider"},
#         "relationship": "Gandalf's letter identifies Strider as a friend."
#     },
#     {
#         "node_1": {"label": "Person", "name": "Black Riders"},
#         "node_2": {"label": "Object", "name": "Ring"},
#         "relationship": "Black Riders are in pursuit to seize the Ring."
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-10 16:40:58 - INFO
# Trying JSON Parsing:
# [
#     {
#         "node_1": {"label": "Person", "name": "Merry"},
#         "node_2": {"label": "Person", "name": "Pippin"},
#         "relationship": "Merry and Pippin were both trapped by Old Man Willow."
#     },
#     {
#         "node_1": {"label": "Person", "name": "Tom Bombadil"},
#         "node_2": {"label": "Person", "name": "Merry"},
#         "relationship": "Tom Bombadil rescued Merry from Old Man Willow."
#     },
#     {
#         "node_1": {"label": "Person", "name": "Tom Bombadil"},
#         "node_2": {"label": "Person", "name": "Pippin"},
#         "relationship": "Tom Bombadil rescued Pippin from Old Man Willow."
#     },
#     {
#         "node_1": {"label": "Person", "name": "Tom Bombadil"},
#         "node_2": {"label": "Person", "name": "Frodo"},
#         "relationship": "Tom Bombadil freed Frodo from the barrow-wight's spell."
#     },
#     {
#         "node_1": {"label": "Person", "name": "Tom Bombadil"},
#         "node_2": {"label": "Object", "name": "ancient swords"},
#         "relationship": "Tom Bombadil gives ancient swords to Frodo and his friends."
#     },
#     {
#         "node_1": {"label": "Person", "name": "Strider"},
#         "node_2": {"label": "Place", "name": "Rivendell"},
#         "relationship": "Strider guides the group toward Rivendell."
#     },
#     {
#         "node_1": {"label": "Person", "name": "Frodo"},
#         "node_2": {"label": "Person", "name": "Strider"},
#         "relationship": "Strider meets Frodo in the village of Bree."
#     },
#     {
#         "node_1": {"label": "Person", "name": "Frodo"},
#         "node_2": {"label": "Object", "name": "Ring"},
#         "relationship": "Frodo is associated with the Ring which the Black Riders are after."
#     },
#     {
#         "node_1": {"label": "Person", "name": "innkeeper"},
#         "node_2": {"label": "Document", "name": "old letter"},
#         "relationship": "The innkeeper gives Frodo an old letter from Gandalf."
#     },
#     {
#         "node_1": {"label": "Document", "name": "old letter"},
#         "node_2": {"label": "Person", "name": "Gandalf"},
#         "relationship": "The old letter is written by Gandalf."
#     },
#     {
#         "node_1": {"label": "Person", "name": "Gandalf"},
#         "node_2": {"label": "Person", "name": "Strider"},
#         "relationship": "Gandalf's letter identifies Strider as a friend."
#     },
#     {
#         "node_1": {"label": "Person", "name": "Black Riders"},
#         "node_2": {"label": "Object", "name": "Ring"},
#         "relationship": "Black Riders are in pursuit to seize the Ring."
#     }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-10 16:40:58 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-10 16:40:59 - INFO
# Document: 3
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-10 16:40:59 - INFO
# Using Ontology:
# labels=[{'Person': 'Person name without any adjectives, Remember a person may be referenced by their name or using a pronoun'}, {'Object': "Do not add the definite article 'the' in the object name"}, {'Event': 'Event event involving multiple people. Do not include qualifiers or verbs like gives, leaves, works etc.'}, 'Place', 'Document', 'Organization', 'Action', {'Miscellaneous': 'Any important concept can not be categorized with any other given label'}] relationships=['Relation between any pair of Entities']
#
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-05-10 16:41:35 - INFO
# LLM Response:
# [
#    {
#        "node_1": {"label": "Place", "name": "Weathertop"},
#        "node_2": {"label": "Event", "name": "attack"},
#        "relationship": "At Weathertop, the event of an attack occurs"
#    },
#    {
#        "node_1": {"label": "Person", "name": "Frodo"},
#        "node_2": {"label": "Object", "name": "cursed blade"},
#        "relationship": "Frodo is wounded by the cursed blade"
#    },
#    {
#        "node_1": {"label": "Person", "name": "Strider"},
#        "node_2": {"label": "Action", "name": "fights off"},
#        "relationship": "Strider actively repels the attack"
#    },
#    {
#        "node_1": {"label": "Person", "name": "Strider"},
#        "node_2": {"label": "Person", "name": "Frodo"},
#        "relationship": "Strider treats Frodo with athelas to combat the curse from the blade"
#    },
#    {
#        "node_1": {"label": "Person", "name": "Glorfindel"},
#        "node_2": {"label": "Person", "name": "Frodo"},
#        "relationship": "Glorfindel rides with Frodo, who is now deathly ill, towards Rivendell"
#    },
#    {
#        "node_1": {"label": "Place", "name": "Ford of Bruinen"},
#        "node_2": {"label": "Event", "name": "pursuit"},
#        "relationship": "The Black Riders pursue Frodo into the Ford of Bruinen"
#    },
#    {
#        "node_1": {"label": "Action", "name": "swept away"},
#        "node_2": {"label": "Place", "name": "Ford of Bruinen"},
#        "relationship": "The Black Riders are swept away by flood waters in the Ford of Bruinen"
#    },
#    {
#        "node_1": {"label": "Person", "name": "Elrond"},
#        "node_2": {"label": "Action", "name": "summon flood waters"},
#        "relationship": "Elrond summons flood waters at Ford of Bruinen"
#    },
#    {
#        "node_1": {"label": "Person", "name": "Elrond"},
#        "node_2": {"label": "Person", "name": "Frodo"},
#        "relationship": "Elrond takes care of Frodo, aiding his recovery in Rivendell"
#    },
#    {
#        "node_1": {"label": "Person", "name": "Gandalf"},
#        "node_2": {"label": "Person", "name": "Frodo"},
#        "relationship": "Gandalf informs Frodo about the true nature of the Black Riders, identifying them as Nazgûl"
#    },
#    {
#        "node_1": {"label": "Action", "name": "informs"},
#        "node_2": {"label": "Object", "name": "Rings of Power"},
#        "relationship": "Gandalf provides information that the Black Riders are enslaved by Rings of Power to serve Sauron"
#    }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-10 16:41:35 - INFO
# Trying JSON Parsing:
# [
#    {
#        "node_1": {"label": "Place", "name": "Weathertop"},
#        "node_2": {"label": "Event", "name": "attack"},
#        "relationship": "At Weathertop, the event of an attack occurs"
#    },
#    {
#        "node_1": {"label": "Person", "name": "Frodo"},
#        "node_2": {"label": "Object", "name": "cursed blade"},
#        "relationship": "Frodo is wounded by the cursed blade"
#    },
#    {
#        "node_1": {"label": "Person", "name": "Strider"},
#        "node_2": {"label": "Action", "name": "fights off"},
#        "relationship": "Strider actively repels the attack"
#    },
#    {
#        "node_1": {"label": "Person", "name": "Strider"},
#        "node_2": {"label": "Person", "name": "Frodo"},
#        "relationship": "Strider treats Frodo with athelas to combat the curse from the blade"
#    },
#    {
#        "node_1": {"label": "Person", "name": "Glorfindel"},
#        "node_2": {"label": "Person", "name": "Frodo"},
#        "relationship": "Glorfindel rides with Frodo, who is now deathly ill, towards Rivendell"
#    },
#    {
#        "node_1": {"label": "Place", "name": "Ford of Bruinen"},
#        "node_2": {"label": "Event", "name": "pursuit"},
#        "relationship": "The Black Riders pursue Frodo into the Ford of Bruinen"
#    },
#    {
#        "node_1": {"label": "Action", "name": "swept away"},
#        "node_2": {"label": "Place", "name": "Ford of Bruinen"},
#        "relationship": "The Black Riders are swept away by flood waters in the Ford of Bruinen"
#    },
#    {
#        "node_1": {"label": "Person", "name": "Elrond"},
#        "node_2": {"label": "Action", "name": "summon flood waters"},
#        "relationship": "Elrond summons flood waters at Ford of Bruinen"
#    },
#    {
#        "node_1": {"label": "Person", "name": "Elrond"},
#        "node_2": {"label": "Person", "name": "Frodo"},
#        "relationship": "Elrond takes care of Frodo, aiding his recovery in Rivendell"
#    },
#    {
#        "node_1": {"label": "Person", "name": "Gandalf"},
#        "node_2": {"label": "Person", "name": "Frodo"},
#        "relationship": "Gandalf informs Frodo about the true nature of the Black Riders, identifying them as Nazgûl"
#    },
#    {
#        "node_1": {"label": "Action", "name": "informs"},
#        "node_2": {"label": "Object", "name": "Rings of Power"},
#        "relationship": "Gandalf provides information that the Black Riders are enslaved by Rings of Power to serve Sauron"
#    }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-05-10 16:41:35 - INFO
# JSON Parsing Successful!

# %%
graph[0]
# Out:
# [Edge(node_1=Node(label='Person', name='Bilbo Baggins'), node_2=Node(label='Event', name='birthday'), relationship='Bilbo Baggins celebrates his birthday.', metadata=None, order=0),
#  Edge(node_1=Node(label='Person', name='Bilbo Baggins'), node_2=Node(label='Person', name='Frodo'), relationship='Bilbo Baggins leaves the Ring to Frodo, who is his heir.', metadata=None, order=0),
#  Edge(node_1=Node(label='Person', name='Gandalf'), node_2=Node(label='Object', name='Ring'), relationship='Gandalf suspects and later confirms that the Ring is a Ring of Power.', metadata=None, order=0),
#  Edge(node_1=Node(label='Person', name='Ring'), node_2=Node(label='Person', name='Dark Lord Sauron'), relationship='The Ring was lost by Dark Lord Sauron.', metadata=None, order=0),
#  Edge(node_1=Node(label='Person', name='Gandalf'), node_2=Node(label='Person', name='Frodo'), relationship='Gandalf counsels Frodo to take the Ring away from the Shire and promises to return.', metadata=None, order=0),
#  Edge(node_1=Node(label='Person', name='Frodo'), node_2=Node(label='Person', name='Pippin Took'), relationship='Frodo sets out on foot with his cousin Pippin Took.', metadata=None, order=0),
#  Edge(node_1=Node(label='Person', name='Frodo'), node_2=Node(label='Person', name='Sam Gamgee'), relationship="Sam Gamgee, as Frodo's gardener, joins him on his journey.", metadata=None, order=0),
#  Edge(node_1=Node(label='Person', name='Black Riders'), node_2=Node(label='Person', name='Elves'), relationship="The Elves' singing to Elbereth helps ward off the Black Riders.", metadata=None, order=0),
#  Edge(node_1=Node(label='Place', name='Bucklebury Ferry'), node_2=Node(label='Person', name='Merry Brandybuck'), relationship='The Hobbits meet their friend Merry Brandybuck at Bucklebury Ferry.', metadata=None, order=0),
#  Edge(node_1=Node(label='Person', name='Merry Brandybuck'), node_2=Node(label='Person', name='Frodo'), relationship="Merry Brandybuck insists on joining Frodo's journey along with knowing about the Ring.", metadata=None, order=0),
#  Edge(node_1=Node(label='Person', name='Pippin Took'), node_2=Node(label='Person', name='Frodo'), relationship='Pippin Took reveals that he knows about the Ring and insists on joining Frodo on his journey.', metadata=None, order=0),
#  Edge(node_1=Node(label='Person', name='Merry'), node_2=Node(label='Person', name='Pippin'), relationship='Merry and Pippin were both trapped by Old Man Willow.', metadata=None, order=1),
#  Edge(node_1=Node(label='Person', name='Tom Bombadil'), node_2=Node(label='Person', name='Merry'), relationship='Tom Bombadil rescued Merry from Old Man Willow.', metadata=None, order=1),
#  Edge(node_1=Node(label='Person', name='Tom Bombadil'), node_2=Node(label='Person', name='Pippin'), relationship='Tom Bombadil rescued Pippin from Old Man Willow.', metadata=None, order=1),
#  Edge(node_1=Node(label='Person', name='Tom Bombadil'), node_2=Node(label='Person', name='Frodo'), relationship="Tom Bombadil freed Frodo from the barrow-wight's spell.", metadata=None, order=1),
#  Edge(node_1=Node(label='Person', name='Tom Bombadil'), node_2=Node(label='Object', name='ancient swords'), relationship='Tom Bombadil gives ancient swords to Frodo and his friends.', metadata=None, order=1),
#  Edge(node_1=Node(label='Person', name='Strider'), node_2=Node(label='Place', name='Rivendell'), relationship='Strider guides the group toward Rivendell.', metadata=None, order=1),
#  Edge(node_1=Node(label='Person', name='Frodo'), node_2=Node(label='Person', name='Strider'), relationship='Strider meets Frodo in the village of Bree.', metadata=None, order=1),
#  Edge(node_1=Node(label='Person', name='Frodo'), node_2=Node(label='Object', name='Ring'), relationship='Frodo is associated with the Ring which the Black Riders are after.', metadata=None, order=1),
#  Edge(node_1=Node(label='Person', name='innkeeper'), node_2=Node(label='Document', name='old letter'), relationship='The innkeeper gives Frodo an old letter from Gandalf.', metadata=None, order=1),
#  Edge(node_1=Node(label='Document', name='old letter'), node_2=Node(label='Person', name='Gandalf'), relationship='The old letter is written by Gandalf.', metadata=None, order=1),
#  Edge(node_1=Node(label='Person', name='Gandalf'), node_2=Node(label='Person', name='Strider'), relationship="Gandalf's letter identifies Strider as a friend.", metadata=None, order=1),
#  Edge(node_1=Node(label='Person', name='Black Riders'), node_2=Node(label='Object', name='Ring'), relationship='Black Riders are in pursuit to seize the Ring.', metadata=None, order=1),
#  Edge(node_1=Node(label='Place', name='Weathertop'), node_2=Node(label='Event', name='attack'), relationship='At Weathertop, the event of an attack occurs', metadata=None, order=2),
#  Edge(node_1=Node(label='Person', name='Frodo'), node_2=Node(label='Object', name='cursed blade'), relationship='Frodo is wounded by the cursed blade', metadata=None, order=2),
#  Edge(node_1=Node(label='Person', name='Strider'), node_2=Node(label='Action', name='fights off'), relationship='Strider actively repels the attack', metadata=None, order=2),
#  Edge(node_1=Node(label='Person', name='Strider'), node_2=Node(label='Person', name='Frodo'), relationship='Strider treats Frodo with athelas to combat the curse from the blade', metadata=None, order=2),
#  Edge(node_1=Node(label='Person', name='Glorfindel'), node_2=Node(label='Person', name='Frodo'), relationship='Glorfindel rides with Frodo, who is now deathly ill, towards Rivendell', metadata=None, order=2),
#  Edge(node_1=Node(label='Place', name='Ford of Bruinen'), node_2=Node(label='Event', name='pursuit'), relationship='The Black Riders pursue Frodo into the Ford of Bruinen', metadata=None, order=2),
#  Edge(node_1=Node(label='Action', name='swept away'), node_2=Node(label='Place', name='Ford of Bruinen'), relationship='The Black Riders are swept away by flood waters in the Ford of Bruinen', metadata=None, order=2),
#  Edge(node_1=Node(label='Person', name='Elrond'), node_2=Node(label='Action', name='summon flood waters'), relationship='Elrond summons flood waters at Ford of Bruinen', metadata=None, order=2),
#  Edge(node_1=Node(label='Person', name='Elrond'), node_2=Node(label='Person', name='Frodo'), relationship='Elrond takes care of Frodo, aiding his recovery in Rivendell', metadata=None, order=2),
#  Edge(node_1=Node(label='Person', name='Gandalf'), node_2=Node(label='Person', name='Frodo'), relationship='Gandalf informs Frodo about the true nature of the Black Riders, identifying them as Nazgûl', metadata=None, order=2),
#  Edge(node_1=Node(label='Action', name='informs'), node_2=Node(label='Object', name='Rings of Power'), relationship='Gandalf provides information that the Black Riders are enslaved by Rings of Power to serve Sauron', metadata=None, order=2)]

# %% [markdown]
# ___

# %% [markdown]
# # instructor KG with iterative updates

# %%
from pydantic import BaseModel, Field
from typing import List


class Node(BaseModel):
    id: int
    label: str
    color: str
    
    def __hash__(self) -> int:
        return hash((id, self.label))

class Edge(BaseModel):
    source: int
    target: int
    label: str
    color: str = "black"
    
    def __hash__(self) -> int:
        return hash((self.source, self.target, self.label))

class KnowledgeGraph(BaseModel):
    nodes: List[Node] = Field(..., default_factory=list)
    edges: List[Edge] = Field(..., default_factory=list)

# %%
from openai import OpenAI
import instructor

client = instructor.from_openai(OpenAI())

def generate_graph(input) -> KnowledgeGraph:
    return client.chat.completions.create(
        model="gpt-4o",
        messages=[
            {
                "role": "user",
                "content": f"Help me understand the following Legal Service by describing it as a detailed knowledge graph: {input}",
            }
        ],
        response_model=KnowledgeGraph,
    )

# %%
Markdown(services_df['full_description'].tolist()[0])
# Out:
# Employment Disputes: Handles legal issues concerning current or former employees pursuing legal action against the company. Cases include wrongful termination, payment-related disputes, or contractual matters. Does not handle discrimination accusations.

# %%
graph_0 = generate_graph(input=services_df['full_description'].tolist()[0])

# %%
from graphviz import Digraph

def visualize_knowledge_graph(kg: KnowledgeGraph):
    dot = Digraph(comment="Knowledge Graph")

    # Add nodes
    for node in kg.nodes:
        dot.node(str(node.id), node.label, color=node.color)

    # Add edges
    for edge in kg.edges:
        dot.edge(str(edge.source), str(edge.target), label=edge.label, color=edge.color)

    # Render the graph
    dot.render("knowledge_graph.gv", view=True)

# %%
visualize_knowledge_graph(graph_0)

# %%
from graphviz import Digraph
from typing import Optional
from pydantic import BaseModel, Field
from typing import List

class Node(BaseModel):
    id: int
    label: str
    color: str
    
    def __hash__(self) -> int:
        return hash((id, self.label))

class Edge(BaseModel):
    source: int
    target: int
    label: str
    color: str = "black"
    
    def __hash__(self) -> int:
        return hash((self.source, self.target, self.label))


class KnowledgeGraph(BaseModel):
    nodes: Optional[List[Node]] = Field(..., default_factory=list)
    edges: Optional[List[Edge]] = Field(..., default_factory=list)

    def update(self, other: "KnowledgeGraph") -> "KnowledgeGraph":
        """Updates the current graph with the other graph, deduplicating nodes and edges."""
        return KnowledgeGraph(
            nodes=list(set(self.nodes + other.nodes)),
            edges=list(set(self.edges + other.edges)),
        )

    def draw(self, prefix: str = None):
        dot = Digraph(comment="Knowledge Graph")

        for node in self.nodes:  
            dot.node(str(node.id), node.label, color=node.color)

        for edge in self.edges:  
            dot.edge(
                str(edge.source), str(edge.target), label=edge.label, color=edge.color
            )
        dot.render(prefix, format="png", view=True)

# %%
from openai import OpenAI
import instructor

client = instructor.from_openai(OpenAI())

def generate_graph(input: List[str]) -> KnowledgeGraph:
    cur_state = KnowledgeGraph()  
    num_iterations = len(input)
    for i, inp in enumerate(input):
        new_updates = client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {
                    "role": "system",
                    "content": """You are an iterative knowledge graph builder for a Legal Services front desk.
                    You are given the current state of the graph, and you must append the nodes and edges for a new Service 
                    to it. Do not provide any duplicates and try to reuse nodes as much as possible.""",
                },
                {
                    "role": "user",
                    "content": f"""Extract any new nodes and edges from the following:
                    # Part {i}/{num_iterations} of the input:

                    {inp}""",
                },
                {
                    "role": "user",
                    "content": f"""Here is the current state of the graph:
                    {cur_state.model_dump_json(indent=2)}""",
                },  
            ],
            response_model=KnowledgeGraph,
        )  # type: ignore

        # Update the current state
        cur_state = cur_state.update(new_updates)  
        cur_state.draw(prefix=f"iteration_{i}")
    return cur_state

# %%
sample_texts = services_df['full_description'].tolist()[:9]

# %%
graph: KnowledgeGraph = generate_graph(sample_texts)
graph.draw(prefix="final")
