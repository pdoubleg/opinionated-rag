# %%
import os
from dotenv import load_dotenv
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
from IPython.display import Markdown, display, HTML

import uuid
from tqdm import tqdm
import instructor
import openai
from langchain_community.document_loaders import DataFrameLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

load_dotenv()
# Out:
# True

# %%
os.chdir(os.path.dirname(os.getcwd()))

# %%
df = pd.read_parquet('citation_data_with_context.parquet')
df = df.drop_duplicates(subset=['body'], keep='first')

# %%
sample_test = df.sample(1)
text_column = 'body'

splitter = RecursiveCharacterTextSplitter(
    chunk_size=6000,
    chunk_overlap=100,
    length_function=len,
    is_separator_regex=False,
)

def dataframe2Documents(df: pd.DataFrame, text_column: str):
    loader = DataFrameLoader(df, page_content_column=text_column)
    return loader.load()

# %%
documents = dataframe2Documents(sample_test, text_column)
docs = splitter.split_documents(documents)
len(docs)
# Out:
# 8

# %%
def extract_elements_from_chunks(docs):
    client = openai.OpenAI()
    elements = []
    for index, doc in enumerate(docs):
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": "Extract entities and relationships from the following text."},
                {"role": "user", "content": doc.page_content}
            ]
        )
        print(f"Chunk index {index} of {len(docs)}:")
        entities_and_relations = response.choices[0].message.content
        elements.append(entities_and_relations)
    return elements

# %%
elements = extract_elements_from_chunks(docs)
# Out:
# Chunk index 0 of 8:
# Chunk index 1 of 8:
# Chunk index 2 of 8:
# Chunk index 3 of 8:
# Chunk index 4 of 8:
# Chunk index 5 of 8:
# Chunk index 6 of 8:
# Chunk index 7 of 8:

# %%
print(elements[0])
# Out:
# Entities:
# 1. Justice Hartman
# 2. Illinois National Insurance Company (Illinois National)
# 3. RLI Insurance Company (RLI)
# 4. Michael Schneider
# 5. Haul-away, Inc. (Haulaway)
# 6. Hyang W Yoo
# 7. C. Groot Automatic Disposal Company, Inc. (Groot Automatic Disposal)
# 8. Groot Industries, Inc. (Groot Industries)
# 9. American International Adjustment Company, Inc.
# 10. Marvin L. Donaldson (litigation specialist)
# 11. Rick Dikeman (RLI claims examiner)
#
# Relationships:
# 1. Justice Hartman - Delivered the opinion of the court
# 2. Illinois National Insurance Company - Defendant
# 3. RLI Insurance Company - Plaintiff
# 4. Michael Schneider - Employee of Haul-away, Inc.; involved in an accident
# 5. Haul-away, Inc. - Related to Groot Industries; Michael Schneider's employer
# 6. Hyang W Yoo - Driver involved in the accident with Michael Schneider
# 7. C. Groot Automatic Disposal Company, Inc. - Owned the garbage truck involved in the accident
# 8. Groot Industries, Inc. - Parent company of Haulaway and Groot Automatic Disposal
# 9. American International Adjustment Company, Inc. - Related to coverage notification
# 10. Marvin L. Donaldson - Sent a coverage notification letter to Groot Industries
# 11. Rick Dikeman - Sent a reservation of rights letter to Groot Industries on behalf of RLI

# %%
def summarize_elements(elements):
    client = openai.OpenAI()
    summaries = []
    for _, element in enumerate(elements):
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": "Summarize the following entities and relationships in a structured format. Use \"->\" to represent relationships, after the \"Relationships:\" word."},
                {"role": "user", "content": element}
            ]
        )
        print("Element summary:", response.choices[0].message.content)
        summary = response.choices[0].message.content
        summaries.append(summary)
    return summaries

# %%
element_summaries = summarize_elements(elements)
# Out:
# Element summary: Entities:
# 1. Justice Hartman
# 2. Illinois National Insurance Company (Illinois National)
# 3. RLI Insurance Company (RLI)
# 4. Michael Schneider
# 5. Haul-away, Inc. (Haulaway)
# 6. Hyang W Yoo
# 7. C. Groot Automatic Disposal Company, Inc. (Groot Automatic Disposal)
# 8. Groot Industries, Inc. (Groot Industries)
# 9. American International Adjustment Company, Inc.
# 10. Marvin L. Donaldson (litigation specialist)
# 11. Rick Dikeman (RLI claims examiner)
#
# Relationships:
# 1. Justice Hartman -> Delivered the opinion of the court
# 2. Illinois National Insurance Company -> Defendant
# 3. RLI Insurance Company -> Plaintiff
# 4. Michael Schneider -> Employee of Haul-away, Inc.; involved in an accident
# 5. Haul-away, Inc. -> Related to Groot Industries; Michael Schneider's employer
# 6. Hyang W Yoo -> Driver involved in the accident with Michael Schneider
# 7. C. Groot Automatic Disposal Company, Inc. -> Owned the garbage truck involved in the accident
# 8. Groot Industries, Inc. -> Parent company of Haulaway and Groot Automatic Disposal
# 9. American International Adjustment Company, Inc. -> Related to coverage notification
# 10. Marvin L. Donaldson -> Sent a coverage notification letter to Groot Industries
# 11. Rick Dikeman -> Sent a reservation of rights letter to Groot Industries on behalf of RLI
# Element summary: ### Entities:
# 1. **Susan Warnke**: AIG Claim Services, Inc. claims representative responsible for Schneider claims.
# 2. **AIG Claim Services, Inc. (AIG)**: Company representing Illinois National in the Schneider lawsuit.
# 3. **Illinois National**: Insurance company represented by AIG in connection with the Schneider lawsuit.
# 4. **Schneider**: Subject of the lawsuit involving multiple claims.
# 5. **Richard Palatine**: Warnke’s supervisor at AIG.
# 6. **Robert Bright**: Director of claims litigation for RLI.
# 7. **RLI**: Company involved in providing an umbrella policy.
# 8. **Lawrence K. Rynning**: RLI’s defense counsel.
# 9. **Groot Industries**: One of the entities involved in the Schneider claims.
# 10. **Groot Automatic Disposal**: Another entity involved in the Schneider claims.
# 11. **Groot defendants**: General term referring to Groot Industries and Groot Automatic Disposal in the context of the Schneider lawsuit.
#
# ### Relationships:
# 1. Employment and Role -> (Susan Warnke - AIG Claim Services, Inc. / AIG): Susan Warnke is an AIG claims representative.
# 2. Responsibility Assignment -> (Susan Warnke - Schneider claims): Susan Warnke holds primary responsibility for the Schneider claims.
# 3. Representation -> (AIG - Illinois National): AIG represents Illinois National in the Schneider lawsuit.
# 4. Supervision -> (Richard Palatine - Susan Warnke): Richard Palatine is Susan Warnke’s supervisor.
# 5. Interaction and Correspondence -> (Susan Warnke - Robert Bright): Robert Bright communicated with Susan Warnke questioning her coverage analysis.
# 6. Interaction and Correspondence -> (Susan Warnke - Lawrence K. Rynning): Lawrence K. Rynning communicated with Susan Warnke about coverage issues.
# 7. Interaction -> (Robert Bright - Lawrence K. Rynning): Both are involved in the correspondence discussing the Schneider lawsuit.
# 8. Liability Clarification -> (Illinois National’s CGL policy - Groot defendants): Disputes exist on whether coverage applies to the Groot defendants under the CGL policy.
# 9. Policy Coverage Dispute -> (BA policy - CGL policy and Schneider lawsuit): Disputes between policies in connection with coverage for the Schneider lawsuit.
# 10. Internal Analysis and Decision-Making -> (Richard Palatine - Susan Warnke): Both confirmed the coverage under the CGL policy after reviewing the situation.
# 11. Communication of Authority -> (RLI - Susan Warnke): RLI communicated with Susan Warnke about $1 million in settlement authority under the CGL policy.
# 12. Evaluative Interaction -> (Susan Warnke - Dennis Palatine): Palatine and Susan Warnke made decisions together on insurance coverage.
# 13. Letter Communication -> (Susan Warnke - Groot defendants): Warnke did not inform the Groot defendants about changes in coverage analysis.
# 14. Testimony -> (Susan Warnke - legal context): Susan Warnke gave multiple testimonies about the coverage analysis and decisions.
# 15. Policy Analysis -> (Illinois National’s CGL policy and BA policy - Schneider lawsuit): Warnke analyzed and debated the proper policies to apply to the Schneider claims.
# 16. Legal Interpretation -> (Susan Warnke - Law compliance): Warnke testified regarding issues about why specific endorsements were not included in policies.
# Element summary: ### Entities:
# 1. **Individuals:**
#    - Rynning
#    - Warnke
#    - Schneider
#    - Don Schmitz
#
# 2. **Organizations:**
#    - Illinois National
#    - RLI (Reinsurance Company)
#    - Groot defendants
#
# 3. **Documents/Policies:**
#    - CGL policy (Commercial General Liability policy)
#    - BA policy (Business Auto policy)
#    - UIM (Underinsured Motorist) benefits
#    - Settlement conference report
#    - April 2, 1996, memorandum
#    - Settlement agreement
#    - Complaint for declaratory judgment
#
# 4. **Dates:**
#    - July 6, 1995
#    - March 12, 1996
#    - March 27, 1996
#    - April 2, 1996
#    - September 6, 1996
#
# ### Relationships:
# 1. Communication:
#    - Rynning -> sent a letter to -> Warnke on July 6, 1995.
#    - Warnke -> prepared a settlement report to -> Don Schmitz on March 12, 1996.
#    - Warnke -> authored an April 2, 1996, memorandum to -> instructing a clerk about a policy change.
#
# 2. Claim Filing:
#    - Schneider -> filed an action against -> Illinois National and RLI for UIM benefits under policies issued to -> Groot defendants.
#    - RLI -> filed a complaint for declaratory judgment and monetary judgment on -> September 6, 1996.
#
# 3. Policy Coverage and Payments:
#    - Schneider -> expected -> nearly $1 million in workers' compensation benefits.
#    - Illinois National -> paid $1 million to -> Schneider under the BA policy as part of a $3.15 million settlement.
#    - RLI -> agreed to pay $1.6 million on behalf of -> Groot defendants for the settlement.
#
# 4. Settlement and Legal Actions:
#    - Settlement conference report -> was prepared by -> Warnke with recommendations to settle up to $1,000,000.
#    - Schneider -> dismissed the claim for -> UIM benefits as part of the settlement agreement.
#    - Court findings and decisions regarding the applicability of -> CGL and BA policies and payment limits.
#
# 5. Legal Assertions and Defenses:
#    - Illinois National -> asserted that claims were barred by -> the automobile exclusion in the CGL policy and claimed it did not owe additional amounts under UIM or CGL due to the BA policy’s antistacking clause.
#    - RLI -> contended that -> Illinois National should have authorized payments under multiple policies and that Illinois National's handling was improper.
#    - Circuit court -> found -> Illinois National breached its duty to defend under both policies and estopped from asserting policy exclusions, but upheld the BA policy’s antistacking clause regarding UIM benefits.
# Element summary: **Entities:**
#
# 1. **Illinois National**
#    - Description: An insurance company involved in the appeal.
#
# 2. **RLI**
#    - Description: An insurance company cross-appealing in the case.
#
# 3. **Circuit Court**
#    - Description: The court that initially granted the partial summary judgment.
#
# 4. **Schneider Lawsuit**
#    - Description: The lawsuit for which Illinois National paid settlements.
#
# 5. **Groot Defendants**
#    - Description: The insured parties under Illinois National’s policies.
#
# 6. **Continental Casualty Co.**
#    - Description: Referenced case related to insurance policy construction.
#
# 7. **McDowell & Colantoni, Ltd.**
#    - Description: Parties involved in the referenced insurance case.
#
# 8. **University of Illinois**
#    - Description: Referenced in connection with another related case.
#
# 9. **Outboard Marine Corp.**
#    - Description: Referenced in connection with a related case.
#
# 10. **Liberty Mutual Insurance Co.**
#     - Description: Referenced in connection with a related case.
#
# 11. **Crum & Forster Managers Corp.**
#     - Description: Referenced in a case about insurance policy intent.
#
# 12. **Resolution Trust Corp. (Crum)**
#     - Description: Referenced in the same case as Crum & Forster Managers Corp.
#
# 13. **United States Fidelity & Guaranty Co. (Wilkin)**
#     - Description: Referenced in a case about duty to defend.
#
# 14. **Wilkin Insulation Co.**
#     - Description: Parties involved in the referenced insurance case.
#
# 15. **United States Fire Insurance Co.**
#     - Description: Referenced in a case related to duty to defend.
#
# 16. **Aetna Life & Casualty**
#     - Description: Referenced in the same case as United States Fire Insurance.
#
# 17. **Insurance Co. of the State of Pennsylvania (Protective Insurance)**
#     - Description: Referenced in a case about declaratory judgments and rights.
#
# 18. **Maryland Casualty Co. (Peppers)**
#     - Description: Referenced in a case about defense of noncoverage.
#
# 19. **Peppers**
#     - Description: Referenced in the same case as Maryland Casualty Co.
#
# **Relationships:**
#
# 1. **Illinois National** -> filed a notice of appeal.
# 2. **RLI** -> filed a cross-appeal.
# 3. **Circuit Court** -> granted **RLI** partial summary judgment.
# 4. **Illinois National** -> paid **$1 million** to settle the **Schneider lawsuit**.
# 5. **Illinois National** -> argues against **RLI's** reimbursement claim.
# 6. **Illinois National** -> provided defense to the **Groot defendants**.
# 7. **Circuit Court** -> uses case law from **Continental Casualty Co. v. McDowell & Colantoni, Ltd.**
# 8. **Review of summary judgment** -> involves determining if judgment was correct per **University of Illinois v. Continental Casualty Co.**
# 9. **Summary judgment orders** -> are reviewed de novo, as in **Outboard Marine Corp. v. Liberty Mutual Insurance Co.**
# 10. **Construction of terms** in insurance policies -> is a question of law, as referenced in **Crum & Forster Managers Corp. v. Resolution Trust Corp.**
# 11. **Duty to defend** -> based on the underlying complaint, as explained in **United States Fidelity & Guaranty Co. v. Wilkin Insulation Co.** and **United States Fire Insurance Co. v. Aetna Life & Casualty.**
# 12. **Insurer's uncertainty** in duty to defend -> discussed in **Insurance Co. of the State of Pennsylvania v. Protective Insurance Co.**
# 13. **Failure to defend** must result in prejudice to the insured, -> as mentioned in **Maryland Casualty Co. v. Peppers.**
# Element summary: Entities:
# 1. Illinois National
# 2. Peppers (case reference: 64 Ill. 2d at 196)
# 3. National Ben Franklin Insurance Co.
# 4. Davidovitch (case reference: 123 Ill. App. 3d 88, 93, 462 N.E.2d 696, 1984)
# 5. Mid-State Savings & Loan Ass’n (case reference: 175 Ill. App. 3d 265, 272, 529 N.E.2d 696, 1988)
# 6. Illinois Insurance Exchange, Inc.
# 7. Westchester Fire Insurance Co. (case reference: 321 Ill. App. 3d 622, 633, 747 N.E.2d 955, 2001)
# 8. G. Heileman Brewing Co.
# 9. Reis (case reference: 69 Ill. App. 3d 777, 782, 387 N.E.2d 700, 1978)
# 10. Providence Hospital (case reference: Rollins Burdick Hunter of Illinois, Inc., 824 F. Supp. 131, 1993)
# 11. Schneider (individual with an underlying complaint)
# 12. Haulaway
# 13. Groot Automatic Disposal (Groot defendants)
# 14. Warnke (claims representative)
# 15. Village of Lombard (case reference: Intergovernmental Risk Management Agency, 288 Ill. App. 3d 1003, 1997)
# 16. Briseno (case reference: Chicago Union Station Co., 197 Ill. App. 3d 902, 1990)
# 17. RLI (party filing for summary judgment)
#
# Relationships:
# 1. Peppers -> determined that prejudice by an insurer's assumption of defense is a question of fact (Peppers, 64 Ill. 2d at 196).
# 2. National Ben Franklin Insurance Co. -> case with Davidovitch established grounds for proving estoppel based on reliance on acts or representations (Davidovitch, 123 Ill. App. 3d 88, 93, 462 N.E.2d 696, 1984).
# 3. Illinois National -> cites Mid-State Savings' assertion that mere delay is insufficient to establish prejudice (Mid-State Savings & Loan Ass’n v. Illinois Insurance Exchange, Inc., 175 Ill. App. 3d 265, 272, 529 N.E.2d 696, 1988).
# 4. Westchester Fire Insurance Co. -> emphasized insurer’s duty to not delay contesting coverage if in doubt and timing relative to trial or settlement (Westchester Fire Insurance Co. v. G. Heileman Brewing Co., 321 Ill. App. 3d 622, 633, 747 N.E.2d 955, 2001).
# 5. Westchester Fire Insurance Co. -> quoted Providence Hospital on the importance of insurer’s timing relative to trial/settlement (Providence Hospital, 824 F. Supp. 131, 1993).
# 6. Illinois National -> received notice of a claim involving Schneider (September 1992).
# 7. Warnke (claims representative) -> switched coverages post-settlement, impacting Haulaway and Groot defendants due to anti-stacking clause.
# 8. Illinois National -> changed coverage post-settlement, placing its interests over insureds’, prejudicing Groot defendants (Village of Lombard v. Intergovernmental Risk Management Agency; Briseno v. Chicago Union Station Co.).
# 9. RLI -> filed for and granted summary judgment against Illinois National.
# Element summary: ### Entities
# 1. **RLI** - An insurance company asserting a cross-appeal.
# 2. **Illinois National** - Another insurance company involved in the case with RLI.
# 3. **Schneider** - The injured party seeking UIM (Underinsured Motorist) coverage.
# 4. **Circuit Court** - The court where the partial summary judgment was granted.
# 5. **BA Policy** - A business auto insurance policy involved in the case.
# 6. **Groot Defendants** - Defendants under the liability coverage of the BA policy.
# 7. **Warnke** - A person whose testimony concluded the applicability of UIM coverage.
# 8. **Yoo** - An underinsured driver involved in the accident.
# 9. **Gibbs v. Madison Mutual Insurance Co.** - A case referenced for legal precedent (referred to as Gibbs).
# 10. **Hoglund v. State Farm Mutual Automobile Insurance Co.** - Another case referenced for legal precedent (referred to as Hoglund).
# 11. **$1.6 million** - The amount RLI is entitled to recover on remand, not in excess.
#
# ### Relationships
# 1. **RLI -> Cross-appeals against -> Illinois National** - Regarding UIM coverage for Schneider's injuries.
# 2. **Circuit Court -> Grants -> Partial summary judgment in favor of Illinois National** - In the case.
# 3. **RLI -> Argues -> Antistacking provisions of the BA policy do not bar UIM coverage for Schneider**.
# 4. **Text -> References -> Gibbs and Hoglund cases** - To argue about policy ambiguities and setoffs.
# 5. **Warnke's Testimony -> Concludes -> Applicability of UIM coverage** - Under the terms provided in the UM coverage form.
# 6. **Illinois Law -> Enacts -> UIM coverage requirements** - Effective July 1, 1983.
# 7. **Schneider -> Seeks recovery -> Under the Groot defendants' liability coverage** - Involving separate liabilities.
# 8. **Policy Ambiguity -> Construed in favor of -> The insured (Schneider)**.
# 9. **Illinois National -> Entitled to setoff -> $100,000 paid by Yoo's insurance** company.
#
# ### Legal Conclusions
# 1. **Illinois National -> Entitlement -> Setoff for the $100,000 paid by Yoo's insurance**.
# 2. **RLI -> Reimbursement Rights -> Entitled to seek up to $1.6 million under the UIM provisions on remand**.
# Element summary: ### Entities
#
# 1. **Entities: Legal Bodies**
#    - **Circuit Court of Cook County**
#    - **RLI**
#    - **Illinois National**
#    - **Groot Defendants**
#    - **Warnke**
#    - **Bright**
#    - **Western Casualty & Surety Co. (Brochu)**
#    - **Royal Insurance Co.**
#    - **Process Design Associates, Inc.**
#
# 2. **Entities: Legal Provisions**
#    - **Partial Summary Judgment**
#    - **Product Liability**
#    - **Negligence**
#    - **Illinois National's Antistacking Clause**
#    - **Underinsured Motorist (UIM) Coverage**
#    - **BA Policy**
#    - **UM Coverage**
#    - **Automobile Liability Exclusion**
#    - **CGL Policy**
#    - **Estoppel**
#    - **Waiver Theory**
#
# 3. **Entities: Policy Terms & Limits**
#    - **Auto**
#    - **Garbage Truck**
#    - **Aggregate Maximum Limit of Insurance**
#    - **$1.6 Million**
#    - **$1 Million**
#
# ### Relationships
#
# 1. **Court Judgments**
#    - Circuit Court of Cook County -> granted partial summary judgment -> RLI
#    - Partial summary judgment in favor of Illinois National -> reversed and remanded with directions to enter judgment in favor -> RLI (amount not to exceed $1.6 million)
#    - THEIS, EJ., and HOFFMAN, J. -> concurred
#
# 2. **Legal Claims**
#    - Schneider's civil claims -> against -> Groot Defendants (involving product liability and negligence)
#    - Product liability count -> claimed -> garbage truck was unreasonably dangerous due to design and operational flaws
#    - Negligence count -> alleged -> Groot Defendants failed to mitigate risks by not providing adequate lighting, reflective clothing, and instructions
#
# 3. **Policy Terms and Coverage**
#    - BA Policy -> includes coverage for -> UM coverage ($1 million limit)
#    - BA Policy -> does not clearly state if -> UIM coverage is included
#    - Illinois National -> stated its BA policy contained -> UIM coverage (maximum limits of $1 million)
#    - RLI's automobile liability limitation -> excludes coverage for operations away from premises unless performed by -> independent contractors or under written contract
#
# 4. **Legal Arguments**
#    - Illinois National -> gave actual notice of defenses under -> CGL policy
#    - Illinois National -> argues -> estoppel cannot extend policy coverage or eliminate coverage limits
#    - RLI -> argues -> Illinois National precluded itself from claiming policy exclusions through claims handling procedures
#    - Illinois National -> relies on -> letter from RLI regarding automobile liability exclusions in RLI's policy endorsements
#
# 5. **Legal Precedents**
#    - Western Casualty & Surety Co. v. Brochu (1985) -> Questions not raised in the circuit court are considered -> waived
#    - Royal Insurance Co. v. Process Design Associates, Inc. (1991) -> demonstrated circumstances involving -> excess insurance carrier attempting to prove prejudice to the insured
# Element summary: Entities:
# 1. Illinois National (insurer)
# 2. Mid-State Savings (case)
# 3. Old Mutual Casualty Co. v. Clark (case - referred to as Clark)
# 4. 53 Ill. App. 3d 274, 368 N.E.2d 702 (1977) (case citation)
# 5. Royal Globe Insurance Co. v. Tutt (case - referred to as Tutt)
# 6. 108 Ill. App. 3d 69, 438 N.E.2d 943 (1982) (case citation)
# 7. Groot defendants (insureds)
# 8. Circuit court (judicial body)
# 9. Underlying action (legal context)
# 10. Plaintiff insureds (insureds)
#
# Relationships:
# - Illinois National -> relies on -> Mid-State Savings, Clark, Tutt
# - Mid-State Savings -> involves -> plaintiff insureds with private attorneys + attorneys hired by insurer
# - Clark -> involves -> insureds who failed to prove injury from their own counsel
# - Groot defendants -> relied solely on counsel provided by -> Illinois National
# - Tutt -> involves -> insurer notifying insured of reservation of rights 10 months after a motion to dismiss
# - Circuit court -> applies -> conclusive presumption of prejudice to insured in Tutt
# - Tutt court -> reverses -> circuit court’s decision, no prejudice shown to insured
# - Illinois National -> failed to reserve rights or seek declaratory judgment -> present case, resulting in prejudice to insureds

# %%
import networkx as nx

# 4. Element Summaries → Graph Communities
def build_graph_from_summaries(summaries):
    G = nx.Graph()
    for index, summary in enumerate(summaries):
        print(f"Summary index {index} of {len(summaries)}:")
        lines = summary.split("\n")
        entities_section = False
        relationships_section = False
        entities = []
        for line in lines:
            if line.startswith("### Entities:") or line.startswith("**Entities:**"):
                entities_section = True
                relationships_section = False
                continue
            elif line.startswith("### Relationships:") or line.startswith("**Relationships:**"):
                entities_section = False
                relationships_section = True
                continue
            if entities_section and line.strip():
                if line[0].isdigit() and line[1] == ".":
                    line = line.split(".", 1)[1].strip()
                entity = line.strip()
                entity = entity.replace("**", "")
                entities.append(entity)
                G.add_node(entity)
            elif relationships_section and line.strip():
                parts = line.split("->")
                if len(parts) >= 2:
                    source = parts[0].strip()
                    target = parts[-1].strip()
                    relation = " -> ".join(parts[1:-1]).strip()
                    G.add_edge(source, target, label=relation)
    return G

# %%
graph = build_graph_from_summaries(element_summaries)
# Out:
# Summary index 0 of 8:
# Summary index 1 of 8:
# Summary index 2 of 8:
# Summary index 3 of 8:
# Summary index 4 of 8:
# Summary index 5 of 8:
# Summary index 6 of 8:
# Summary index 7 of 8:

# %%
from cdlib import algorithms

def detect_communities(graph):
    communities = []
    index = 0
    for component in nx.connected_components(graph):
        print(
            f"Component index {index} of {len(list(nx.connected_components(graph)))}:")
        subgraph = graph.subgraph(component)
        if len(subgraph.nodes) > 1:  # Leiden algorithm requires at least 2 nodes
            try:
                sub_communities = algorithms.leiden(subgraph)
                for community in sub_communities.communities:
                    communities.append(list(community))
            except Exception as e:
                print(f"Error processing community {index}: {e}")
        else:
            communities.append(list(subgraph.nodes))
        index += 1
    print("Communities from detect_communities:", communities)
    return communities

# %%
communities = detect_communities(graph)
# Out:
# Component index 0 of 102:
# Component index 1 of 102:
# Component index 2 of 102:
# Component index 3 of 102:
# Component index 4 of 102:
# Component index 5 of 102:
# Component index 6 of 102:
# Component index 7 of 102:
# Component index 8 of 102:
# Component index 9 of 102:
# Component index 10 of 102:
# Component index 11 of 102:
# Error processing community 11: invalid literal for int() with base 10: '(Susan Warnke - AIG Claim Services, Inc. / AIG): Susan Warnke is an AIG claims representative.'
# Component index 12 of 102:
# Error processing community 12: invalid literal for int() with base 10: '2. Responsibility Assignment'
# Component index 13 of 102:
# Error processing community 13: invalid literal for int() with base 10: '3. Representation'
# Component index 14 of 102:
# Error processing community 14: invalid literal for int() with base 10: '4. Supervision'
# Component index 15 of 102:
# Error processing community 15: invalid literal for int() with base 10: '5. Interaction and Correspondence'
# Component index 16 of 102:
# Error processing community 16: invalid literal for int() with base 10: '6. Interaction and Correspondence'
# Component index 17 of 102:
# Error processing community 17: invalid literal for int() with base 10: '7. Interaction'
# Component index 18 of 102:
# Error processing community 18: invalid literal for int() with base 10: '8. Liability Clarification'
# Component index 19 of 102:
# Error processing community 19: invalid literal for int() with base 10: '9. Policy Coverage Dispute'
# Component index 20 of 102:
# Error processing community 20: invalid literal for int() with base 10: '(Richard Palatine - Susan Warnke): Both confirmed the coverage under the CGL policy after reviewing the situation.'
# Component index 21 of 102:
# Error processing community 21: invalid literal for int() with base 10: '11. Communication of Authority'
# Component index 22 of 102:
# Error processing community 22: invalid literal for int() with base 10: '12. Evaluative Interaction'
# Component index 23 of 102:
# Error processing community 23: invalid literal for int() with base 10: '(Susan Warnke - Groot defendants): Warnke did not inform the Groot defendants about changes in coverage analysis.'
# Component index 24 of 102:
# Error processing community 24: invalid literal for int() with base 10: '(Susan Warnke - legal context): Susan Warnke gave multiple testimonies about the coverage analysis and decisions.'
# Component index 25 of 102:
# Error processing community 25: invalid literal for int() with base 10: '(Illinois National’s CGL policy and BA policy - Schneider lawsuit): Warnke analyzed and debated the proper policies to apply to the Schneider claims.'
# Component index 26 of 102:
# Error processing community 26: invalid literal for int() with base 10: '(Susan Warnke - Law compliance): Warnke testified regarding issues about why specific endorsements were not included in policies.'
# Component index 27 of 102:
# Component index 28 of 102:
# Error processing community 28: invalid literal for int() with base 10: '- Rynning'
# Component index 29 of 102:
# Error processing community 29: invalid literal for int() with base 10: 'instructing a clerk about a policy change.'
# Component index 30 of 102:
# Error processing community 30: invalid literal for int() with base 10: '- Schneider'
# Component index 31 of 102:
# Component index 32 of 102:
# Component index 33 of 102:
# Error processing community 33: invalid literal for int() with base 10: '- Illinois National'
# Component index 34 of 102:
# Component index 35 of 102:
# Component index 36 of 102:
# Component index 37 of 102:
# Component index 38 of 102:
# Component index 39 of 102:
# Component index 40 of 102:
# Error processing community 40: invalid literal for int() with base 10: 'Warnke with recommendations to settle up to $1,000,000.'
# Component index 41 of 102:
# Component index 42 of 102:
# Component index 43 of 102:
# Component index 44 of 102:
# Component index 45 of 102:
# Component index 46 of 102:
# Component index 47 of 102:
# Component index 48 of 102:
# Component index 49 of 102:
# Component index 50 of 102:
# Error processing community 50: invalid literal for int() with base 10: 'Groot defendants for the settlement.'
# Component index 51 of 102:
# Error processing community 51: invalid literal for int() with base 10: '- Court findings and decisions regarding the applicability of'
# Component index 52 of 102:
# Error processing community 52: invalid literal for int() with base 10: 'Illinois National breached its duty to defend under both policies and estopped from asserting policy exclusions, but upheld the BA policy’s antistacking clause regarding UIM benefits.'
# Component index 53 of 102:
# Component index 54 of 102:
# Component index 55 of 102:
# Component index 56 of 102:
# Component index 57 of 102:
# Component index 58 of 102:
# Component index 59 of 102:
# Component index 60 of 102:
# Component index 61 of 102:
# Component index 62 of 102:
# Component index 63 of 102:
# Component index 64 of 102:
# Component index 65 of 102:
# Component index 66 of 102:
# Component index 67 of 102:
# Component index 68 of 102:
# Component index 69 of 102:
# Component index 70 of 102:
# Component index 71 of 102:
# Component index 72 of 102:
# Component index 73 of 102:
# Component index 74 of 102:
# Component index 75 of 102:
# Component index 76 of 102:
# Component index 77 of 102:
# Component index 78 of 102:
# Component index 79 of 102:
# Component index 80 of 102:
# Component index 81 of 102:
# Component index 82 of 102:
# Component index 83 of 102:
# Component index 84 of 102:
# Component index 85 of 102:
# Component index 86 of 102:
# Component index 87 of 102:
# Component index 88 of 102:
# Component index 89 of 102:
# Error processing community 89: invalid literal for int() with base 10: '1. **Illinois National**'
# Component index 90 of 102:
# Error processing community 90: invalid literal for int() with base 10: '2. **RLI**'
# Component index 91 of 102:
# Error processing community 91: invalid literal for int() with base 10: '3. **Circuit Court**'
# Component index 92 of 102:
# Error processing community 92: invalid literal for int() with base 10: 'paid **$1 million** to settle the **Schneider lawsuit**.'
# Component index 93 of 102:
# Error processing community 93: invalid literal for int() with base 10: "argues against **RLI's** reimbursement claim."
# Component index 94 of 102:
# Error processing community 94: invalid literal for int() with base 10: 'provided defense to the **Groot defendants**.'
# Component index 95 of 102:
# Error processing community 95: invalid literal for int() with base 10: '7. **Circuit Court**'
# Component index 96 of 102:
# Error processing community 96: invalid literal for int() with base 10: '8. **Review of summary judgment**'
# Component index 97 of 102:
# Error processing community 97: invalid literal for int() with base 10: '9. **Summary judgment orders**'
# Component index 98 of 102:
# Error processing community 98: invalid literal for int() with base 10: '10. **Construction of terms** in insurance policies'
# Component index 99 of 102:
# Error processing community 99: invalid literal for int() with base 10: '11. **Duty to defend**'
# Component index 100 of 102:
# Error processing community 100: invalid literal for int() with base 10: "12. **Insurer's uncertainty** in duty to defend"
# Component index 101 of 102:
# Error processing community 101: invalid literal for int() with base 10: '13. **Failure to defend** must result in prejudice to the insured,'
# Communities from detect_communities: [['Susan Warnke: AIG Claim Services, Inc. claims representative responsible for Schneider claims.'], ['AIG Claim Services, Inc. (AIG): Company representing Illinois National in the Schneider lawsuit.'], ['Illinois National: Insurance company represented by AIG in connection with the Schneider lawsuit.'], ['Schneider: Subject of the lawsuit involving multiple claims.'], ['Richard Palatine: Warnke’s supervisor at AIG.'], ['Robert Bright: Director of claims litigation for RLI.'], ['RLI: Company involved in providing an umbrella policy.'], ['Lawrence K. Rynning: RLI’s defense counsel.'], ['Groot Industries: One of the entities involved in the Schneider claims.'], ['10. Groot Automatic Disposal: Another entity involved in the Schneider claims.'], ['11. Groot defendants: General term referring to Groot Industries and Groot Automatic Disposal in the context of the Schneider lawsuit.'], ['Individuals:'], ['- Don Schmitz'], ['Organizations:'], ['- RLI (Reinsurance Company)'], ['- Groot defendants'], ['Documents/Policies:'], ['- CGL policy (Commercial General Liability policy)'], ['- BA policy (Business Auto policy)'], ['- UIM (Underinsured Motorist) benefits'], ['- April 2, 1996, memorandum'], ['- Settlement agreement'], ['- Complaint for declaratory judgment'], ['Dates:'], ['- July 6, 1995'], ['- March 12, 1996'], ['- March 27, 1996'], ['- April 2, 1996'], ['- September 6, 1996'], ['Illinois National'], ['- Description: An insurance company involved in the appeal.'], ['RLI'], ['- Description: An insurance company cross-appealing in the case.'], ['Circuit Court'], ['- Description: The court that initially granted the partial summary judgment.'], ['Schneider Lawsuit'], ['- Description: The lawsuit for which Illinois National paid settlements.'], ['Groot Defendants'], ['- Description: The insured parties under Illinois National’s policies.'], ['Continental Casualty Co.'], ['- Description: Referenced case related to insurance policy construction.'], ['McDowell & Colantoni, Ltd.'], ['- Description: Parties involved in the referenced insurance case.'], ['University of Illinois'], ['- Description: Referenced in connection with another related case.'], ['Outboard Marine Corp.'], ['- Description: Referenced in connection with a related case.'], ['10. Liberty Mutual Insurance Co.'], ['11. Crum & Forster Managers Corp.'], ['- Description: Referenced in a case about insurance policy intent.'], ['12. Resolution Trust Corp. (Crum)'], ['- Description: Referenced in the same case as Crum & Forster Managers Corp.'], ['13. United States Fidelity & Guaranty Co. (Wilkin)'], ['- Description: Referenced in a case about duty to defend.'], ['14. Wilkin Insulation Co.'], ['15. United States Fire Insurance Co.'], ['- Description: Referenced in a case related to duty to defend.'], ['16. Aetna Life & Casualty'], ['- Description: Referenced in the same case as United States Fire Insurance.'], ['17. Insurance Co. of the State of Pennsylvania (Protective Insurance)'], ['- Description: Referenced in a case about declaratory judgments and rights.'], ['18. Maryland Casualty Co. (Peppers)'], ['- Description: Referenced in a case about defense of noncoverage.'], ['19. Peppers'], ['- Description: Referenced in the same case as Maryland Casualty Co.']]

# %%
len(communities)
# Out:
# 65

# %%
def summarize_communities(communities, graph):
    client = openai.OpenAI()
    community_summaries = []
    for index, community in enumerate(communities):
        print(f"Summarize Community index {index} of {len(communities)}:")
        subgraph = graph.subgraph(community)
        nodes = list(subgraph.nodes)
        edges = list(subgraph.edges(data=True))
        description = "Entities: " + ", ".join(nodes) + "\nRelationships: "
        relationships = []
        for edge in edges:
            relationships.append(
                f"{edge[0]} -> {edge[2]['label']} -> {edge[1]}")
        description += ", ".join(relationships)

        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": "Summarize the following community of entities and relationships."},
                {"role": "user", "content": description}
            ]
        )
        summary = response.choices[0].message.content.strip()
        community_summaries.append(summary)
    return community_summaries

# %%
summarized_communities = summarize_communities(communities, graph)
# Out:
# Summarize Community index 0 of 65:
# Summarize Community index 1 of 65:
# Summarize Community index 2 of 65:
# Summarize Community index 3 of 65:
# Summarize Community index 4 of 65:
# Summarize Community index 5 of 65:
# Summarize Community index 6 of 65:
# Summarize Community index 7 of 65:
# Summarize Community index 8 of 65:
# Summarize Community index 9 of 65:
# Summarize Community index 10 of 65:
# Summarize Community index 11 of 65:
# Summarize Community index 12 of 65:
# Summarize Community index 13 of 65:
# Summarize Community index 14 of 65:
# Summarize Community index 15 of 65:
# Summarize Community index 16 of 65:
# Summarize Community index 17 of 65:
# Summarize Community index 18 of 65:
# Summarize Community index 19 of 65:
# Summarize Community index 20 of 65:
# Summarize Community index 21 of 65:
# Summarize Community index 22 of 65:
# Summarize Community index 23 of 65:
# Summarize Community index 24 of 65:
# Summarize Community index 25 of 65:
# Summarize Community index 26 of 65:
# Summarize Community index 27 of 65:
# Summarize Community index 28 of 65:
# Summarize Community index 29 of 65:
# Summarize Community index 30 of 65:
# Summarize Community index 31 of 65:
# Summarize Community index 32 of 65:
# Summarize Community index 33 of 65:
# Summarize Community index 34 of 65:
# Summarize Community index 35 of 65:
# Summarize Community index 36 of 65:
# Summarize Community index 37 of 65:
# Summarize Community index 38 of 65:
# Summarize Community index 39 of 65:
# Summarize Community index 40 of 65:
# Summarize Community index 41 of 65:
# Summarize Community index 42 of 65:
# Summarize Community index 43 of 65:
# Summarize Community index 44 of 65:
# Summarize Community index 45 of 65:
# Summarize Community index 46 of 65:
# Summarize Community index 47 of 65:
# Summarize Community index 48 of 65:
# Summarize Community index 49 of 65:
# Summarize Community index 50 of 65:
# Summarize Community index 51 of 65:
# Summarize Community index 52 of 65:
# Summarize Community index 53 of 65:
# Summarize Community index 54 of 65:
# Summarize Community index 55 of 65:
# Summarize Community index 56 of 65:
# Summarize Community index 57 of 65:
# Summarize Community index 58 of 65:
# Summarize Community index 59 of 65:
# Summarize Community index 60 of 65:
# Summarize Community index 61 of 65:
# Summarize Community index 62 of 65:
# Summarize Community index 63 of 65:
# Summarize Community index 64 of 65:

# %%
summarized_communities[3]
# Out:
# 'The community involves Schneider, who is the subject of a lawsuit that encompasses various claims. This indicates a legal context where multiple allegations or issues have been raised against Schneider. The primary relationship revolves around Schneider being the central figure in the litigation process with these multiple claims.'

# %%
def generate_answers_from_communities(community_summaries, query):
    client = openai.OpenAI()
    intermediate_answers = []
    for index, summary in enumerate(community_summaries):
        print(f"Summary index {index} of {len(community_summaries)}:")
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": "Answer the following query based on the provided summary."},
                {"role": "user", "content": f"Query: {query} Summary: {summary}"}
            ]
        )
        print("Intermediate answer:", response.choices[0].message.content)
        intermediate_answers.append(
            response.choices[0].message.content)

    final_response = client.chat.completions.create(
        model="gpt-4o",
        messages=[
            {"role": "system",
                "content": "Combine these answers into a final, concise response."},
            {"role": "user", "content": f"Intermediate answers: {intermediate_answers}"}
        ]
    )
    final_answer = final_response.choices[0].message.content
    return final_answer

# %%
from typing import List
from openai import OpenAI
import instructor
from pydantic import BaseModel, Field

client = instructor.from_openai(OpenAI())


def user_message(theme: str, text: str) -> str:
    return f"While focusing on the theme **{theme}**, generate an ontology for the following input text: ```\n{text}\n```"

def system_message() -> str:
    return (
        "You are an expert at creating an ontology for a given theme or topic. "
        "Users will provide you with a **theme** and an input text delimited by ```. "
        "Extract all the entity types from the input text relevant to the **theme**. "
        "The goal is to create an ontology to use for downstream knowledge graph construction for the **theme**."
    )


def generate_ontology(theme: str, text: str, model: str) -> str:
    return client.chat.completions.create(
        model=model,
        max_retries=3,
        messages=[
            {
                "role": "system",
                "content": system_message(),
            },
            {
                "role": "user",
                "content": user_message(theme=theme, text=text),
            },
        ],
        response_model=Ontology,
    )
